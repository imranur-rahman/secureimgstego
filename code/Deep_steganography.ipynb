# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/My\ Drive/code
# Out:
# /content/drive/My Drive/code

# %%
# !git clone https://github.com/alexandremuzio/deep-steg.git
# Out:
# Cloning into 'deep-steg'...
# remote: Enumerating objects: 114, done.
# remote: Total 114 (delta 0), reused 0 (delta 0), pack-reused 114
# Receiving objects: 100% (114/114), 108.13 MiB | 12.56 MiB/s, done.
# Resolving deltas: 100% (41/41), done.
# Checking out files: 100% (23/23), done.

# %%
import numpy as np

def mse(imageA, imageB):
	# the 'Mean Squared Error' between the two images is the
	# sum of the squared difference between the two images;
	# NOTE: the two images must have the same dimension
	err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
	err /= float(imageA.shape[0] * imageA.shape[1])
	arr = ((imageA-imageB)**2).reshape(64*64*3)
	# return the MSE, the lower the error, the more "similar"
	# the two images are
	return arr

imageA = np.random.rand(64,64,3)
imageB = np.random.rand(64,64,3)
print(np.concatenate([mse(imageA,imageB),np.array([1,2,3])]))
# Out:
# [0.14185572 0.18469359 0.15826179 ... 1.         2.         3.        ]

# %% [markdown]
# Install Wget to download the tiny imagenet dataset

# %%
# !pip install wget

# %% [markdown]
# Download Tiny Imagenet

# %%
import wget

print('Beginning file download with wget module')

url = 'http://www.image-net.org/image/tiny/tiny-imagenet-200.zip'
wget.download(url, '/content/drive/My Drive/data/tiny-imagenet-200.zip')

# %% [markdown]
# Unzip tiny-imagenet-200.zip

# %%
cd /content/drive/My\ Drive/temp
# Out:
# /content/drive/My Drive/temp

# %%
# !ls
# Out:
# 'Copy of tiny-imagenet-200.zip'

# %%
# !apt-get install p7zip-full
!7za x FileName

# %%
import zipfile
zip_ref = zipfile.ZipFile("Copy of tiny-imagenet-200.zip", 'r')
zip_ref.extractall()
zip_ref.close()

# %%
# !unzip -q tiny-imagenet-200.zip && ls tiny-imagenet-200
# Out:
# replace tiny-imagenet-200/words.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
cd /content/drive/My\ Drive/code
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-42-5193a1d04bfe>", line 1, in <module>
#     get_ipython().magic('cd /content/drive/My\\ Drive/code')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-91>", line 2, in cd
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
# ...

# %%
# !git clone https://github.com/tuanphan09/deep-steganography.git
# Out:
# Cloning into 'deep-steganography'...
# remote: Enumerating objects: 18, done.
# remote: Total 18 (delta 0), reused 0 (delta 0), pack-reused 18
# Unpacking objects: 100% (18/18), done.

# %%
cd deep-steganography/
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-39-1f47dbc21986>", line 1, in <module>
#     get_ipython().magic('cd deep-steganography/')
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2160, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2081, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-91>", line 2, in cd
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
# ...

# %%
# !python dataset.py
# Out:
# 2020-08-27 09:41:50.608550: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1

# %%
# !python model.py
# Out:
# 2020-08-27 09:41:54.570184: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1

# %%
# !python train.py
# Out:
#   File "train.py", line 89
#     model_file = "("/content/drive/My Drive/code/models/CNN/weights-{epoch:02d}-{val_loss:.2f}.hdf5"
#                                           ^
# SyntaxError: invalid syntax

# %%
# !python predict.py
# Out:
# 2020-08-22 19:16:31.037534: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-08-22 19:16:32.540115: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2300000000 Hz
# 2020-08-22 19:16:32.540375: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2672bc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-08-22 19:16:32.540411: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-08-22 19:16:32.542662: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-08-22 19:16:32.614025: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# !python statistic.py
# Out:
# Traceback (most recent call last):
#   File "statistic.py", line 52, in <module>
#     new_img = cv2.resize(img, (100, 200))
# cv2.error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
