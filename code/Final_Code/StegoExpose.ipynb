# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Initial Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip -q "/content/drive/My Drive/data/tiny-imagenet-200.zip"
# Out:
# replace tiny-imagenet-200/words.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %%
### Imports ###
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard
from keras.engine.topology import Network
from keras.layers import *
from keras.models import Model
from keras.preprocessing import image
import keras.backend as K

import matplotlib.pyplot as plt
import tensorflow as tf

import numpy as np
import os
import random
import scipy.misc
from tqdm import *

# %matplotlib inline

# %%
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(123)
random.seed(121)
tf.random.set_seed(85)

# %%
### Constants ###
DATA_DIR = "/content/tiny-imagenet-200"
TRAIN_DIR = os.path.join(DATA_DIR, "train")
TEST_DIR = os.path.join(DATA_DIR, "test")

IMG_SHAPE = (64, 64)

# %%
def load_dataset_small(num_images_per_class_train=100, num_images_test=1000):
    """Loads training and test datasets, from Tiny ImageNet Visual Recogition Challenge.

    Arguments:
        num_images_per_class_train: number of images per class to load into training dataset.
        num_images_test: total number of images to load into training dataset.
    """
    X_train = []
    X_test = []

    # Create training set.
    for c in os.listdir(TRAIN_DIR):
        c_dir = os.path.join(TRAIN_DIR, c, 'images')
        c_imgs = os.listdir(c_dir)
        random.shuffle(c_imgs)
        #for img_name_i in c_imgs[0:num_images_per_class_train]:
        for img_name_i in c_imgs:
            img_i = image.load_img(os.path.join(c_dir, img_name_i))
            x = image.img_to_array(img_i)
            X_train.append(x)
    random.shuffle(X_train)

    # Create test set.
    test_dir = os.path.join(TEST_DIR, 'images')
    test_imgs = os.listdir(test_dir)
    random.shuffle(test_imgs)
    #for img_name_i in test_imgs[0:num_images_test]:
    for img_name_i in test_imgs:
        img_i = image.load_img(os.path.join(test_dir, img_name_i))
        x = image.img_to_array(img_i)
        X_test.append(x)

    # Return train and test data as numpy arrays.
    return np.array(X_train), np.array(X_test)

# %%
# Load dataset.
X_train_orig, X_test_orig = load_dataset_small()

# Normalize image vectors.
X_train = X_train_orig/255.
X_test = X_test_orig/255.

# Print statistics.
print ("Number of training examples = " + str(X_train.shape[0]))
print ("Number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape)) # Should be (train_size, 64, 64, 3).
# Out:
# Number of training examples = 100000
# Number of test examples = 10000
# X_train shape: (100000, 64, 64, 3)

# %%
#training set lagbe na bro
del X_train
del X_train_orig, X_test_orig

# %%
# We split testing set into two halfs.
# S: secret image
input_S = X_test[0:X_test.shape[0] // 2]

# C: cover image
input_C = X_test[X_test.shape[0] // 2:]

# %% [markdown]
# ## Baluja

# %%
# Variable used to weight the losses of the secret and cover images (See paper for more details)
beta = 1.0

# Loss for reveal network
def rev_loss(y_true, y_pred):
    # Loss for reveal network is: beta * |S-S'|
    return beta * K.sum(K.square(y_true - y_pred))

# Loss for the full model, used for preparation and hidding networks
def full_loss(y_true, y_pred):
    # Loss for the full model is: |C-C'| + beta * |S-S'|
    s_true, c_true = y_true[:,:,:,0:3], y_true[:,:,:,3:6]
    s_pred, c_pred = y_pred[:,:,:,0:3], y_pred[:,:,:,3:6]
    s_loss = K.sum(K.square(s_true - s_pred))
    c_loss = K.sum(K.square(c_true - c_pred))
    return s_loss + c_loss


# Returns the encoder as a Keras model, composed by Preparation and Hiding Networks.
def make_encoder(input_size):
    input_S = Input(shape=(input_size))
    input_C= Input(shape=(input_size))

    x = input_S

    # Preparation Network
    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_prep0_3x3')(x) #changed
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_prep0_4x4')(x) #changed
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_prep0_5x5')(x) #changed
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_prep1_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_prep1_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_prep1_5x5')(x)
    x = concatenate([x3, x4, x5])

    x = concatenate([input_C, x])

    # Hiding network
    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid0_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid0_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid0_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid1_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid1_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid1_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid2_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid2_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid2_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid3_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid3_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid3_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid4_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid4_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid5_5x5')(x)
    x = concatenate([x3, x4, x5])

    output_Cprime = Conv2D(3, (3, 3), strides = (1, 1), padding='same', activation='relu', name='output_C')(x)

    return Model(inputs=[input_S, input_C], #changed
                 outputs=output_Cprime,
                 name = 'Encoder')

# Returns the decoder as a Keras model, composed by the Reveal Network
def make_decoder(input_size, fixed=False):

    # Reveal network
    reveal_input = Input(shape=(input_size))

    # Adding Gaussian noise with 0.01 standard deviation.
    x = GaussianNoise(0.01, name='output_C_noise')(reveal_input) #changed

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev0_3x3')(x) #changed
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev0_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev0_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev1_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev1_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev1_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev2_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev2_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev2_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev3_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev3_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev3_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev4_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev4_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev5_5x5')(x)
    x = concatenate([x3, x4, x5])

    output_Sprime = Conv2D(3, (3, 3), strides = (1, 1), padding='same', activation='relu', name='output_S')(x)

    if not fixed:
        return Model(inputs=reveal_input,
                     outputs=output_Sprime,
                     name = 'Decoder')
    # else:
    #     return Container(inputs=reveal_input,
    #                      outputs=output_Sprime,
    #                      name = 'DecoderFixed')                    # Changed
    else:
      return Network(inputs= reveal_input,   #changed
                      outputs=output_Sprime,
                      name = 'DecoderFixed')

# Full model.
def make_model(input_size):
    input_S = Input(shape=(input_size))
    input_C= Input(shape=(input_size))

    encoder = make_encoder(input_size)

    decoder = make_decoder(input_size)
    decoder.compile(optimizer='adam', loss=rev_loss)
    decoder.trainable = False

    output_Cprime = encoder([input_S, input_C]) #changed
    output_Sprime = decoder(output_Cprime) #changed

    autoencoder = Model(inputs=[input_S, input_C],
                        outputs=concatenate([output_Sprime, output_Cprime]))
    autoencoder.compile(optimizer='adam', loss=full_loss)
    return encoder, decoder, autoencoder

# %%
encoder_model, reveal_model, autoencoder_model = make_model(input_S.shape[1:])
autoencoder_model.load_weights('/content/drive/My Drive/Final_Model/baluja/baluja_autoencoder_model_100k_50e.hdf5')
encoder_model.load_weights('/content/drive/My Drive/Final_Model/baluja/baluja_encoder_model_100k_50e.hdf5')
reveal_model.load_weights('/content/drive/My Drive/Final_Model/baluja/baluja_reveal_model_100k_50e.hdf5')

# %%
# !mkdir "/content/Baluja"

# %%
from google.colab import files
from cv2 import cv2
from tqdm import tqdm
from PIL import Image
import matplotlib

secret=X_test[0:2000]
cover=X_test[2000:4000]

# test_actual_K = np.random.randint(2, size=(2000,4096))
C_prime = encoder_model.predict([secret, cover])

i=1

for c in tqdm(cover):
  matplotlib.image.imsave('/content/Baluja/clean_'+str(i)+'.png',c)
  i= i+1

i=1
for s in tqdm(C_prime):
  s = s.clip(min = 0, max =1)
  matplotlib.image.imsave('/content/Baluja/stego_'+str(i)+'.png',s)

  i= i+1
# Out:
# 100%|██████████| 2000/2000 [00:04<00:00, 436.38it/s]
# 100%|██████████| 2000/2000 [00:04<00:00, 411.54it/s]

# %%
# !zip -r /content/Baluja.zip /content/Baluja
from google.colab import files
files.download("/content/Baluja.zip")

# %% [markdown]
# ##Key Concatenation

# %%
# Variable used to weight the losses of the secret and cover images (See paper for more details)
beta = 1.0

# Loss for reveal network
def rev_loss(y_true, y_pred):
    # Loss for reveal network is: beta * |S-S'|
    return beta * K.sum(K.square(y_true - y_pred))

# Loss for the full model, used for preparation and hidding networks
def full_loss(y_true, y_pred):
    # Loss for the full model is: |C-C'| + beta * |S-S'|
    s_true, c_true = y_true[:,:,:,0:3], y_true[:,:,:,3:6]
    s_pred, c_pred = y_pred[:,:,:,0:3], y_pred[:,:,:,3:6]
    s_loss = rev_loss(s_true, s_pred)
    c_loss = rev_loss(c_true, c_pred)
    return s_loss + c_loss


# Returns the encoder as a Keras model, composed by Preparation and Hiding Networks.
def make_encoder(input_size):
    input_S = Input(shape=(input_size))
    input_C= Input(shape=(input_size))
    input_K = Input(shape=(input_size))

    # input_K = Input(shape=(81,)) #changed
    # filter = Reshape((3, 3, 3, 3))(input_K)
    # x = tf.nn.conv2d(input_S, filter, strides = (1, 1, 1, 1), padding='VALID')


    #x = tf.math.multiply(input_S, input_K)
    x = concatenate([input_S, input_K])
    # Preparation Network
    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_prep0_3x3')(x) #changed
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_prep0_4x4')(x) #changed
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_prep0_5x5')(x) #changed
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_prep1_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_prep1_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_prep1_5x5')(x)
    x = concatenate([x3, x4, x5])

    x = concatenate([input_C, x])

    # Hiding network
    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid0_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid0_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid0_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid1_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid1_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid1_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid2_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid2_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid2_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid3_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid3_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid3_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid4_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid4_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid5_5x5')(x)
    x = concatenate([x3, x4, x5])

    output_Cprime = Conv2D(3, (3, 3), strides = (1, 1), padding='same', activation='relu', name='output_C')(x)

    return Model(inputs=[input_S, input_C, input_K], #changed
                 outputs=output_Cprime,
                 name = 'Encoder')

# Returns the decoder as a Keras model, composed by the Reveal Network
def make_decoder(input_size, fixed=False):

    # Reveal network
    reveal_input = Input(shape=(input_size))
    input_K = Input(shape=(input_size))


    # Adding Gaussian noise with 0.01 standard deviation.
    input_with_noise = GaussianNoise(0.01, name='output_C_noise')(reveal_input) #changed

    x = concatenate([input_with_noise, input_K])
    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev0_3x3')(x) #changed
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev0_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev0_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev1_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev1_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev1_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev2_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev2_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev2_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev3_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev3_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev3_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev4_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev4_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev5_5x5')(x)
    x = concatenate([x3, x4, x5])

    output_Sprime = Conv2D(3, (3, 3), strides = (1, 1), padding='same', activation='relu', name='output_S')(x)

    if not fixed:
        return Model(inputs=[reveal_input,input_K],
                     outputs=output_Sprime,
                     name = 'Decoder')
    # else:
    #     return Container(inputs=reveal_input,
    #                      outputs=output_Sprime,
    #                      name = 'DecoderFixed')                    # Changed
    else:
      return Network(inputs=[reveal_input,input_K],   #changed
                      outputs=output_Sprime,
                      name = 'DecoderFixed')

# Full model.
def make_model(input_size):
    input_S = Input(shape=(input_size))
    input_C= Input(shape=(input_size))
    input_K = Input(shape=(input_size))  #changed

    encoder = make_encoder(input_size)

    decoder = make_decoder(input_size)
    decoder.compile(optimizer='adam', loss=rev_loss)
    decoder.trainable = False

    output_Cprime = encoder([input_S, input_C, input_K]) #changed
    output_Sprime = decoder([output_Cprime, input_K]) #changed

    autoencoder = Model(inputs=[input_S, input_C, input_K],
                        outputs=concatenate([output_Sprime, output_Cprime]))
    autoencoder.compile(optimizer='adam', loss=full_loss)
    return encoder, decoder, autoencoder

# %%
encoder_model, reveal_model, autoencoder_model = make_model(input_S.shape[1:])
autoencoder_model.load_weights('/content/drive/My Drive/Final_Model/key_concatenation/key_concatenation_autoencoder_model_100k_50e.hdf5')
encoder_model.load_weights('/content/drive/My Drive/Final_Model/key_concatenation/key_concatenation_encoder_model_100k_50e.hdf5')
reveal_model.load_weights('/content/drive/My Drive/Final_Model/key_concatenation/key_concatenation_reveal_model_100k_50e.hdf5')

# %%
# !mkdir "/content/Key_concat"

# %%
from google.colab import files
from cv2 import cv2
from tqdm import tqdm
from PIL import Image
import matplotlib

secret=X_test[0:2000]
cover=X_test[2000:4000]

input_K = np.random.randint(256, size=(len(secret), 64, 64, 3))
input_K = input_K/255.

C_prime = encoder_model.predict([secret, cover, input_K])

i=1

for c in tqdm(cover):
  matplotlib.image.imsave('/content/Key_concat/clean_'+str(i)+'.png',c)
  i= i+1

i=1
for s in tqdm(C_prime):
  s = s.clip(min = 0, max =1)
  matplotlib.image.imsave('/content/Key_concat/stego_'+str(i)+'.png',s)

  i= i+1
# Out:
# 100%|██████████| 2000/2000 [00:04<00:00, 431.09it/s]
# 100%|██████████| 2000/2000 [00:04<00:00, 404.92it/s]

# %%
# !zip -r /content/Key_concat.zip /content/Key_concat
from google.colab import files
files.download("/content/Key_concat.zip")
# Out:
#   adding: content/Key_concat/ (stored 0%)
#   adding: content/Key_concat/stego_690.png (stored 0%)
#   adding: content/Key_concat/stego_1950.png (stored 0%)
#   adding: content/Key_concat/clean_899.png (stored 0%)
#   adding: content/Key_concat/clean_1851.png (deflated 0%)
#   adding: content/Key_concat/stego_21.png (stored 0%)
#   adding: content/Key_concat/stego_1400.png (stored 0%)
#   adding: content/Key_concat/stego_1638.png (stored 0%)
#   adding: content/Key_concat/stego_640.png (stored 0%)
#   adding: content/Key_concat/clean_930.png (deflated 0%)
#   adding: content/Key_concat/stego_1883.png (stored 0%)
#   adding: content/Key_concat/stego_16.png (stored 0%)
#   adding: content/Key_concat/clean_1369.png (deflated 0%)
#   adding: content/Key_concat/clean_39.png (stored 0%)
#   adding: content/Key_concat/stego_566.png (stored 0%)
#   adding: content/Key_concat/stego_13.png (stored 0%)
#   adding: content/Key_concat/clean_1330.png (deflated 0%)
#   adding: content/Key_concat/stego_1233.png (stored 0%)
#   adding: content/Key_concat/stego_375.png (stored 0%)
#   adding: content/Key_concat/stego_1260.png (stored 0%)
#   adding: content/Key_concat/stego_429.png (stored 0%)
#   adding: content/Key_concat/clean_1126.png (stored 0%)
#   adding: content/Key_concat/clean_1912.png (deflated 2%)
#   adding: content/Key_concat/stego_950.png (stored 0%)
#   adding: content/Key_concat/stego_1196.png (stored 0%)
#   adding: content/Key_concat/clean_1329.png (deflated 0%)
#   adding: content/Key_concat/stego_1826.png (stored 0%)
#   adding: content/Key_concat/clean_1622.png (deflated 1%)
#   adding: content/Key_concat/clean_1192.png (deflated 1%)
#   adding: content/Key_concat/clean_1600.png (stored 0%)
#   adding: content/Key_concat/stego_1788.png (stored 0%)
#   adding: content/Key_concat/stego_1806.png (stored 0%)
#   adding: content/Key_concat/stego_820.png (stored 0%)
#   adding: content/Key_concat/clean_1702.png (stored 0%)
#   adding: content/Key_concat/stego_1890.png (stored 0%)
#   adding: content/Key_concat/clean_303.png (deflated 1%)
#   adding: content/Key_concat/clean_631.png (deflated 1%)
#   adding: content/Key_concat/stego_17.png (stored 0%)
#   adding: content/Key_concat/stego_965.png (stored 0%)
#   adding: content/Key_concat/stego_1310.png (stored 0%)
#   adding: content/Key_concat/clean_1829.png (stored 0%)
#   adding: content/Key_concat/stego_1531.png (stored 0%)
#   adding: content/Key_concat/clean_891.png (stored 0%)
#   adding: content/Key_concat/clean_383.png (stored 0%)
#   adding: content/Key_concat/stego_315.png (stored 0%)
#   adding: content/Key_concat/stego_1029.png (stored 0%)
#   adding: content/Key_concat/clean_591.png (stored 0%)
#   adding: content/Key_concat/stego_1850.png (stored 0%)
#   adding: content/Key_concat/clean_279.png (stored 0%)
#   adding: content/Key_concat/clean_1890.png (deflated 1%)
#   adding: content/Key_concat/clean_450.png (stored 0%)
#   adding: content/Key_concat/clean_1986.png (deflated 0%)
#   adding: content/Key_concat/clean_1675.png (deflated 0%)
#   adding: content/Key_concat/clean_1155.png (stored 0%)
#   adding: content/Key_concat/clean_813.png (deflated 0%)
#   adding: content/Key_concat/stego_1122.png (stored 0%)
#   adding: content/Key_concat/clean_485.png (stored 0%)
#   adding: content/Key_concat/clean_815.png (stored 0%)
#   adding: content/Key_concat/clean_1028.png (stored 0%)
#   adding: content/Key_concat/clean_1246.png (deflated 1%)
#   adding: content/Key_concat/clean_1741.png (stored 0%)
#   adding: content/Key_concat/stego_1148.png (stored 0%)
#   adding: content/Key_concat/stego_1475.png (stored 0%)
#   adding: content/Key_concat/stego_1647.png (stored 0%)
#   adding: content/Key_concat/stego_42.png (stored 0%)
#   adding: content/Key_concat/clean_51.png (stored 0%)
#   adding: content/Key_concat/clean_1460.png (stored 0%)
#   adding: content/Key_concat/clean_1142.png (stored 0%)
#   adding: content/Key_concat/stego_1556.png (stored 0%)
#   adding: content/Key_concat/clean_1753.png (stored 0%)
#   adding: content/Key_concat/clean_972.png (deflated 0%)
#   adding: content/Key_concat/stego_1922.png (stored 0%)
#   adding: content/Key_concat/stego_291.png (stored 0%)
#   adding: content/Key_concat/stego_768.png (stored 0%)
#   adding: content/Key_concat/stego_975.png (stored 0%)
#   adding: content/Key_concat/stego_551.png (stored 0%)
#   adding: content/Key_concat/clean_278.png (deflated 0%)
#   adding: content/Key_concat/stego_220.png (stored 0%)
#   adding: content/Key_concat/stego_1489.png (stored 0%)
#   adding: content/Key_concat/stego_1028.png (stored 0%)
#   adding: content/Key_concat/stego_136.png (stored 0%)
#   adding: content/Key_concat/clean_1122.png (stored 0%)
#   adding: content/Key_concat/clean_1488.png (deflated 0%)
#   adding: content/Key_concat/clean_744.png (deflated 0%)
#   adding: content/Key_concat/clean_662.png (deflated 1%)
#   adding: content/Key_concat/stego_1664.png (stored 0%)
#   adding: content/Key_concat/clean_758.png (deflated 0%)
#   adding: content/Key_concat/clean_1210.png (deflated 0%)
#   adding: content/Key_concat/stego_952.png (stored 0%)
#   adding: content/Key_concat/stego_149.png (stored 0%)
#   adding: content/Key_concat/stego_983.png (stored 0%)
#   adding: content/Key_concat/clean_1678.png (stored 0%)
#   adding: content/Key_concat/clean_1993.png (stored 0%)
#   adding: content/Key_concat/clean_394.png (deflated 1%)
#   adding: content/Key_concat/clean_1409.png (deflated 0%)
#   adding: content/Key_concat/clean_985.png (stored 0%)
#   adding: content/Key_concat/stego_538.png (stored 0%)
#   adding: content/Key_concat/stego_790.png (stored 0%)
#   adding: content/Key_concat/stego_1402.png (stored 0%)
#   adding: content/Key_concat/clean_1413.png (deflated 0%)
#   adding: content/Key_concat/stego_869.png (stored 0%)
#   adding: content/Key_concat/clean_1664.png (deflated 0%)
#   adding: content/Key_concat/stego_584.png (stored 0%)
#   adding: content/Key_concat/stego_676.png (stored 0%)
#   adding: content/Key_concat/clean_432.png (stored 0%)
#   adding: content/Key_concat/clean_374.png (stored 0%)
#   adding: content/Key_concat/stego_525.png (stored 0%)
#   adding: content/Key_concat/clean_608.png (stored 0%)
#   adding: content/Key_concat/clean_1326.png (stored 0%)
#   adding: content/Key_concat/stego_5.png (stored 0%)
#   adding: content/Key_concat/clean_637.png (deflated 1%)
#   adding: content/Key_concat/clean_252.png (stored 0%)
#   adding: content/Key_concat/stego_275.png (stored 0%)
#   adding: content/Key_concat/clean_773.png (deflated 0%)
#   adding: content/Key_concat/clean_655.png (stored 0%)
#   adding: content/Key_concat/stego_1567.png (stored 0%)
#   adding: content/Key_concat/stego_494.png (stored 0%)
#   adding: content/Key_concat/stego_860.png (stored 0%)
#   adding: content/Key_concat/clean_1662.png (stored 0%)
#   adding: content/Key_concat/clean_185.png (deflated 0%)
#   adding: content/Key_concat/stego_1784.png (stored 0%)
#   adding: content/Key_concat/stego_1708.png (stored 0%)
#   adding: content/Key_concat/stego_309.png (stored 0%)
#   adding: content/Key_concat/clean_473.png (stored 0%)
#   adding: content/Key_concat/clean_1990.png (deflated 0%)
#   adding: content/Key_concat/stego_1126.png (stored 0%)
#   adding: content/Key_concat/stego_190.png (stored 0%)
#   adding: content/Key_concat/clean_312.png (stored 0%)
#   adding: content/Key_concat/stego_320.png (stored 0%)
#   adding: content/Key_concat/stego_798.png (stored 0%)
#   adding: content/Key_concat/clean_246.png (stored 0%)
#   adding: content/Key_concat/stego_499.png (stored 0%)
#   adding: content/Key_concat/clean_982.png (stored 0%)
#   adding: content/Key_concat/stego_1088.png (stored 0%)
#   adding: content/Key_concat/stego_1505.png (stored 0%)
#   adding: content/Key_concat/clean_615.png (stored 0%)
#   adding: content/Key_concat/clean_1441.png (stored 0%)
#   adding: content/Key_concat/clean_509.png (deflated 0%)
#   adding: content/Key_concat/stego_1863.png (stored 0%)
#   adding: content/Key_concat/clean_684.png (deflated 0%)
#   adding: content/Key_concat/stego_586.png (stored 0%)
#   adding: content/Key_concat/clean_1016.png (deflated 8%)
#   adding: content/Key_concat/clean_350.png (deflated 0%)
#   adding: content/Key_concat/stego_734.png (stored 0%)
#   adding: content/Key_concat/stego_2.png (stored 0%)
#   adding: content/Key_concat/stego_861.png (stored 0%)
#   adding: content/Key_concat/clean_896.png (stored 0%)
#   adding: content/Key_concat/stego_1816.png (stored 0%)
#   adding: content/Key_concat/stego_1157.png (stored 0%)
#   adding: content/Key_concat/stego_1371.png (stored 0%)
#   adding: content/Key_concat/stego_1812.png (stored 0%)
#   adding: content/Key_concat/stego_1269.png (stored 0%)
#   adding: content/Key_concat/stego_1973.png (stored 0%)
#   adding: content/Key_concat/clean_435.png (deflated 2%)
#   adding: content/Key_concat/clean_1242.png (stored 0%)
#   adding: content/Key_concat/stego_1070.png (stored 0%)
#   adding: content/Key_concat/stego_723.png (stored 0%)
#   adding: content/Key_concat/clean_820.png (deflated 1%)
#   adding: content/Key_concat/clean_1536.png (stored 0%)
#   adding: content/Key_concat/stego_1501.png (stored 0%)
#   adding: content/Key_concat/clean_468.png (stored 0%)
#   adding: content/Key_concat/clean_205.png (stored 0%)
#   adding: content/Key_concat/stego_1514.png (stored 0%)
#   adding: content/Key_concat/clean_340.png (deflated 1%)
#   adding: content/Key_concat/stego_1051.png (stored 0%)
#   adding: content/Key_concat/clean_986.png (deflated 1%)
#   adding: content/Key_concat/stego_692.png (stored 0%)
#   adding: content/Key_concat/stego_1061.png (stored 0%)
#   adding: content/Key_concat/stego_117.png (stored 0%)
#   adding: content/Key_concat/stego_1303.png (stored 0%)
#   adding: content/Key_concat/stego_747.png (stored 0%)
#   adding: content/Key_concat/clean_242.png (deflated 0%)
#   adding: content/Key_concat/stego_1293.png (stored 0%)
#   adding: content/Key_concat/clean_70.png (stored 0%)
#   adding: content/Key_concat/stego_428.png (stored 0%)
#   adding: content/Key_concat/stego_962.png (stored 0%)
#   adding: content/Key_concat/clean_1825.png (deflated 0%)
#   adding: content/Key_concat/stego_580.png (stored 0%)
#   adding: content/Key_concat/clean_308.png (deflated 1%)
#   adding: content/Key_concat/stego_286.png (stored 0%)
#   adding: content/Key_concat/clean_1202.png (stored 0%)
#   adding: content/Key_concat/stego_633.png (stored 0%)
#   adding: content/Key_concat/stego_1696.png (stored 0%)
#   adding: content/Key_concat/stego_1137.png (stored 0%)
#   adding: content/Key_concat/clean_947.png (stored 0%)
#   adding: content/Key_concat/stego_1605.png (stored 0%)
#   adding: content/Key_concat/clean_269.png (stored 0%)
#   adding: content/Key_concat/clean_167.png (deflated 0%)
#   adding: content/Key_concat/clean_1041.png (stored 0%)
#   adding: content/Key_concat/stego_1368.png (stored 0%)
#   adding: content/Key_concat/clean_945.png (deflated 0%)
#   adding: content/Key_concat/clean_1424.png (deflated 0%)
#   adding: content/Key_concat/clean_1281.png (stored 0%)
#   adding: content/Key_concat/stego_1699.png (stored 0%)
#   adding: content/Key_concat/stego_394.png (stored 0%)
#   adding: content/Key_concat/stego_299.png (stored 0%)
#   adding: content/Key_concat/stego_1814.png (stored 0%)
#   adding: content/Key_concat/clean_1793.png (stored 0%)
#   adding: content/Key_concat/clean_951.png (stored 0%)
#   adding: content/Key_concat/stego_262.png (stored 0%)
#   adding: content/Key_concat/stego_1931.png (stored 0%)
#   adding: content/Key_concat/stego_1518.png (stored 0%)
#   adding: content/Key_concat/stego_1988.png (stored 0%)
#   adding: content/Key_concat/clean_1672.png (stored 0%)
#   adding: content/Key_concat/stego_111.png (stored 0%)
#   adding: content/Key_concat/clean_789.png (stored 0%)
#   adding: content/Key_concat/stego_1082.png (stored 0%)
#   adding: content/Key_concat/stego_1955.png (stored 0%)
#   adding: content/Key_concat/stego_579.png (stored 0%)
#   adding: content/Key_concat/clean_1683.png (stored 0%)
#   adding: content/Key_concat/stego_215.png (stored 0%)
#   adding: content/Key_concat/clean_111.png (stored 0%)
#   adding: content/Key_concat/clean_1659.png (deflated 0%)
#   adding: content/Key_concat/stego_1618.png (stored 0%)
#   adding: content/Key_concat/clean_1378.png (stored 0%)
#   adding: content/Key_concat/stego_1256.png (stored 0%)
#   adding: content/Key_concat/clean_135.png (stored 0%)
#   adding: content/Key_concat/stego_1881.png (stored 0%)
#   adding: content/Key_concat/clean_236.png (deflated 0%)
#   adding: content/Key_concat/clean_1570.png (stored 0%)
#   adding: content/Key_concat/stego_1150.png (stored 0%)
#   adding: content/Key_concat/stego_1215.png (stored 0%)
#   adding: content/Key_concat/stego_1288.png (stored 0%)
#   adding: content/Key_concat/clean_607.png (stored 0%)
#   adding: content/Key_concat/stego_855.png (stored 0%)
#   adding: content/Key_concat/stego_972.png (stored 0%)
#   adding: content/Key_concat/clean_1927.png (stored 0%)
#   adding: content/Key_concat/stego_999.png (stored 0%)
#   adding: content/Key_concat/clean_1040.png (deflated 0%)
#   adding: content/Key_concat/stego_1377.png (stored 0%)
#   adding: content/Key_concat/clean_1067.png (stored 0%)
#   adding: content/Key_concat/stego_1562.png (stored 0%)
#   adding: content/Key_concat/stego_1948.png (stored 0%)
#   adding: content/Key_concat/clean_129.png (deflated 0%)
#   adding: content/Key_concat/stego_1291.png (stored 0%)
#   adding: content/Key_concat/clean_1612.png (stored 0%)
#   adding: content/Key_concat/clean_1947.png (deflated 0%)
#   adding: content/Key_concat/clean_1382.png (stored 0%)
#   adding: content/Key_concat/clean_1236.png (stored 0%)
#   adding: content/Key_concat/clean_1403.png (stored 0%)
#   adding: content/Key_concat/stego_121.png (stored 0%)
#   adding: content/Key_concat/stego_1458.png (stored 0%)
#   adding: content/Key_concat/clean_389.png (stored 0%)
#   adding: content/Key_concat/stego_1001.png (stored 0%)
#   adding: content/Key_concat/stego_1084.png (stored 0%)
#   adding: content/Key_concat/stego_1246.png (stored 0%)
#   adding: content/Key_concat/stego_97.png (stored 0%)
#   adding: content/Key_concat/clean_2000.png (deflated 1%)
#   adding: content/Key_concat/stego_1186.png (stored 0%)
#   adding: content/Key_concat/clean_392.png (stored 0%)
#   adding: content/Key_concat/clean_1454.png (stored 0%)
#   adding: content/Key_concat/clean_1107.png (stored 0%)
#   adding: content/Key_concat/stego_1969.png (stored 0%)
#   adding: content/Key_concat/clean_274.png (stored 0%)
#   adding: content/Key_concat/stego_1810.png (stored 0%)
#   adding: content/Key_concat/stego_1237.png (stored 0%)
#   adding: content/Key_concat/stego_180.png (stored 0%)
#   adding: content/Key_concat/stego_1407.png (stored 0%)
#   adding: content/Key_concat/clean_41.png (deflated 0%)
#   adding: content/Key_concat/stego_84.png (stored 0%)
#   adding: content/Key_concat/clean_1874.png (deflated 8%)
#   adding: content/Key_concat/stego_1572.png (stored 0%)
#   adding: content/Key_concat/clean_1597.png (deflated 0%)
#   adding: content/Key_concat/stego_350.png (stored 0%)
#   adding: content/Key_concat/clean_1959.png (stored 0%)
#   adding: content/Key_concat/stego_281.png (stored 0%)
#   adding: content/Key_concat/clean_436.png (deflated 0%)
#   adding: content/Key_concat/stego_1786.png (stored 0%)
#   adding: content/Key_concat/stego_979.png (stored 0%)
#   adding: content/Key_concat/stego_1091.png (stored 0%)
#   adding: content/Key_concat/stego_305.png (stored 0%)
#   adding: content/Key_concat/stego_514.png (stored 0%)
#   adding: content/Key_concat/stego_189.png (stored 0%)
#   adding: content/Key_concat/clean_706.png (stored 0%)
#   adding: content/Key_concat/stego_745.png (stored 0%)
#   adding: content/Key_concat/clean_592.png (deflated 0%)
#   adding: content/Key_concat/stego_831.png (stored 0%)
#   adding: content/Key_concat/stego_176.png (stored 0%)
#   adding: content/Key_concat/stego_889.png (stored 0%)
#   adding: content/Key_concat/stego_1172.png (stored 0%)
#   adding: content/Key_concat/stego_614.png (stored 0%)
#   adding: content/Key_concat/stego_67.png (stored 0%)
#   adding: content/Key_concat/clean_1160.png (stored 0%)
#   adding: content/Key_concat/stego_1472.png (stored 0%)
#   adding: content/Key_concat/stego_195.png (stored 0%)
#   adding: content/Key_concat/clean_550.png (deflated 0%)
#   adding: content/Key_concat/clean_1135.png (deflated 0%)
#   adding: content/Key_concat/stego_38.png (stored 0%)
#   adding: content/Key_concat/clean_651.png (deflated 0%)
#   adding: content/Key_concat/stego_1183.png (stored 0%)
#   adding: content/Key_concat/clean_967.png (stored 0%)
#   adding: content/Key_concat/clean_1845.png (stored 0%)
#   adding: content/Key_concat/stego_1532.png (stored 0%)
#   adding: content/Key_concat/clean_845.png (deflated 0%)
#   adding: content/Key_concat/stego_669.png (stored 0%)
#   adding: content/Key_concat/clean_499.png (stored 0%)
#   adding: content/Key_concat/stego_145.png (stored 0%)
#   adding: content/Key_concat/clean_757.png (deflated 1%)
#   adding: content/Key_concat/stego_1180.png (stored 0%)
#   adding: content/Key_concat/stego_1687.png (stored 0%)
#   adding: content/Key_concat/clean_671.png (stored 0%)
#   adding: content/Key_concat/clean_1626.png (stored 0%)
#   adding: content/Key_concat/stego_763.png (stored 0%)
#   adding: content/Key_concat/clean_601.png (stored 0%)
#   adding: content/Key_concat/clean_12.png (stored 0%)
#   adding: content/Key_concat/clean_1965.png (stored 0%)
#   adding: content/Key_concat/clean_553.png (stored 0%)
#   adding: content/Key_concat/clean_1341.png (stored 0%)
#   adding: content/Key_concat/clean_232.png (deflated 1%)
#   adding: content/Key_concat/stego_1772.png (stored 0%)
#   adding: content/Key_concat/stego_1836.png (stored 0%)
#   adding: content/Key_concat/clean_1815.png (stored 0%)
#   adding: content/Key_concat/stego_221.png (stored 0%)
#   adding: content/Key_concat/stego_1946.png (stored 0%)
#   adding: content/Key_concat/clean_1308.png (deflated 2%)
#   adding: content/Key_concat/stego_1860.png (stored 0%)
#   adding: content/Key_concat/clean_1784.png (deflated 0%)
#   adding: content/Key_concat/clean_847.png (deflated 1%)
#   adding: content/Key_concat/clean_935.png (stored 0%)
#   adding: content/Key_concat/stego_1691.png (stored 0%)
#   adding: content/Key_concat/clean_912.png (stored 0%)
#   adding: content/Key_concat/clean_121.png (deflated 0%)
#   adding: content/Key_concat/clean_200.png (stored 0%)
#   adding: content/Key_concat/clean_515.png (stored 0%)
#   adding: content/Key_concat/stego_1389.png (stored 0%)
#   adding: content/Key_concat/clean_1515.png (deflated 0%)
#   adding: content/Key_concat/stego_219.png (stored 0%)
#   adding: content/Key_concat/clean_266.png (stored 0%)
#   adding: content/Key_concat/stego_1999.png (stored 0%)
#   adding: content/Key_concat/stego_1227.png (stored 0%)
#   adding: content/Key_concat/stego_44.png (stored 0%)
#   adding: content/Key_concat/clean_82.png (deflated 2%)
#   adding: content/Key_concat/clean_818.png (deflated 0%)
#   adding: content/Key_concat/stego_870.png (stored 0%)
#   adding: content/Key_concat/stego_943.png (stored 0%)
#   adding: content/Key_concat/clean_996.png (stored 0%)
#   adding: content/Key_concat/clean_1293.png (deflated 0%)
#   adding: content/Key_concat/stego_270.png (stored 0%)
#   adding: content/Key_concat/clean_1164.png (stored 0%)
#   adding: content/Key_concat/clean_1284.png (deflated 1%)
#   adding: content/Key_concat/stego_1898.png (stored 0%)
#   adding: content/Key_concat/clean_860.png (stored 0%)
#   adding: content/Key_concat/stego_1182.png (stored 0%)
#   adding: content/Key_concat/clean_733.png (stored 0%)
#   adding: content/Key_concat/stego_1059.png (stored 0%)
#   adding: content/Key_concat/stego_1841.png (stored 0%)
#   adding: content/Key_concat/clean_219.png (stored 0%)
#   adding: content/Key_concat/clean_418.png (deflated 1%)
#   adding: content/Key_concat/clean_1740.png (deflated 0%)
#   adding: content/Key_concat/clean_369.png (stored 0%)
#   adding: content/Key_concat/clean_1264.png (deflated 0%)
#   adding: content/Key_concat/stego_404.png (stored 0%)
#   adding: content/Key_concat/stego_384.png (stored 0%)
#   adding: content/Key_concat/stego_1520.png (stored 0%)
#   adding: content/Key_concat/stego_671.png (stored 0%)
#   adding: content/Key_concat/clean_164.png (stored 0%)
#   adding: content/Key_concat/stego_568.png (stored 0%)
#   adding: content/Key_concat/stego_726.png (stored 0%)
#   adding: content/Key_concat/clean_1001.png (stored 0%)
#   adding: content/Key_concat/stego_1224.png (stored 0%)
#   adding: content/Key_concat/stego_1124.png (stored 0%)
#   adding: content/Key_concat/stego_849.png (stored 0%)
#   adding: content/Key_concat/clean_1103.png (deflated 0%)
#   adding: content/Key_concat/clean_69.png (stored 0%)
#   adding: content/Key_concat/clean_939.png (deflated 1%)
#   adding: content/Key_concat/clean_1063.png (deflated 1%)
#   adding: content/Key_concat/clean_1750.png (deflated 0%)
#   adding: content/Key_concat/stego_341.png (stored 0%)
#   adding: content/Key_concat/stego_272.png (stored 0%)
#   adding: content/Key_concat/clean_669.png (deflated 0%)
#   adding: content/Key_concat/clean_1852.png (stored 0%)
#   adding: content/Key_concat/stego_915.png (stored 0%)
#   adding: content/Key_concat/clean_978.png (stored 0%)
#   adding: content/Key_concat/stego_1170.png (stored 0%)
#   adding: content/Key_concat/clean_1718.png (stored 0%)
#   adding: content/Key_concat/stego_1414.png (stored 0%)
#   adding: content/Key_concat/clean_299.png (stored 0%)
#   adding: content/Key_concat/clean_1438.png (stored 0%)
#   adding: content/Key_concat/stego_1425.png (stored 0%)
#   adding: content/Key_concat/clean_530.png (stored 0%)
#   adding: content/Key_concat/clean_1323.png (stored 0%)
#   adding: content/Key_concat/clean_1858.png (stored 0%)
#   adding: content/Key_concat/stego_330.png (stored 0%)
#   adding: content/Key_concat/stego_879.png (stored 0%)
#   adding: content/Key_concat/stego_239.png (stored 0%)
#   adding: content/Key_concat/stego_1191.png (stored 0%)
#   adding: content/Key_concat/clean_888.png (stored 0%)
#   adding: content/Key_concat/stego_1019.png (stored 0%)
#   adding: content/Key_concat/stego_985.png (stored 0%)
#   adding: content/Key_concat/clean_804.png (stored 0%)
#   adding: content/Key_concat/stego_1895.png (stored 0%)
#   adding: content/Key_concat/clean_74.png (stored 0%)
#   adding: content/Key_concat/clean_966.png (deflated 0%)
#   adding: content/Key_concat/stego_1127.png (stored 0%)
#   adding: content/Key_concat/clean_626.png (deflated 0%)
#   adding: content/Key_concat/stego_10.png (stored 0%)
#   adding: content/Key_concat/clean_1188.png (stored 0%)
#   adding: content/Key_concat/clean_1310.png (stored 0%)
#   adding: content/Key_concat/stego_1141.png (stored 0%)
#   adding: content/Key_concat/stego_1324.png (stored 0%)
#   adding: content/Key_concat/clean_386.png (stored 0%)
#   adding: content/Key_concat/stego_371.png (stored 0%)
#   adding: content/Key_concat/stego_427.png (stored 0%)
#   adding: content/Key_concat/clean_638.png (stored 0%)
#   adding: content/Key_concat/clean_479.png (stored 0%)
#   adding: content/Key_concat/stego_1383.png (stored 0%)
#   adding: content/Key_concat/clean_1757.png (stored 0%)
#   adding: content/Key_concat/clean_523.png (deflated 0%)
#   adding: content/Key_concat/stego_553.png (stored 0%)
#   adding: content/Key_concat/clean_3.png (stored 0%)
#   adding: content/Key_concat/stego_1721.png (stored 0%)
#   adding: content/Key_concat/clean_1789.png (deflated 1%)
#   adding: content/Key_concat/clean_943.png (stored 0%)
#   adding: content/Key_concat/stego_1451.png (stored 0%)
#   adding: content/Key_concat/clean_475.png (deflated 2%)
#   adding: content/Key_concat/clean_1457.png (deflated 1%)
#   adding: content/Key_concat/clean_1132.png (stored 0%)
#   adding: content/Key_concat/stego_1851.png (stored 0%)
#   adding: content/Key_concat/stego_163.png (stored 0%)
#   adding: content/Key_concat/stego_107.png (stored 0%)
#   adding: content/Key_concat/clean_886.png (stored 0%)
#   adding: content/Key_concat/clean_1913.png (deflated 0%)
#   adding: content/Key_concat/stego_1164.png (stored 0%)
#   adding: content/Key_concat/clean_787.png (stored 0%)
#   adding: content/Key_concat/stego_1495.png (stored 0%)
#   adding: content/Key_concat/clean_1811.png (stored 0%)
#   adding: content/Key_concat/clean_1893.png (stored 0%)
#   adding: content/Key_concat/stego_1971.png (stored 0%)
#   adding: content/Key_concat/stego_1616.png (stored 0%)
#   adding: content/Key_concat/stego_458.png (stored 0%)
#   adding: content/Key_concat/clean_506.png (stored 0%)
#   adding: content/Key_concat/stego_347.png (stored 0%)
#   adding: content/Key_concat/stego_1147.png (stored 0%)
#   adding: content/Key_concat/clean_391.png (stored 0%)
#   adding: content/Key_concat/clean_800.png (stored 0%)
#   adding: content/Key_concat/stego_1042.png (stored 0%)
#   adding: content/Key_concat/stego_468.png (stored 0%)
#   adding: content/Key_concat/stego_208.png (stored 0%)
#   adding: content/Key_concat/stego_1596.png (stored 0%)
#   adding: content/Key_concat/clean_1862.png (stored 0%)
#   adding: content/Key_concat/stego_412.png (stored 0%)
#   adding: content/Key_concat/stego_1899.png (stored 0%)
#   adding: content/Key_concat/clean_31.png (stored 0%)
#   adding: content/Key_concat/stego_70.png (stored 0%)
#   adding: content/Key_concat/clean_1705.png (deflated 0%)
#   adding: content/Key_concat/clean_946.png (stored 0%)
#   adding: content/Key_concat/stego_1873.png (stored 0%)
#   adding: content/Key_concat/stego_1201.png (stored 0%)
#   adding: content/Key_concat/clean_1697.png (stored 0%)
#   adding: content/Key_concat/stego_1128.png (stored 0%)
#   adding: content/Key_concat/clean_247.png (deflated 1%)
#   adding: content/Key_concat/stego_110.png (stored 0%)
#   adding: content/Key_concat/stego_33.png (stored 0%)
#   adding: content/Key_concat/stego_1566.png (stored 0%)
#   adding: content/Key_concat/stego_465.png (stored 0%)
#   adding: content/Key_concat/stego_921.png (stored 0%)
#   adding: content/Key_concat/clean_141.png (stored 0%)
#   adding: content/Key_concat/stego_1355.png (stored 0%)
#   adding: content/Key_concat/stego_124.png (stored 0%)
#   adding: content/Key_concat/clean_437.png (stored 0%)
#   adding: content/Key_concat/stego_856.png (stored 0%)
#   adding: content/Key_concat/stego_1595.png (stored 0%)
#   adding: content/Key_concat/stego_1720.png (stored 0%)
#   adding: content/Key_concat/clean_989.png (stored 0%)
#   adding: content/Key_concat/stego_1594.png (stored 0%)
#   adding: content/Key_concat/clean_1498.png (stored 0%)
#   adding: content/Key_concat/clean_1256.png (stored 0%)
#   adding: content/Key_concat/stego_809.png (stored 0%)
#   adding: content/Key_concat/clean_245.png (deflated 0%)
#   adding: content/Key_concat/clean_1708.png (stored 0%)
#   adding: content/Key_concat/stego_1623.png (stored 0%)
#   adding: content/Key_concat/stego_593.png (stored 0%)
#   adding: content/Key_concat/clean_1888.png (stored 0%)
#   adding: content/Key_concat/clean_240.png (stored 0%)
#   adding: content/Key_concat/clean_178.png (deflated 6%)
#   adding: content/Key_concat/stego_1297.png (stored 0%)
#   adding: content/Key_concat/stego_147.png (stored 0%)
#   adding: content/Key_concat/clean_1624.png (deflated 1%)
#   adding: content/Key_concat/stego_249.png (stored 0%)
#   adding: content/Key_concat/clean_234.png (stored 0%)
#   adding: content/Key_concat/stego_815.png (stored 0%)
#   adding: content/Key_concat/stego_802.png (stored 0%)
#   adding: content/Key_concat/clean_762.png (stored 0%)
#   adding: content/Key_concat/clean_923.png (stored 0%)
#   adding: content/Key_concat/stego_37.png (stored 0%)
#   adding: content/Key_concat/stego_337.png (stored 0%)
#   adding: content/Key_concat/clean_1169.png (stored 0%)
#   adding: content/Key_concat/stego_30.png (stored 0%)
#   adding: content/Key_concat/stego_992.png (stored 0%)
#   adding: content/Key_concat/stego_1404.png (stored 0%)
#   adding: content/Key_concat/stego_1354.png (stored 0%)
#   adding: content/Key_concat/clean_1525.png (stored 0%)
#   adding: content/Key_concat/stego_9.png (stored 0%)
#   adding: content/Key_concat/stego_541.png (stored 0%)
#   adding: content/Key_concat/stego_1979.png (stored 0%)
#   adding: content/Key_concat/clean_1669.png (stored 0%)
#   adding: content/Key_concat/clean_766.png (stored 0%)
#   adding: content/Key_concat/clean_271.png (deflated 0%)
#   adding: content/Key_concat/stego_253.png (stored 0%)
#   adding: content/Key_concat/clean_854.png (stored 0%)
#   adding: content/Key_concat/stego_1838.png (stored 0%)
#   adding: content/Key_concat/stego_1230.png (stored 0%)
#   adding: content/Key_concat/clean_1278.png (stored 0%)
#   adding: content/Key_concat/clean_961.png (deflated 0%)
#   adding: content/Key_concat/stego_844.png (stored 0%)
#   adding: content/Key_concat/stego_463.png (stored 0%)
#   adding: content/Key_concat/stego_1014.png (stored 0%)
#   adding: content/Key_concat/stego_631.png (stored 0%)
#   adding: content/Key_concat/clean_992.png (stored 0%)
#   adding: content/Key_concat/stego_1292.png (stored 0%)
#   adding: content/Key_concat/clean_1762.png (stored 0%)
#   adding: content/Key_concat/clean_1232.png (stored 0%)
#   adding: content/Key_concat/clean_635.png (deflated 1%)
#   adding: content/Key_concat/stego_529.png (stored 0%)
#   adding: content/Key_concat/clean_1981.png (stored 0%)
#   adding: content/Key_concat/clean_563.png (deflated 0%)
#   adding: content/Key_concat/stego_304.png (stored 0%)
#   adding: content/Key_concat/clean_406.png (stored 0%)
#   adding: content/Key_concat/stego_420.png (stored 0%)
#   adding: content/Key_concat/stego_160.png (stored 0%)
#   adding: content/Key_concat/clean_1108.png (deflated 0%)
#   adding: content/Key_concat/clean_1909.png (stored 0%)
#   adding: content/Key_concat/stego_1640.png (stored 0%)
#   adding: content/Key_concat/stego_662.png (stored 0%)
#   adding: content/Key_concat/clean_387.png (stored 0%)
#   adding: content/Key_concat/clean_1665.png (stored 0%)
#   adding: content/Key_concat/clean_1743.png (stored 0%)
#   adding: content/Key_concat/stego_1453.png (stored 0%)
#   adding: content/Key_concat/clean_1260.png (stored 0%)
#   adding: content/Key_concat/stego_1417.png (stored 0%)
#   adding: content/Key_concat/stego_743.png (stored 0%)
#   adding: content/Key_concat/stego_1742.png (stored 0%)
#   adding: content/Key_concat/stego_415.png (stored 0%)
#   adding: content/Key_concat/clean_400.png (deflated 0%)
#   adding: content/Key_concat/stego_388.png (stored 0%)
#   adding: content/Key_concat/stego_598.png (stored 0%)
#   adding: content/Key_concat/clean_1849.png (deflated 1%)
#   adding: content/Key_concat/clean_1696.png (deflated 0%)
#   adding: content/Key_concat/stego_1521.png (stored 0%)
#   adding: content/Key_concat/stego_387.png (stored 0%)
#   adding: content/Key_concat/stego_1231.png (stored 0%)
#   adding: content/Key_concat/stego_1139.png (stored 0%)
#   adding: content/Key_concat/stego_488.png (stored 0%)
#   adding: content/Key_concat/stego_876.png (stored 0%)
#   adding: content/Key_concat/clean_541.png (deflated 0%)
#   adding: content/Key_concat/clean_1152.png (stored 0%)
#   adding: content/Key_concat/clean_723.png (stored 0%)
#   adding: content/Key_concat/stego_1546.png (stored 0%)
#   adding: content/Key_concat/stego_601.png (stored 0%)
#   adding: content/Key_concat/stego_1266.png (stored 0%)
#   adding: content/Key_concat/stego_1848.png (stored 0%)
#   adding: content/Key_concat/clean_612.png (deflated 1%)
#   adding: content/Key_concat/stego_1499.png (stored 0%)
#   adding: content/Key_concat/clean_1364.png (deflated 1%)
#   adding: content/Key_concat/stego_750.png (stored 0%)
#   adding: content/Key_concat/clean_858.png (stored 0%)
#   adding: content/Key_concat/stego_1719.png (stored 0%)
#   adding: content/Key_concat/stego_751.png (stored 0%)
#   adding: content/Key_concat/clean_1072.png (stored 0%)
#   adding: content/Key_concat/stego_418.png (stored 0%)
#   adding: content/Key_concat/stego_1358.png (stored 0%)
#   adding: content/Key_concat/clean_352.png (deflated 1%)
#   adding: content/Key_concat/clean_1625.png (stored 0%)
#   adding: content/Key_concat/clean_1642.png (deflated 2%)
#   adding: content/Key_concat/stego_119.png (stored 0%)
#   adding: content/Key_concat/stego_1608.png (stored 0%)
#   adding: content/Key_concat/stego_561.png (stored 0%)
#   adding: content/Key_concat/stego_1706.png (stored 0%)
#   adding: content/Key_concat/stego_1934.png (stored 0%)
#   adding: content/Key_concat/stego_1214.png (stored 0%)
#   adding: content/Key_concat/stego_585.png (stored 0%)
#   adding: content/Key_concat/clean_1045.png (deflated 0%)
#   adding: content/Key_concat/clean_1176.png (stored 0%)
#   adding: content/Key_concat/stego_892.png (stored 0%)
#   adding: content/Key_concat/clean_110.png (stored 0%)
#   adding: content/Key_concat/clean_755.png (deflated 1%)
#   adding: content/Key_concat/stego_1281.png (stored 0%)
#   adding: content/Key_concat/stego_1469.png (stored 0%)
#   adding: content/Key_concat/stego_231.png (stored 0%)
#   adding: content/Key_concat/stego_438.png (stored 0%)
#   adding: content/Key_concat/clean_1591.png (stored 0%)
#   adding: content/Key_concat/clean_1213.png (stored 0%)
#   adding: content/Key_concat/stego_533.png (stored 0%)
#   adding: content/Key_concat/clean_1138.png (deflated 0%)
#   adding: content/Key_concat/clean_235.png (deflated 1%)
#   adding: content/Key_concat/clean_1189.png (stored 0%)
#   adding: content/Key_concat/stego_871.png (stored 0%)
#   adding: content/Key_concat/clean_364.png (deflated 1%)
#   adding: content/Key_concat/clean_584.png (deflated 2%)
#   adding: content/Key_concat/stego_1978.png (stored 0%)
#   adding: content/Key_concat/stego_413.png (stored 0%)
#   adding: content/Key_concat/stego_1712.png (stored 0%)
#   adding: content/Key_concat/clean_1455.png (deflated 2%)
#   adding: content/Key_concat/stego_1259.png (stored 0%)
#   adding: content/Key_concat/stego_131.png (stored 0%)
#   adding: content/Key_concat/stego_432.png (stored 0%)
#   adding: content/Key_concat/stego_1963.png (stored 0%)
#   adding: content/Key_concat/stego_796.png (stored 0%)
#   adding: content/Key_concat/clean_316.png (deflated 0%)
#   adding: content/Key_concat/stego_1390.png (stored 0%)
#   adding: content/Key_concat/stego_519.png (stored 0%)
#   adding: content/Key_concat/clean_1930.png (stored 0%)
#   adding: content/Key_concat/clean_540.png (stored 0%)
#   adding: content/Key_concat/stego_213.png (stored 0%)
#   adding: content/Key_concat/stego_83.png (stored 0%)
#   adding: content/Key_concat/stego_1678.png (stored 0%)
#   adding: content/Key_concat/stego_618.png (stored 0%)
#   adding: content/Key_concat/clean_1813.png (stored 0%)
#   adding: content/Key_concat/clean_1305.png (stored 0%)
#   adding: content/Key_concat/clean_372.png (stored 0%)
#   adding: content/Key_concat/stego_1219.png (stored 0%)
#   adding: content/Key_concat/stego_1754.png (stored 0%)
#   adding: content/Key_concat/clean_89.png (deflated 0%)
#   adding: content/Key_concat/clean_1629.png (stored 0%)
#   adding: content/Key_concat/stego_1247.png (stored 0%)
#   adding: content/Key_concat/stego_1541.png (stored 0%)
#   adding: content/Key_concat/stego_1787.png (stored 0%)
#   adding: content/Key_concat/clean_1447.png (stored 0%)
#   adding: content/Key_concat/stego_142.png (stored 0%)
#   adding: content/Key_concat/stego_1342.png (stored 0%)
#   adding: content/Key_concat/stego_1582.png (stored 0%)
#   adding: content/Key_concat/clean_309.png (deflated 1%)
#   adding: content/Key_concat/stego_1228.png (stored 0%)
#   adding: content/Key_concat/stego_1331.png (stored 0%)
#   adding: content/Key_concat/stego_1636.png (stored 0%)
#   adding: content/Key_concat/stego_197.png (stored 0%)
#   adding: content/Key_concat/stego_284.png (stored 0%)
#   adding: content/Key_concat/stego_1722.png (stored 0%)
#   adding: content/Key_concat/clean_123.png (stored 0%)
#   adding: content/Key_concat/clean_805.png (stored 0%)
#   adding: content/Key_concat/clean_277.png (stored 0%)
#   adding: content/Key_concat/clean_323.png (stored 0%)
#   adding: content/Key_concat/clean_763.png (stored 0%)
#   adding: content/Key_concat/stego_451.png (stored 0%)
#   adding: content/Key_concat/clean_1481.png (deflated 0%)
#   adding: content/Key_concat/stego_1780.png (stored 0%)
#   adding: content/Key_concat/stego_783.png (stored 0%)
#   adding: content/Key_concat/clean_1007.png (stored 0%)
#   adding: content/Key_concat/clean_1054.png (stored 0%)
#   adding: content/Key_concat/clean_802.png (stored 0%)
#   adding: content/Key_concat/stego_1538.png (stored 0%)
#   adding: content/Key_concat/stego_1344.png (stored 0%)
#   adding: content/Key_concat/stego_1450.png (stored 0%)
#   adding: content/Key_concat/stego_863.png (stored 0%)
#   adding: content/Key_concat/clean_527.png (deflated 0%)
#   adding: content/Key_concat/stego_656.png (stored 0%)
#   adding: content/Key_concat/clean_1000.png (stored 0%)
#   adding: content/Key_concat/stego_274.png (stored 0%)
#   adding: content/Key_concat/stego_293.png (stored 0%)
#   adding: content/Key_concat/clean_742.png (stored 0%)
#   adding: content/Key_concat/stego_104.png (stored 0%)
#   adding: content/Key_concat/stego_444.png (stored 0%)
#   adding: content/Key_concat/stego_167.png (stored 0%)
#   adding: content/Key_concat/clean_905.png (deflated 0%)
#   adding: content/Key_concat/clean_639.png (stored 0%)
#   adding: content/Key_concat/stego_730.png (stored 0%)
#   adding: content/Key_concat/clean_1227.png (stored 0%)
#   adding: content/Key_concat/clean_248.png (deflated 1%)
#   adding: content/Key_concat/clean_1201.png (deflated 1%)
#   adding: content/Key_concat/stego_359.png (stored 0%)
#   adding: content/Key_concat/stego_285.png (stored 0%)
#   adding: content/Key_concat/stego_1023.png (stored 0%)
#   adding: content/Key_concat/clean_831.png (deflated 0%)
#   adding: content/Key_concat/clean_725.png (stored 0%)
#   adding: content/Key_concat/clean_1295.png (deflated 1%)
#   adding: content/Key_concat/stego_1364.png (stored 0%)
#   adding: content/Key_concat/clean_22.png (stored 0%)
#   adding: content/Key_concat/clean_431.png (stored 0%)
#   adding: content/Key_concat/stego_1054.png (stored 0%)
#   adding: content/Key_concat/clean_231.png (deflated 0%)
#   adding: content/Key_concat/clean_1387.png (stored 0%)
#   adding: content/Key_concat/stego_1441.png (stored 0%)
#   adding: content/Key_concat/clean_1934.png (deflated 0%)
#   adding: content/Key_concat/stego_958.png (stored 0%)
#   adding: content/Key_concat/clean_868.png (stored 0%)
#   adding: content/Key_concat/stego_419.png (stored 0%)
#   adding: content/Key_concat/clean_953.png (stored 0%)
#   adding: content/Key_concat/stego_530.png (stored 0%)
#   adding: content/Key_concat/stego_771.png (stored 0%)
#   adding: content/Key_concat/clean_1783.png (stored 0%)
#   adding: content/Key_concat/clean_1538.png (deflated 0%)
#   adding: content/Key_concat/stego_1805.png (stored 0%)
#   adding: content/Key_concat/clean_1020.png (stored 0%)
#   adding: content/Key_concat/clean_1546.png (deflated 1%)
#   adding: content/Key_concat/stego_764.png (stored 0%)
#   adding: content/Key_concat/stego_397.png (stored 0%)
#   adding: content/Key_concat/clean_1553.png (stored 0%)
#   adding: content/Key_concat/stego_170.png (stored 0%)
#   adding: content/Key_concat/clean_1644.png (stored 0%)
#   adding: content/Key_concat/clean_1230.png (stored 0%)
#   adding: content/Key_concat/stego_157.png (stored 0%)
#   adding: content/Key_concat/clean_1102.png (stored 0%)
#   adding: content/Key_concat/clean_1104.png (stored 0%)
#   adding: content/Key_concat/stego_1791.png (stored 0%)
#   adding: content/Key_concat/clean_679.png (deflated 0%)
#   adding: content/Key_concat/stego_1045.png (stored 0%)
#   adding: content/Key_concat/stego_179.png (stored 0%)
#   adding: content/Key_concat/clean_101.png (stored 0%)
#   adding: content/Key_concat/clean_1925.png (deflated 0%)
#   adding: content/Key_concat/clean_1204.png (stored 0%)
#   adding: content/Key_concat/clean_949.png (deflated 0%)
#   adding: content/Key_concat/clean_1386.png (deflated 1%)
#   adding: content/Key_concat/stego_1778.png (stored 0%)
#   adding: content/Key_concat/clean_1345.png (stored 0%)
#   adding: content/Key_concat/clean_1037.png (stored 0%)
#   adding: content/Key_concat/clean_547.png (deflated 0%)
#   adding: content/Key_concat/clean_1892.png (stored 0%)
#   adding: content/Key_concat/clean_458.png (stored 0%)
#   adding: content/Key_concat/clean_1321.png (stored 0%)
#   adding: content/Key_concat/clean_710.png (stored 0%)
#   adding: content/Key_concat/clean_1167.png (stored 0%)
#   adding: content/Key_concat/clean_785.png (stored 0%)
#   adding: content/Key_concat/clean_1822.png (stored 0%)
#   adding: content/Key_concat/stego_489.png (stored 0%)
#   adding: content/Key_concat/clean_942.png (stored 0%)
#   adding: content/Key_concat/clean_873.png (stored 0%)
#   adding: content/Key_concat/clean_846.png (stored 0%)
#   adding: content/Key_concat/clean_151.png (deflated 0%)
#   adding: content/Key_concat/clean_1914.png (deflated 1%)
#   adding: content/Key_concat/clean_1799.png (deflated 2%)
#   adding: content/Key_concat/clean_1729.png (stored 0%)
#   adding: content/Key_concat/stego_1258.png (stored 0%)
#   adding: content/Key_concat/clean_1449.png (deflated 0%)
#   adding: content/Key_concat/clean_76.png (stored 0%)
#   adding: content/Key_concat/clean_261.png (deflated 0%)
#   adding: content/Key_concat/clean_1800.png (deflated 2%)
#   adding: content/Key_concat/clean_1855.png (stored 0%)
#   adding: content/Key_concat/stego_1202.png (stored 0%)
#   adding: content/Key_concat/stego_166.png (stored 0%)
#   adding: content/Key_concat/clean_1991.png (deflated 0%)
#   adding: content/Key_concat/stego_1741.png (stored 0%)
#   adding: content/Key_concat/stego_819.png (stored 0%)
#   adding: content/Key_concat/stego_1627.png (stored 0%)
#   adding: content/Key_concat/clean_1144.png (deflated 0%)
#   adding: content/Key_concat/clean_1503.png (deflated 0%)
#   adding: content/Key_concat/clean_1641.png (deflated 0%)
#   adding: content/Key_concat/stego_411.png (stored 0%)
#   adding: content/Key_concat/clean_1788.png (stored 0%)
#   adding: content/Key_concat/stego_1216.png (stored 0%)
#   adding: content/Key_concat/clean_1185.png (stored 0%)
#   adding: content/Key_concat/clean_1021.png (stored 0%)
#   adding: content/Key_concat/stego_1120.png (stored 0%)
#   adding: content/Key_concat/stego_317.png (stored 0%)
#   adding: content/Key_concat/stego_1974.png (stored 0%)
#   adding: content/Key_concat/stego_1203.png (stored 0%)
#   adding: content/Key_concat/stego_1300.png (stored 0%)
#   adding: content/Key_concat/stego_1671.png (stored 0%)
#   adding: content/Key_concat/clean_1875.png (deflated 1%)
#   adding: content/Key_concat/stego_1683.png (stored 0%)
#   adding: content/Key_concat/stego_1476.png (stored 0%)
#   adding: content/Key_concat/clean_4.png (stored 0%)
#   adding: content/Key_concat/clean_1532.png (deflated 0%)
#   adding: content/Key_concat/stego_1526.png (stored 0%)
#   adding: content/Key_concat/stego_333.png (stored 0%)
#   adding: content/Key_concat/clean_403.png (stored 0%)
#   adding: content/Key_concat/stego_1792.png (stored 0%)
#   adding: content/Key_concat/stego_1855.png (stored 0%)
#   adding: content/Key_concat/clean_208.png (deflated 1%)
#   adding: content/Key_concat/clean_1008.png (stored 0%)
#   adding: content/Key_concat/clean_398.png (deflated 3%)
#   adding: content/Key_concat/clean_1420.png (stored 0%)
#   adding: content/Key_concat/stego_1154.png (stored 0%)
#   adding: content/Key_concat/clean_1391.png (stored 0%)
#   adding: content/Key_concat/stego_354.png (stored 0%)
#   adding: content/Key_concat/stego_1593.png (stored 0%)
#   adding: content/Key_concat/clean_1580.png (deflated 1%)
#   adding: content/Key_concat/clean_137.png (stored 0%)
#   adding: content/Key_concat/clean_476.png (deflated 0%)
#   adding: content/Key_concat/clean_1206.png (deflated 2%)
#   adding: content/Key_concat/clean_346.png (stored 0%)
#   adding: content/Key_concat/stego_1771.png (stored 0%)
#   adding: content/Key_concat/clean_1867.png (deflated 2%)
#   adding: content/Key_concat/clean_25.png (stored 0%)
#   adding: content/Key_concat/clean_160.png (deflated 0%)
#   adding: content/Key_concat/stego_1020.png (stored 0%)
#   adding: content/Key_concat/clean_1734.png (stored 0%)
#   adding: content/Key_concat/clean_1015.png (stored 0%)
#   adding: content/Key_concat/stego_251.png (stored 0%)
#   adding: content/Key_concat/stego_28.png (stored 0%)
#   adding: content/Key_concat/stego_188.png (stored 0%)
#   adding: content/Key_concat/stego_1408.png (stored 0%)
#   adding: content/Key_concat/clean_282.png (stored 0%)
#   adding: content/Key_concat/stego_295.png (stored 0%)
#   adding: content/Key_concat/clean_1880.png (stored 0%)
#   adding: content/Key_concat/stego_1740.png (stored 0%)
#   adding: content/Key_concat/stego_1262.png (stored 0%)
#   adding: content/Key_concat/stego_1271.png (stored 0%)
#   adding: content/Key_concat/clean_1405.png (stored 0%)
#   adding: content/Key_concat/clean_1545.png (stored 0%)
#   adding: content/Key_concat/stego_1479.png (stored 0%)
#   adding: content/Key_concat/clean_594.png (deflated 0%)
#   adding: content/Key_concat/clean_381.png (deflated 0%)
#   adding: content/Key_concat/clean_803.png (stored 0%)
#   adding: content/Key_concat/clean_1061.png (deflated 2%)
#   adding: content/Key_concat/stego_1332.png (stored 0%)
#   adding: content/Key_concat/stego_555.png (stored 0%)
#   adding: content/Key_concat/clean_683.png (deflated 0%)
#   adding: content/Key_concat/stego_1995.png (stored 0%)
#   adding: content/Key_concat/clean_150.png (stored 0%)
#   adding: content/Key_concat/stego_478.png (stored 0%)
#   adding: content/Key_concat/stego_807.png (stored 0%)
#   adding: content/Key_concat/clean_928.png (deflated 1%)
#   adding: content/Key_concat/clean_1183.png (stored 0%)
#   adding: content/Key_concat/stego_1549.png (stored 0%)
#   adding: content/Key_concat/stego_997.png (stored 0%)
#   adding: content/Key_concat/clean_1724.png (stored 0%)
#   adding: content/Key_concat/clean_60.png (stored 0%)
#   adding: content/Key_concat/clean_154.png (stored 0%)
#   adding: content/Key_concat/stego_46.png (stored 0%)
#   adding: content/Key_concat/stego_953.png (stored 0%)
#   adding: content/Key_concat/clean_456.png (deflated 0%)
#   adding: content/Key_concat/clean_1902.png (stored 0%)
#   adding: content/Key_concat/stego_63.png (stored 0%)
#   adding: content/Key_concat/clean_1835.png (stored 0%)
#   adding: content/Key_concat/clean_1333.png (stored 0%)
#   adding: content/Key_concat/clean_833.png (stored 0%)
#   adding: content/Key_concat/clean_1904.png (deflated 0%)
#   adding: content/Key_concat/stego_883.png (stored 0%)
#   adding: content/Key_concat/clean_1399.png (deflated 1%)
#   adding: content/Key_concat/clean_162.png (stored 0%)
#   adding: content/Key_concat/clean_919.png (stored 0%)
#   adding: content/Key_concat/stego_563.png (stored 0%)
#   adding: content/Key_concat/clean_1154.png (deflated 0%)
#   adding: content/Key_concat/stego_731.png (stored 0%)
#   adding: content/Key_concat/clean_181.png (stored 0%)
#   adding: content/Key_concat/stego_1782.png (stored 0%)
#   adding: content/Key_concat/stego_443.png (stored 0%)
#   adding: content/Key_concat/clean_1198.png (stored 0%)
#   adding: content/Key_concat/clean_556.png (stored 0%)
#   adding: content/Key_concat/clean_1479.png (deflated 0%)
#   adding: content/Key_concat/stego_18.png (stored 0%)
#   adding: content/Key_concat/stego_55.png (stored 0%)
#   adding: content/Key_concat/stego_254.png (stored 0%)
#   adding: content/Key_concat/clean_344.png (stored 0%)
#   adding: content/Key_concat/clean_1876.png (stored 0%)
#   adding: content/Key_concat/stego_306.png (stored 0%)
#   adding: content/Key_concat/stego_581.png (stored 0%)
#   adding: content/Key_concat/stego_1888.png (stored 0%)
#   adding: content/Key_concat/stego_784.png (stored 0%)
#   adding: content/Key_concat/stego_439.png (stored 0%)
#   adding: content/Key_concat/clean_1255.png (stored 0%)
#   adding: content/Key_concat/stego_621.png (stored 0%)
#   adding: content/Key_concat/clean_1.png (deflated 0%)
#   adding: content/Key_concat/stego_182.png (stored 0%)
#   adding: content/Key_concat/clean_1496.png (stored 0%)
#   adding: content/Key_concat/clean_539.png (deflated 2%)
#   adding: content/Key_concat/stego_1027.png (stored 0%)
#   adding: content/Key_concat/clean_1967.png (deflated 0%)
#   adding: content/Key_concat/stego_326.png (stored 0%)
#   adding: content/Key_concat/stego_1317.png (stored 0%)
#   adding: content/Key_concat/clean_73.png (deflated 1%)
#   adding: content/Key_concat/stego_830.png (stored 0%)
#   adding: content/Key_concat/stego_1193.png (stored 0%)
#   adding: content/Key_concat/stego_1982.png (stored 0%)
#   adding: content/Key_concat/clean_780.png (stored 0%)
#   adding: content/Key_concat/stego_1105.png (stored 0%)
#   adding: content/Key_concat/clean_1302.png (stored 0%)
#   adding: content/Key_concat/stego_1766.png (stored 0%)
#   adding: content/Key_concat/clean_1217.png (stored 0%)
#   adding: content/Key_concat/clean_107.png (deflated 0%)
# ...
#   adding: content/Key_concat/clean_549.png (deflated 0%)
#   adding: content/Key_concat/clean_579.png (deflated 0%)
#   adding: content/Key_concat/stego_655.png (stored 0%)
#   adding: content/Key_concat/clean_1347.png (stored 0%)
#   adding: content/Key_concat/clean_313.png (deflated 1%)
#   adding: content/Key_concat/clean_918.png (stored 0%)
#   adding: content/Key_concat/stego_235.png (stored 0%)
#   adding: content/Key_concat/clean_192.png (stored 0%)
#   adding: content/Key_concat/clean_1114.png (stored 0%)
#   adding: content/Key_concat/clean_348.png (stored 0%)
#   adding: content/Key_concat/clean_1975.png (stored 0%)
#   adding: content/Key_concat/stego_1017.png (stored 0%)
#   adding: content/Key_concat/clean_1506.png (deflated 0%)
#   adding: content/Key_concat/clean_1507.png (stored 0%)
#   adding: content/Key_concat/stego_120.png (stored 0%)
#   adding: content/Key_concat/stego_1285.png (stored 0%)
#   adding: content/Key_concat/clean_124.png (stored 0%)
#   adding: content/Key_concat/stego_681.png (stored 0%)
#   adding: content/Key_concat/clean_552.png (stored 0%)
#   adding: content/Key_concat/clean_810.png (deflated 1%)
#   adding: content/Key_concat/stego_714.png (stored 0%)
#   adding: content/Key_concat/stego_1378.png (stored 0%)
#   adding: content/Key_concat/clean_883.png (stored 0%)
#   adding: content/Key_concat/stego_1146.png (stored 0%)
#   adding: content/Key_concat/clean_1492.png (deflated 0%)
#   adding: content/Key_concat/stego_872.png (stored 0%)
#   adding: content/Key_concat/clean_678.png (stored 0%)
#   adding: content/Key_concat/clean_1846.png (deflated 1%)
#   adding: content/Key_concat/clean_1074.png (deflated 2%)
#   adding: content/Key_concat/clean_565.png (deflated 0%)
#   adding: content/Key_concat/stego_1142.png (stored 0%)
#   adding: content/Key_concat/stego_588.png (stored 0%)
#   adding: content/Key_concat/clean_1136.png (deflated 0%)
#   adding: content/Key_concat/clean_1023.png (deflated 1%)
#   adding: content/Key_concat/clean_1514.png (stored 0%)
#   adding: content/Key_concat/clean_1803.png (deflated 0%)
#   adding: content/Key_concat/clean_641.png (stored 0%)
#   adding: content/Key_concat/clean_681.png (stored 0%)
#   adding: content/Key_concat/clean_1700.png (stored 0%)
#   adding: content/Key_concat/stego_1052.png (stored 0%)
#   adding: content/Key_concat/stego_204.png (stored 0%)
#   adding: content/Key_concat/clean_1285.png (stored 0%)
#   adding: content/Key_concat/clean_900.png (stored 0%)
#   adding: content/Key_concat/clean_125.png (stored 0%)
#   adding: content/Key_concat/clean_944.png (stored 0%)
#   adding: content/Key_concat/clean_998.png (stored 0%)
#   adding: content/Key_concat/stego_407.png (stored 0%)
#   adding: content/Key_concat/clean_1833.png (stored 0%)
#   adding: content/Key_concat/clean_724.png (stored 0%)
#   adding: content/Key_concat/clean_497.png (deflated 5%)
#   adding: content/Key_concat/clean_366.png (stored 0%)
#   adding: content/Key_concat/clean_1863.png (stored 0%)
#   adding: content/Key_concat/stego_735.png (stored 0%)
#   adding: content/Key_concat/stego_893.png (stored 0%)
#   adding: content/Key_concat/stego_1905.png (stored 0%)
#   adding: content/Key_concat/stego_60.png (stored 0%)
#   adding: content/Key_concat/clean_1112.png (stored 0%)
#   adding: content/Key_concat/clean_380.png (deflated 0%)
#   adding: content/Key_concat/stego_600.png (stored 0%)
#   adding: content/Key_concat/clean_1566.png (stored 0%)
#   adding: content/Key_concat/clean_738.png (stored 0%)
#   adding: content/Key_concat/clean_1483.png (stored 0%)
#   adding: content/Key_concat/clean_1516.png (stored 0%)
#   adding: content/Key_concat/stego_1536.png (stored 0%)
#   adding: content/Key_concat/clean_534.png (stored 0%)
#   adding: content/Key_concat/clean_1148.png (deflated 0%)
#   adding: content/Key_concat/clean_50.png (stored 0%)
#   adding: content/Key_concat/stego_342.png (stored 0%)
#   adding: content/Key_concat/clean_665.png (deflated 0%)
#   adding: content/Key_concat/clean_1589.png (stored 0%)
#   adding: content/Key_concat/clean_159.png (stored 0%)
#   adding: content/Key_concat/clean_314.png (deflated 0%)
#   adding: content/Key_concat/stego_1686.png (stored 0%)
#   adding: content/Key_concat/stego_1010.png (stored 0%)
#   adding: content/Key_concat/clean_126.png (deflated 0%)
#   adding: content/Key_concat/clean_1602.png (stored 0%)
#   adding: content/Key_concat/clean_1471.png (deflated 9%)
#   adding: content/Key_concat/clean_71.png (stored 0%)
#   adding: content/Key_concat/clean_1182.png (deflated 0%)
#   adding: content/Key_concat/stego_1445.png (stored 0%)
#   adding: content/Key_concat/stego_1249.png (stored 0%)
#   adding: content/Key_concat/stego_1746.png (stored 0%)
#   adding: content/Key_concat/clean_273.png (deflated 3%)
#   adding: content/Key_concat/stego_257.png (stored 0%)
#   adding: content/Key_concat/clean_375.png (stored 0%)
#   adding: content/Key_concat/clean_963.png (stored 0%)
#   adding: content/Key_concat/clean_115.png (stored 0%)
#   adding: content/Key_concat/stego_93.png (stored 0%)
#   adding: content/Key_concat/stego_1739.png (stored 0%)
#   adding: content/Key_concat/clean_165.png (stored 0%)
#   adding: content/Key_concat/clean_1894.png (deflated 0%)
#   adding: content/Key_concat/clean_1651.png (stored 0%)
#   adding: content/Key_concat/clean_363.png (stored 0%)
#   adding: content/Key_concat/stego_1904.png (stored 0%)
#   adding: content/Key_concat/stego_842.png (stored 0%)
#   adding: content/Key_concat/clean_1207.png (stored 0%)
#   adding: content/Key_concat/stego_1132.png (stored 0%)
#   adding: content/Key_concat/clean_428.png (deflated 0%)
#   adding: content/Key_concat/stego_1707.png (stored 0%)
#   adding: content/Key_concat/clean_196.png (stored 0%)
#   adding: content/Key_concat/clean_1408.png (stored 0%)
#   adding: content/Key_concat/stego_1115.png (stored 0%)
#   adding: content/Key_concat/clean_1389.png (deflated 0%)
#   adding: content/Key_concat/clean_1777.png (stored 0%)
#   adding: content/Key_concat/stego_226.png (stored 0%)
#   adding: content/Key_concat/stego_749.png (stored 0%)
#   adding: content/Key_concat/stego_54.png (stored 0%)
#   adding: content/Key_concat/stego_501.png (stored 0%)
#   adding: content/Key_concat/clean_1124.png (deflated 0%)
#   adding: content/Key_concat/clean_1064.png (deflated 1%)
#   adding: content/Key_concat/stego_256.png (stored 0%)
#   adding: content/Key_concat/clean_66.png (deflated 4%)
#   adding: content/Key_concat/stego_1804.png (stored 0%)
#   adding: content/Key_concat/clean_1411.png (deflated 1%)
#   adding: content/Key_concat/clean_1053.png (stored 0%)
#   adding: content/Key_concat/stego_698.png (stored 0%)
#   adding: content/Key_concat/stego_1932.png (stored 0%)
#   adding: content/Key_concat/clean_1056.png (stored 0%)
#   adding: content/Key_concat/stego_238.png (stored 0%)
#   adding: content/Key_concat/stego_1776.png (stored 0%)
#   adding: content/Key_concat/stego_1811.png (stored 0%)
#   adding: content/Key_concat/stego_1748.png (stored 0%)
#   adding: content/Key_concat/stego_1910.png (stored 0%)
#   adding: content/Key_concat/stego_1351.png (stored 0%)
#   adding: content/Key_concat/clean_343.png (deflated 0%)
#   adding: content/Key_concat/clean_1222.png (stored 0%)
#   adding: content/Key_concat/stego_1635.png (stored 0%)
#   adding: content/Key_concat/clean_937.png (deflated 1%)
#   adding: content/Key_concat/clean_570.png (stored 0%)
#   adding: content/Key_concat/clean_1567.png (deflated 2%)
#   adding: content/Key_concat/stego_345.png (stored 0%)
#   adding: content/Key_concat/clean_1332.png (deflated 0%)
#   adding: content/Key_concat/stego_271.png (stored 0%)
#   adding: content/Key_concat/stego_1403.png (stored 0%)
#   adding: content/Key_concat/clean_337.png (deflated 0%)
#   adding: content/Key_concat/stego_1484.png (stored 0%)
#   adding: content/Key_concat/clean_656.png (deflated 1%)
#   adding: content/Key_concat/stego_94.png (stored 0%)
#   adding: content/Key_concat/stego_1698.png (stored 0%)
#   adding: content/Key_concat/stego_1455.png (stored 0%)
#   adding: content/Key_concat/clean_427.png (stored 0%)
#   adding: content/Key_concat/clean_595.png (deflated 0%)
#   adding: content/Key_concat/clean_1427.png (deflated 1%)
#   adding: content/Key_concat/clean_1725.png (deflated 0%)
#   adding: content/Key_concat/clean_155.png (stored 0%)
#   adding: content/Key_concat/clean_714.png (deflated 0%)
#   adding: content/Key_concat/stego_339.png (stored 0%)
#   adding: content/Key_concat/stego_562.png (stored 0%)
#   adding: content/Key_concat/stego_421.png (stored 0%)
#   adding: content/Key_concat/clean_1671.png (stored 0%)
#   adding: content/Key_concat/clean_1235.png (deflated 0%)
#   adding: content/Key_concat/clean_984.png (stored 0%)
#   adding: content/Key_concat/clean_1717.png (deflated 0%)
#   adding: content/Key_concat/clean_1853.png (stored 0%)
#   adding: content/Key_concat/stego_516.png (stored 0%)
#   adding: content/Key_concat/clean_488.png (deflated 0%)
#   adding: content/Key_concat/stego_1568.png (stored 0%)
#   adding: content/Key_concat/stego_450.png (stored 0%)
#   adding: content/Key_concat/clean_817.png (deflated 1%)
#   adding: content/Key_concat/stego_165.png (stored 0%)
#   adding: content/Key_concat/stego_1828.png (stored 0%)
#   adding: content/Key_concat/clean_775.png (deflated 2%)
#   adding: content/Key_concat/stego_1586.png (stored 0%)
#   adding: content/Key_concat/stego_942.png (stored 0%)
#   adding: content/Key_concat/clean_933.png (stored 0%)
#   adding: content/Key_concat/clean_455.png (deflated 0%)
#   adding: content/Key_concat/clean_336.png (stored 0%)
#   adding: content/Key_concat/stego_707.png (stored 0%)
#   adding: content/Key_concat/clean_1684.png (deflated 0%)
#   adding: content/Key_concat/stego_1123.png (stored 0%)
#   adding: content/Key_concat/stego_1737.png (stored 0%)
#   adding: content/Key_concat/clean_1288.png (stored 0%)
#   adding: content/Key_concat/clean_877.png (deflated 4%)
#   adding: content/Key_concat/clean_1776.png (deflated 0%)
#   adding: content/Key_concat/clean_1186.png (stored 0%)
#   adding: content/Key_concat/clean_834.png (stored 0%)
#   adding: content/Key_concat/stego_1312.png (stored 0%)
#   adding: content/Key_concat/clean_1936.png (stored 0%)
#   adding: content/Key_concat/stego_193.png (stored 0%)
#   adding: content/Key_concat/stego_65.png (stored 0%)
#   adding: content/Key_concat/clean_1086.png (stored 0%)
#   adding: content/Key_concat/stego_543.png (stored 0%)
#   adding: content/Key_concat/clean_1859.png (stored 0%)
#   adding: content/Key_concat/stego_201.png (stored 0%)
#   adding: content/Key_concat/stego_243.png (stored 0%)
#   adding: content/Key_concat/stego_459.png (stored 0%)
#   adding: content/Key_concat/clean_416.png (stored 0%)
#   adding: content/Key_concat/stego_1598.png (stored 0%)
#   adding: content/Key_concat/clean_211.png (deflated 1%)
#   adding: content/Key_concat/stego_59.png (stored 0%)
#   adding: content/Key_concat/stego_1747.png (stored 0%)
#   adding: content/Key_concat/clean_889.png (stored 0%)
#   adding: content/Key_concat/clean_217.png (stored 0%)
#   adding: content/Key_concat/clean_1328.png (stored 0%)
#   adding: content/Key_concat/clean_1448.png (stored 0%)
#   adding: content/Key_concat/clean_1531.png (deflated 0%)
#   adding: content/Key_concat/clean_1961.png (stored 0%)
#   adding: content/Key_concat/clean_1025.png (deflated 0%)
#   adding: content/Key_concat/stego_1665.png (stored 0%)
#   adding: content/Key_concat/clean_1439.png (deflated 0%)
#   adding: content/Key_concat/clean_682.png (stored 0%)
#   adding: content/Key_concat/clean_113.png (stored 0%)
#   adding: content/Key_concat/clean_1707.png (deflated 9%)
#   adding: content/Key_concat/stego_913.png (stored 0%)
#   adding: content/Key_concat/clean_169.png (stored 0%)
#   adding: content/Key_concat/stego_1985.png (stored 0%)
#   adding: content/Key_concat/clean_1319.png (deflated 1%)
#   adding: content/Key_concat/stego_401.png (stored 0%)
#   adding: content/Key_concat/stego_1981.png (stored 0%)
#   adding: content/Key_concat/clean_1773.png (deflated 1%)
#   adding: content/Key_concat/clean_835.png (stored 0%)
#   adding: content/Key_concat/clean_1071.png (stored 0%)
#   adding: content/Key_concat/clean_385.png (stored 0%)
#   adding: content/Key_concat/clean_1090.png (stored 0%)
#   adding: content/Key_concat/stego_137.png (stored 0%)
#   adding: content/Key_concat/clean_197.png (stored 0%)
#   adding: content/Key_concat/clean_1352.png (stored 0%)
#   adding: content/Key_concat/clean_1181.png (stored 0%)
#   adding: content/Key_concat/stego_184.png (stored 0%)
#   adding: content/Key_concat/clean_1004.png (deflated 1%)
#   adding: content/Key_concat/clean_21.png (deflated 0%)
#   adding: content/Key_concat/stego_241.png (stored 0%)
#   adding: content/Key_concat/stego_680.png (stored 0%)
#   adding: content/Key_concat/clean_694.png (stored 0%)
#   adding: content/Key_concat/clean_1816.png (deflated 1%)
#   adding: content/Key_concat/clean_1484.png (stored 0%)
#   adding: content/Key_concat/stego_918.png (stored 0%)
#   adding: content/Key_concat/stego_1758.png (stored 0%)
#   adding: content/Key_concat/clean_230.png (deflated 1%)
#   adding: content/Key_concat/stego_1057.png (stored 0%)
#   adding: content/Key_concat/stego_1362.png (stored 0%)
#   adding: content/Key_concat/clean_890.png (deflated 1%)
#   adding: content/Key_concat/clean_1327.png (deflated 1%)
#   adding: content/Key_concat/stego_244.png (stored 0%)
#   adding: content/Key_concat/clean_195.png (deflated 0%)
#   adding: content/Key_concat/stego_437.png (stored 0%)
#   adding: content/Key_concat/clean_44.png (stored 0%)
#   adding: content/Key_concat/clean_1357.png (stored 0%)
#   adding: content/Key_concat/stego_1756.png (stored 0%)
#   adding: content/Key_concat/stego_461.png (stored 0%)
#   adding: content/Key_concat/stego_1793.png (stored 0%)
#   adding: content/Key_concat/clean_114.png (deflated 7%)
#   adding: content/Key_concat/stego_1727.png (stored 0%)
#   adding: content/Key_concat/stego_1032.png (stored 0%)
#   adding: content/Key_concat/stego_574.png (stored 0%)
#   adding: content/Key_concat/clean_1088.png (deflated 0%)
#   adding: content/Key_concat/stego_1901.png (stored 0%)
#   adding: content/Key_concat/stego_1621.png (stored 0%)
#   adding: content/Key_concat/clean_449.png (deflated 0%)
#   adding: content/Key_concat/stego_929.png (stored 0%)
#   adding: content/Key_concat/clean_1771.png (stored 0%)
#   adding: content/Key_concat/clean_85.png (stored 0%)
#   adding: content/Key_concat/stego_635.png (stored 0%)
#   adding: content/Key_concat/clean_1561.png (deflated 0%)
#   adding: content/Key_concat/stego_664.png (stored 0%)
#   adding: content/Key_concat/stego_509.png (stored 0%)
#   adding: content/Key_concat/stego_744.png (stored 0%)
#   adding: content/Key_concat/stego_757.png (stored 0%)
#   adding: content/Key_concat/clean_471.png (deflated 0%)
#   adding: content/Key_concat/clean_1262.png (deflated 3%)
#   adding: content/Key_concat/stego_729.png (stored 0%)
#   adding: content/Key_concat/clean_502.png (deflated 0%)
#   adding: content/Key_concat/stego_479.png (stored 0%)
#   adding: content/Key_concat/stego_916.png (stored 0%)
#   adding: content/Key_concat/stego_935.png (stored 0%)
#   adding: content/Key_concat/clean_92.png (deflated 1%)
#   adding: content/Key_concat/stego_8.png (stored 0%)
#   adding: content/Key_concat/stego_1346.png (stored 0%)
#   adding: content/Key_concat/stego_1056.png (stored 0%)
#   adding: content/Key_concat/stego_897.png (stored 0%)
#   adding: content/Key_concat/stego_1396.png (stored 0%)
#   adding: content/Key_concat/clean_562.png (deflated 0%)
#   adding: content/Key_concat/stego_557.png (stored 0%)
#   adding: content/Key_concat/clean_1686.png (stored 0%)
#   adding: content/Key_concat/stego_1221.png (stored 0%)
#   adding: content/Key_concat/clean_48.png (stored 0%)
#   adding: content/Key_concat/stego_447.png (stored 0%)
#   adding: content/Key_concat/clean_1663.png (deflated 0%)
#   adding: content/Key_concat/clean_425.png (stored 0%)
#   adding: content/Key_concat/clean_1868.png (stored 0%)
#   adding: content/Key_concat/clean_917.png (stored 0%)
#   adding: content/Key_concat/clean_959.png (deflated 0%)
#   adding: content/Key_concat/stego_51.png (stored 0%)
#   adding: content/Key_concat/stego_462.png (stored 0%)
#   adding: content/Key_concat/stego_1149.png (stored 0%)
#   adding: content/Key_concat/stego_348.png (stored 0%)

# %% [markdown]
# ##Pixel Shuffling

# %%
# Variable used to weight the losses of the secret and cover images (See paper for more details)
beta = 1.0

# Loss for reveal network
def rev_loss(y_true, y_pred):
    # Loss for reveal network is: beta * |S-S'|
    return beta * K.sum(K.square(y_true - y_pred))

# Loss for the full model, used for preparation and hidding networks
def full_loss(y_true, y_pred):
    # Loss for the full model is: |C-C'| + beta * |S-S'|
    s_true, c_true = y_true[:,:,:,0:3], y_true[:,:,:,3:6]
    s_pred, c_pred = y_pred[:,:,:,0:3], y_pred[:,:,:,3:6]
    s_loss = K.sum(K.square(s_true - s_pred))
    c_loss = K.sum(K.square(c_true - c_pred))
    return s_loss + c_loss


# Returns the encoder as a Keras model, composed by Preparation and Hiding Networks.
def make_encoder(input_size):
    input_S = Input(shape=(input_size))
    input_C= Input(shape=(input_size))
    input_K = Input(shape=(12288,))

    integer_K = tf.dtypes.cast(input_K, tf.int32)
    i1 = tf.expand_dims(tf.range(tf.shape(integer_K)[0]), axis = 1)
    i1 = tf.tile(i1, [1, 12288])
    indices = tf.stack([i1, integer_K], axis=-1)
    tensor = Flatten()(input_S)
    shape = tf.shape(tensor)
    scattered_tensor = tf.scatter_nd(indices, tensor, shape)
    x = Reshape((64,64,3))(scattered_tensor)


    # Preparation Network
    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_prep0_3x3')(x) #changed
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_prep0_4x4')(x) #changed
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_prep0_5x5')(x) #changed
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_prep1_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_prep1_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_prep1_5x5')(x)
    x = concatenate([x3, x4, x5])

    x = concatenate([input_C, x])

    # Hiding network
    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid0_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid0_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid0_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid1_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid1_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid1_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid2_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid2_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid2_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid3_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid3_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid3_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid4_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid4_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid5_5x5')(x)
    x = concatenate([x3, x4, x5])

    output_Cprime = Conv2D(3, (3, 3), strides = (1, 1), padding='same', activation='relu', name='output_C')(x)

    return Model(inputs=[input_S, input_C, input_K], #changed
                 outputs=output_Cprime,
                 name = 'Encoder')

# Returns the decoder as a Keras model, composed by the Reveal Network
def make_decoder(input_size, fixed=False):

    # Reveal network
    reveal_input = Input(shape=(input_size))
    input_K = Input(shape=(12288,))

    # Adding Gaussian noise with 0.01 standard deviation.
    input_with_noise = GaussianNoise(0.01, name='output_C_noise')(reveal_input) #changed
    x = input_with_noise
    # tensor = Flatten()(x)
    # #tensor = Reshape((1, -1))(tensor)
    # print(tensor.shape)
    # indices = Reshape((-1,2))(input_K)
    # indices = tf.dtypes.cast(indices, tf.int32)
    # print(indices.shape)
    # shape = tf.shape(tensor)

    # scattered_tensor = tf.gather_nd(tensor, indices)
    # x = Reshape((64,64,3))(scattered_tensor)
    # print(x.shape)

    #x = concatenate([input_with_noise, input_K])
    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev0_3x3')(x) #changed
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev0_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev0_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev1_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev1_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev1_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev2_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev2_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev2_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev3_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev3_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev3_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev4_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev4_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev5_5x5')(x)
    x = concatenate([x3, x4, x5])

    x = Conv2D(3, (3, 3), strides = (1, 1), padding='same', activation='relu', name='output_S')(x)

    integer_K = tf.dtypes.cast(input_K, tf.int32)
    i1 = tf.expand_dims(tf.range(tf.shape(integer_K)[0]), axis = 1)
    i1 = tf.tile(i1, [1, 12288])
    indices = tf.stack([i1,integer_K], axis=-1)
    tensor = Flatten()(x)
    shape = tf.shape(tensor)

    scattered_tensor = tf.gather_nd(tensor, indices)
    output_Sprime= Reshape((64,64,3))(scattered_tensor)
    #print(x.shape)

    if not fixed:
        return Model(inputs=[reveal_input,input_K],
                     outputs=output_Sprime,
                     name = 'Decoder')
    # else:
    #     return Container(inputs=reveal_input,
    #                      outputs=output_Sprime,
    #                      name = 'DecoderFixed')                    # Changed
    else:
      return Network(inputs=[reveal_input,input_K],   #changed
                      outputs=output_Sprime,
                      name = 'DecoderFixed')

# Full model.
def make_model(input_size):
    input_S = Input(shape=(input_size))
    input_C= Input(shape=(input_size))
    input_K = Input(shape=(12288,))

    encoder = make_encoder(input_size)

    decoder = make_decoder(input_size)
    decoder.compile(optimizer='adam', loss=rev_loss)
    decoder.trainable = False

    output_Cprime = encoder([input_S, input_C, input_K]) #changed
    output_Sprime = decoder([output_Cprime, input_K]) #changed

    autoencoder = Model(inputs=[input_S, input_C, input_K],
                        outputs=concatenate([output_Sprime, output_Cprime]))
    autoencoder.compile(optimizer='adam', loss=full_loss)
    return encoder, decoder, autoencoder

# %%
encoder_model, reveal_model, autoencoder_model = make_model(input_S.shape[1:])
autoencoder_model.load_weights('/content/drive/My Drive/Final_Model/pixel_shuffling/pixel_shuffling_autoencoder_model_100k_50e.hdf5')
encoder_model.load_weights('/content/drive/My Drive/Final_Model/pixel_shuffling/pixel_shuffling_encoder_model_100k_50e.hdf5')
reveal_model.load_weights('/content/drive/My Drive/Final_Model/pixel_shuffling/pixel_shuffling_reveal_model_100k_50e.hdf5')

# %%
# !mkdir "/content/Pixel_Shuffling"

# %%
from google.colab import files
from cv2 import cv2
from tqdm import tqdm
from PIL import Image
import matplotlib

secret=X_test[0:2000]
cover=X_test[2000:4000]

input_K = np.zeros(shape=(len(secret), 12288))
for i in range(len(secret)):
    input_K[i] = random.sample(range(0, 12288), 12288)

C_prime = encoder_model.predict([secret, cover, input_K])

i=1
for c in tqdm(cover):
  matplotlib.image.imsave('/content/Pixel_Shuffling/clean_'+str(i)+'.png',c)
  i= i+1

i=1
for s in tqdm(C_prime):
  s = s.clip(min = 0, max =1)
  matplotlib.image.imsave('/content/Pixel_Shuffling/stego_'+str(i)+'.png',s)

  i= i+1
# Out:
# 100%|██████████| 2000/2000 [00:04<00:00, 423.90it/s]
# 100%|██████████| 2000/2000 [00:04<00:00, 416.38it/s]

# %%
# !zip -r /content/Pixel_Shuffling.zip /content/Pixel_Shuffling
from google.colab import files
files.download("/content/Pixel_Shuffling.zip")
# Out:
#   adding: content/Pixel_Shuffling/ (stored 0%)
#   adding: content/Pixel_Shuffling/stego_690.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1950.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_899.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1851.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_21.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1400.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1638.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_640.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_930.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1883.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_16.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1369.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_39.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_566.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_13.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1330.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1233.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_375.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1260.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_429.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1126.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1912.png (deflated 2%)
#   adding: content/Pixel_Shuffling/stego_950.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1196.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1329.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1826.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1622.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_1192.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_1600.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1788.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1806.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_820.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1702.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1890.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_303.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_631.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_17.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_965.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1310.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1829.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1531.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_891.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_383.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_315.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1029.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_591.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1850.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_279.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1890.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_450.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1986.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1675.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1155.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_813.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1122.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_485.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_815.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1028.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1246.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_1741.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1148.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1475.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1647.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_42.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_51.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1460.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1142.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1556.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1753.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_972.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1922.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_291.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_768.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_975.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_551.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_278.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_220.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1489.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1028.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_136.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1122.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1488.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_744.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_662.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_1664.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_758.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1210.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_952.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_149.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_983.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1678.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1993.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_394.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_1409.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_985.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_538.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_790.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1402.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1413.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_869.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1664.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_584.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_676.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_432.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_374.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_525.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_608.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1326.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_5.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_637.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_252.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_275.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_773.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_655.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1567.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_494.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_860.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1662.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_185.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1784.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1708.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_309.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_473.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1990.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1126.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_190.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_312.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_320.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_798.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_246.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_499.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_982.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1088.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1505.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_615.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1441.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_509.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1863.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_684.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_586.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1016.png (deflated 8%)
#   adding: content/Pixel_Shuffling/clean_350.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_734.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_2.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_861.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_896.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1816.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1157.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1371.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1812.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1269.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1973.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_435.png (deflated 2%)
#   adding: content/Pixel_Shuffling/clean_1242.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1070.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_723.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_820.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_1536.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1501.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_468.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_205.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1514.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_340.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_1051.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_986.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_692.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1061.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_117.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1303.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_747.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_242.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1293.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_70.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_428.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_962.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1825.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_580.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_308.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_286.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1202.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_633.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1696.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1137.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_947.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1605.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_269.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_167.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1041.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1368.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_945.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1424.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1281.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1699.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_394.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_299.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1814.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1793.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_951.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_262.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1931.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1518.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1988.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1672.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_111.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_789.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1082.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1955.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_579.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1683.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_215.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_111.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1659.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1618.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1378.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1256.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_135.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1881.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_236.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1570.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1150.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1215.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1288.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_607.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_855.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_972.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1927.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_999.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1040.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1377.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1067.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1562.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1948.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_129.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1291.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1612.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1947.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1382.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1236.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1403.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_121.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1458.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_389.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1001.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1084.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1246.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_97.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_2000.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_1186.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_392.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1454.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1107.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1969.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_274.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1810.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1237.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_180.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1407.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_41.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_84.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1874.png (deflated 8%)
#   adding: content/Pixel_Shuffling/stego_1572.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1597.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_350.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1959.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_281.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_436.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1786.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_979.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1091.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_305.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_514.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_189.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_706.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_745.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_592.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_831.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_176.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_889.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1172.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_614.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_67.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1160.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1472.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_195.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_550.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1135.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_38.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_651.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1183.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_967.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1845.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1532.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_845.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_669.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_499.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_145.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_757.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_1180.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1687.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_671.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1626.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_763.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_601.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_12.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1965.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_553.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1341.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_232.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_1772.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1836.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1815.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_221.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1946.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1308.png (deflated 2%)
#   adding: content/Pixel_Shuffling/stego_1860.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1784.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_847.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_935.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1691.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_912.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_121.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_200.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_515.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1389.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1515.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_219.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_266.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1999.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1227.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_44.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_82.png (deflated 2%)
#   adding: content/Pixel_Shuffling/clean_818.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_870.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_943.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_996.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1293.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_270.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1164.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1284.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_1898.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_860.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1182.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_733.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1059.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1841.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_219.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_418.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_1740.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_369.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1264.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_404.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_384.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1520.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_671.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_164.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_568.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_726.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1001.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1224.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1124.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_849.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1103.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_69.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_939.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_1063.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_1750.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_341.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_272.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_669.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1852.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_915.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_978.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1170.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1718.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1414.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_299.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1438.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1425.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_530.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1323.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1858.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_330.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_879.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_239.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1191.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_888.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1019.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_985.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_804.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1895.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_74.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_966.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1127.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_626.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_10.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1188.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1310.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1141.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1324.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_386.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_371.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_427.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_638.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_479.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1383.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1757.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_523.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_553.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_3.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1721.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1789.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_943.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1451.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_475.png (deflated 2%)
#   adding: content/Pixel_Shuffling/clean_1457.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_1132.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1851.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_163.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_107.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_886.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1913.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1164.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_787.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1495.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1811.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1893.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1971.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1616.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_458.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_506.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_347.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1147.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_391.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_800.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1042.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_468.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_208.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1596.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1862.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_412.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1899.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_31.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_70.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1705.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_946.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1873.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1201.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1697.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1128.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_247.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_110.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_33.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1566.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_465.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_921.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_141.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1355.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_124.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_437.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_856.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1595.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1720.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_989.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1594.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1498.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1256.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_809.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_245.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1708.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1623.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_593.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1888.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_240.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_178.png (deflated 6%)
#   adding: content/Pixel_Shuffling/stego_1297.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_147.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1624.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_249.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_234.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_815.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_802.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_762.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_923.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_37.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_337.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1169.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_30.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_992.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1404.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1354.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1525.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_9.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_541.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1979.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1669.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_766.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_271.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_253.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_854.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1838.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1230.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1278.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_961.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_844.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_463.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1014.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_631.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_992.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1292.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1762.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1232.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_635.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_529.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1981.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_563.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_304.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_406.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_420.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_160.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1108.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1909.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1640.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_662.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_387.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1665.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1743.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1453.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1260.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1417.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_743.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1742.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_415.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_400.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_388.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_598.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1849.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_1696.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1521.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_387.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1231.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1139.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_488.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_876.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_541.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1152.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_723.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1546.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_601.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1266.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1848.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_612.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_1499.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1364.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_750.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_858.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1719.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_751.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1072.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_418.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1358.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_352.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_1625.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1642.png (deflated 2%)
#   adding: content/Pixel_Shuffling/stego_119.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1608.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_561.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1706.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1934.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1214.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_585.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1045.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1176.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_892.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_110.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_755.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_1281.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1469.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_231.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_438.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1591.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1213.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_533.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1138.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_235.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_1189.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_871.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_364.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_584.png (deflated 2%)
#   adding: content/Pixel_Shuffling/stego_1978.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_413.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1712.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1455.png (deflated 2%)
#   adding: content/Pixel_Shuffling/stego_1259.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_131.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_432.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1963.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_796.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_316.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1390.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_519.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1930.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_540.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_213.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_83.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1678.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_618.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1813.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1305.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_372.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1219.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1754.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_89.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1629.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1247.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1541.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1787.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1447.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_142.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1342.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1582.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_309.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_1228.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1331.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1636.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_197.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_284.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1722.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_123.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_805.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_277.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_323.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_763.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_451.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1481.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1780.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_783.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1007.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1054.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_802.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1538.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1344.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1450.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_863.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_527.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_656.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1000.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_274.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_293.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_742.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_104.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_444.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_167.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_905.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_639.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_730.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1227.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_248.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_1201.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_359.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_285.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1023.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_831.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_725.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1295.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_1364.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_22.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_431.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1054.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_231.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1387.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1441.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1934.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_958.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_868.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_419.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_953.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_530.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_771.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1783.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1538.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1805.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1020.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1546.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_764.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_397.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1553.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_170.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1644.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1230.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_157.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1102.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1104.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1791.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_679.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1045.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_179.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_101.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1925.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1204.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_949.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1386.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_1778.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1345.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1037.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_547.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1892.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_458.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1321.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_710.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1167.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_785.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1822.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_489.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_942.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_873.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_846.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_151.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1914.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_1799.png (deflated 2%)
#   adding: content/Pixel_Shuffling/clean_1729.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1258.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1449.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_76.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_261.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1800.png (deflated 2%)
#   adding: content/Pixel_Shuffling/clean_1855.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1202.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_166.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1991.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1741.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_819.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1627.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1144.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1503.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1641.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_411.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1788.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1216.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1185.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1021.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1120.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_317.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1974.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1203.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1300.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1671.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1875.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_1683.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1476.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_4.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1532.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1526.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_333.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_403.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1792.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1855.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_208.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_1008.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_398.png (deflated 3%)
#   adding: content/Pixel_Shuffling/clean_1420.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1154.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1391.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_354.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1593.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1580.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_137.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_476.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1206.png (deflated 2%)
#   adding: content/Pixel_Shuffling/clean_346.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1771.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1867.png (deflated 2%)
#   adding: content/Pixel_Shuffling/clean_25.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_160.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1020.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1734.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1015.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_251.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_28.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_188.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1408.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_282.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_295.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1880.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1740.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1262.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1271.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1405.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1545.png (stored 0%)
# ...
#   adding: content/Pixel_Shuffling/clean_1492.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_872.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_678.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1846.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_1074.png (deflated 2%)
#   adding: content/Pixel_Shuffling/clean_565.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1142.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_588.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1136.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1023.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_1514.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1803.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_641.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_681.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1700.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1052.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_204.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1285.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_900.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_125.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_944.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_998.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_407.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1833.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_724.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_497.png (deflated 5%)
#   adding: content/Pixel_Shuffling/clean_366.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1863.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_735.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_893.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1905.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_60.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1112.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_380.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_600.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1566.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_738.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1483.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1516.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1536.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_534.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1148.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_50.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_342.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_665.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1589.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_159.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_314.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1686.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1010.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_126.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1602.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1471.png (deflated 9%)
#   adding: content/Pixel_Shuffling/clean_71.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1182.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1445.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1249.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1746.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_273.png (deflated 3%)
#   adding: content/Pixel_Shuffling/stego_257.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_375.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_963.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_115.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_93.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1739.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_165.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1894.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1651.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_363.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1904.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_842.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1207.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1132.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_428.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1707.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_196.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1408.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1115.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1389.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1777.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_226.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_749.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_54.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_501.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1124.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1064.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_256.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_66.png (deflated 4%)
#   adding: content/Pixel_Shuffling/stego_1804.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1411.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_1053.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_698.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1932.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1056.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_238.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1776.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1811.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1748.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1910.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1351.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_343.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1222.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1635.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_937.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_570.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1567.png (deflated 2%)
#   adding: content/Pixel_Shuffling/stego_345.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1332.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_271.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1403.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_337.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1484.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_656.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_94.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1698.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1455.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_427.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_595.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1427.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_1725.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_155.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_714.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_339.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_562.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_421.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1671.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1235.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_984.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1717.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1853.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_516.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_488.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1568.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_450.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_817.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_165.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1828.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_775.png (deflated 2%)
#   adding: content/Pixel_Shuffling/stego_1586.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_942.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_933.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_455.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_336.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_707.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1684.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1123.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1737.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1288.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_877.png (deflated 4%)
#   adding: content/Pixel_Shuffling/clean_1776.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1186.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_834.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1312.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1936.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_193.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_65.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1086.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_543.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1859.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_201.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_243.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_459.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_416.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1598.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_211.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_59.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1747.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_889.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_217.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1328.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1448.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1531.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1961.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1025.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1665.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1439.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_682.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_113.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1707.png (deflated 9%)
#   adding: content/Pixel_Shuffling/stego_913.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_169.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1985.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1319.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_401.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1981.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1773.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_835.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1071.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_385.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1090.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_137.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_197.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1352.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1181.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_184.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1004.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_21.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_241.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_680.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_694.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1816.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_1484.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_918.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1758.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_230.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_1057.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1362.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_890.png (deflated 1%)
#   adding: content/Pixel_Shuffling/clean_1327.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_244.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_195.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_437.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_44.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1357.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1756.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_461.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1793.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_114.png (deflated 7%)
#   adding: content/Pixel_Shuffling/stego_1727.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1032.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_574.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1088.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_1901.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1621.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_449.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_929.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1771.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_85.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_635.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1561.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_664.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_509.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_744.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_757.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_471.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_1262.png (deflated 3%)
#   adding: content/Pixel_Shuffling/stego_729.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_502.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_479.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_916.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_935.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_92.png (deflated 1%)
#   adding: content/Pixel_Shuffling/stego_8.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1346.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1056.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_897.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1396.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_562.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_557.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1686.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1221.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_48.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_447.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1663.png (deflated 0%)
#   adding: content/Pixel_Shuffling/clean_425.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_1868.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_917.png (stored 0%)
#   adding: content/Pixel_Shuffling/clean_959.png (deflated 0%)
#   adding: content/Pixel_Shuffling/stego_51.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_462.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_1149.png (stored 0%)
#   adding: content/Pixel_Shuffling/stego_348.png (stored 0%)

# %% [markdown]
# ##One Block Shuffling

# %%
# Variable used to weight the losses of the secret and cover images (See paper for more details)
beta = 1.0

# Loss for reveal network
def rev_loss(y_true, y_pred):
    # Loss for reveal network is: beta * |S-S'|
    return beta * K.sum(K.square(y_true - y_pred))

# Loss for the full model, used for preparation and hidding networks
def full_loss(y_true, y_pred):
    # Loss for the full model is: |C-C'| + beta * |S-S'|
    s_true, c_true = y_true[:,:,:,0:3], y_true[:,:,:,3:6]
    s_pred, c_pred = y_pred[:,:,:,0:3], y_pred[:,:,:,3:6]
    s_loss = K.sum(K.square(s_true - s_pred))
    c_loss = K.sum(K.square(c_true - c_pred))
    return s_loss + c_loss


# Returns the encoder as a Keras model, composed by Preparation and Hiding Networks.
def make_encoder(input_size):
    input_S = Input(shape=(input_size))
    input_C= Input(shape=(input_size))
    input_K = Input(shape=(4096,))

    integer_K = tf.dtypes.cast(input_K, tf.int32)
    i1 = tf.expand_dims(tf.range(tf.shape(integer_K)[0]), axis = 1)
    i1 = tf.tile(i1, [1, 4096])
    indices = tf.stack([i1, integer_K], axis=-1)
    tensor = Reshape(( -1, 3))(input_S)
    shape = tf.shape(tensor)
    scattered_tensor = tf.scatter_nd(indices, tensor, shape)
    x = Reshape((64,64,3))(scattered_tensor)


    # Preparation Network
    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_prep0_3x3')(x) #changed
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_prep0_4x4')(x) #changed
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_prep0_5x5')(x) #changed
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_prep1_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_prep1_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_prep1_5x5')(x)
    x = concatenate([x3, x4, x5])

    x = concatenate([input_C, x])

    # Hiding network
    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid0_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid0_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid0_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid1_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid1_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid1_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid2_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid2_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid2_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid3_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid3_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid3_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid4_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid4_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid5_5x5')(x)
    x = concatenate([x3, x4, x5])

    output_Cprime = Conv2D(3, (3, 3), strides = (1, 1), padding='same', activation='relu', name='output_C')(x)

    return Model(inputs=[input_S, input_C, input_K], #changed
                 outputs=output_Cprime,
                 name = 'Encoder')

# Returns the decoder as a Keras model, composed by the Reveal Network
def make_decoder(input_size, fixed=False):

    # Reveal network
    reveal_input = Input(shape=(input_size))
    input_K = Input(shape=(4096,))

    # Adding Gaussian noise with 0.01 standard deviation.
    input_with_noise = GaussianNoise(0.01, name='output_C_noise')(reveal_input) #changed
    x = input_with_noise

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev0_3x3')(x) #changed
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev0_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev0_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev1_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev1_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev1_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev2_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev2_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev2_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev3_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev3_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev3_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev4_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev4_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev5_5x5')(x)
    x = concatenate([x3, x4, x5])

    x = Conv2D(3, (3, 3), strides = (1, 1), padding='same', activation='relu', name='output_S')(x)

    integer_K = tf.dtypes.cast(input_K, tf.int32)
    i1 = tf.expand_dims(tf.range(tf.shape(integer_K)[0]), axis = 1)
    i1 = tf.tile(i1, [1, 4096])
    indices = tf.stack([i1,integer_K], axis=-1)
    tensor = Reshape(( -1, 3))(x)
    shape = tf.shape(tensor)

    scattered_tensor = tf.gather_nd(tensor, indices)
    output_Sprime= Reshape((64,64,3))(scattered_tensor)
    #print(x.shape)

    if not fixed:
        return Model(inputs=[reveal_input,input_K],
                     outputs=output_Sprime,
                     name = 'Decoder')
    # else:
    #     return Container(inputs=reveal_input,
    #                      outputs=output_Sprime,
    #                      name = 'DecoderFixed')                    # Changed
    else:
      return Network(inputs=[reveal_input,input_K],   #changed
                      outputs=output_Sprime,
                      name = 'DecoderFixed')

# Full model.
def make_model(input_size):
    input_S = Input(shape=(input_size))
    input_C= Input(shape=(input_size))
    input_K = Input(shape=(4096,))

    encoder = make_encoder(input_size)

    decoder = make_decoder(input_size)
    decoder.compile(optimizer='adam', loss=rev_loss)
    decoder.trainable = False

    output_Cprime = encoder([input_S, input_C, input_K]) #changed
    output_Sprime = decoder([output_Cprime, input_K]) #changed

    autoencoder = Model(inputs=[input_S, input_C, input_K],
                        outputs=concatenate([output_Sprime, output_Cprime]))
    autoencoder.compile(optimizer='adam', loss=full_loss)
    return encoder, decoder, autoencoder

# %%
encoder_model, reveal_model, autoencoder_model = make_model(input_S.shape[1:])
autoencoder_model.load_weights('/content/drive/My Drive/Final_Model/one_block_shuffling/one_block_shuffling_autoencoder_model_100k_50e.hdf5')
encoder_model.load_weights('/content/drive/My Drive/Final_Model/one_block_shuffling/one_block_shuffling_encoder_model_100k_50e.hdf5')
reveal_model.load_weights('/content/drive/My Drive/Final_Model/one_block_shuffling/one_block_shuffling_reveal_model_100k_50e.hdf5')

# %%
# !mkdir "/content/One_block_shuffling"

# %%
from google.colab import files
from cv2 import cv2
from tqdm import tqdm
from PIL import Image
import matplotlib

secret=X_test[0:2000]
cover=X_test[2000:4000]

input_K = np.zeros(shape=(len(secret), 4096))
for i in range(len(secret)):
    input_K[i] = random.sample(range(0, 4096), 4096)

C_prime = encoder_model.predict([secret, cover, input_K])

i=1
for c in tqdm(cover):
  matplotlib.image.imsave('/content/One_block_shuffling/clean_'+str(i)+'.png',c)
  i= i+1

i=1
for s in tqdm(C_prime):
  s = s.clip(min = 0, max =1)
  matplotlib.image.imsave('/content/One_block_shuffling/stego_'+str(i)+'.png',s)

  i= i+1
# Out:
# 100%|██████████| 2000/2000 [00:04<00:00, 416.41it/s]
# 100%|██████████| 2000/2000 [00:04<00:00, 412.23it/s]

# %%
# !zip -r /content/One_block_shuffling.zip /content/One_block_shuffling
from google.colab import files
files.download("/content/One_block_shuffling.zip")
# Out:
#   adding: content/One_block_shuffling/ (stored 0%)
#   adding: content/One_block_shuffling/stego_690.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1950.png (stored 0%)
#   adding: content/One_block_shuffling/clean_899.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1851.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_21.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1400.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1638.png (stored 0%)
#   adding: content/One_block_shuffling/stego_640.png (stored 0%)
#   adding: content/One_block_shuffling/clean_930.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1883.png (stored 0%)
#   adding: content/One_block_shuffling/stego_16.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1369.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_39.png (stored 0%)
#   adding: content/One_block_shuffling/stego_566.png (stored 0%)
#   adding: content/One_block_shuffling/stego_13.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1330.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1233.png (stored 0%)
#   adding: content/One_block_shuffling/stego_375.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1260.png (stored 0%)
#   adding: content/One_block_shuffling/stego_429.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1126.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1912.png (deflated 2%)
#   adding: content/One_block_shuffling/stego_950.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1196.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1329.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1826.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1622.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_1192.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_1600.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1788.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1806.png (stored 0%)
#   adding: content/One_block_shuffling/stego_820.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1702.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1890.png (stored 0%)
#   adding: content/One_block_shuffling/clean_303.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_631.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_17.png (stored 0%)
#   adding: content/One_block_shuffling/stego_965.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1310.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1829.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1531.png (stored 0%)
#   adding: content/One_block_shuffling/clean_891.png (stored 0%)
#   adding: content/One_block_shuffling/clean_383.png (stored 0%)
#   adding: content/One_block_shuffling/stego_315.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1029.png (stored 0%)
#   adding: content/One_block_shuffling/clean_591.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1850.png (stored 0%)
#   adding: content/One_block_shuffling/clean_279.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1890.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_450.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1986.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1675.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1155.png (stored 0%)
#   adding: content/One_block_shuffling/clean_813.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1122.png (stored 0%)
#   adding: content/One_block_shuffling/clean_485.png (stored 0%)
#   adding: content/One_block_shuffling/clean_815.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1028.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1246.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_1741.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1148.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1475.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1647.png (stored 0%)
#   adding: content/One_block_shuffling/stego_42.png (stored 0%)
#   adding: content/One_block_shuffling/clean_51.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1460.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1142.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1556.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1753.png (stored 0%)
#   adding: content/One_block_shuffling/clean_972.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1922.png (stored 0%)
#   adding: content/One_block_shuffling/stego_291.png (stored 0%)
#   adding: content/One_block_shuffling/stego_768.png (stored 0%)
#   adding: content/One_block_shuffling/stego_975.png (stored 0%)
#   adding: content/One_block_shuffling/stego_551.png (stored 0%)
#   adding: content/One_block_shuffling/clean_278.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_220.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1489.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1028.png (stored 0%)
#   adding: content/One_block_shuffling/stego_136.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1122.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1488.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_744.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_662.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_1664.png (stored 0%)
#   adding: content/One_block_shuffling/clean_758.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1210.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_952.png (stored 0%)
#   adding: content/One_block_shuffling/stego_149.png (stored 0%)
#   adding: content/One_block_shuffling/stego_983.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1678.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1993.png (stored 0%)
#   adding: content/One_block_shuffling/clean_394.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_1409.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_985.png (stored 0%)
#   adding: content/One_block_shuffling/stego_538.png (stored 0%)
#   adding: content/One_block_shuffling/stego_790.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1402.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1413.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_869.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1664.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_584.png (stored 0%)
#   adding: content/One_block_shuffling/stego_676.png (stored 0%)
#   adding: content/One_block_shuffling/clean_432.png (stored 0%)
#   adding: content/One_block_shuffling/clean_374.png (stored 0%)
#   adding: content/One_block_shuffling/stego_525.png (stored 0%)
#   adding: content/One_block_shuffling/clean_608.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1326.png (stored 0%)
#   adding: content/One_block_shuffling/stego_5.png (stored 0%)
#   adding: content/One_block_shuffling/clean_637.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_252.png (stored 0%)
#   adding: content/One_block_shuffling/stego_275.png (stored 0%)
#   adding: content/One_block_shuffling/clean_773.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_655.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1567.png (stored 0%)
#   adding: content/One_block_shuffling/stego_494.png (stored 0%)
#   adding: content/One_block_shuffling/stego_860.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1662.png (stored 0%)
#   adding: content/One_block_shuffling/clean_185.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1784.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1708.png (stored 0%)
#   adding: content/One_block_shuffling/stego_309.png (stored 0%)
#   adding: content/One_block_shuffling/clean_473.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1990.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1126.png (stored 0%)
#   adding: content/One_block_shuffling/stego_190.png (stored 0%)
#   adding: content/One_block_shuffling/clean_312.png (stored 0%)
#   adding: content/One_block_shuffling/stego_320.png (stored 0%)
#   adding: content/One_block_shuffling/stego_798.png (stored 0%)
#   adding: content/One_block_shuffling/clean_246.png (stored 0%)
#   adding: content/One_block_shuffling/stego_499.png (stored 0%)
#   adding: content/One_block_shuffling/clean_982.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1088.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1505.png (stored 0%)
#   adding: content/One_block_shuffling/clean_615.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1441.png (stored 0%)
#   adding: content/One_block_shuffling/clean_509.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1863.png (stored 0%)
#   adding: content/One_block_shuffling/clean_684.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_586.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1016.png (deflated 8%)
#   adding: content/One_block_shuffling/clean_350.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_734.png (stored 0%)
#   adding: content/One_block_shuffling/stego_2.png (stored 0%)
#   adding: content/One_block_shuffling/stego_861.png (stored 0%)
#   adding: content/One_block_shuffling/clean_896.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1816.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1157.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1371.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1812.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1269.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1973.png (stored 0%)
#   adding: content/One_block_shuffling/clean_435.png (deflated 2%)
#   adding: content/One_block_shuffling/clean_1242.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1070.png (stored 0%)
#   adding: content/One_block_shuffling/stego_723.png (stored 0%)
#   adding: content/One_block_shuffling/clean_820.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_1536.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1501.png (stored 0%)
#   adding: content/One_block_shuffling/clean_468.png (stored 0%)
#   adding: content/One_block_shuffling/clean_205.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1514.png (stored 0%)
#   adding: content/One_block_shuffling/clean_340.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_1051.png (stored 0%)
#   adding: content/One_block_shuffling/clean_986.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_692.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1061.png (stored 0%)
#   adding: content/One_block_shuffling/stego_117.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1303.png (stored 0%)
#   adding: content/One_block_shuffling/stego_747.png (stored 0%)
#   adding: content/One_block_shuffling/clean_242.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1293.png (stored 0%)
#   adding: content/One_block_shuffling/clean_70.png (stored 0%)
#   adding: content/One_block_shuffling/stego_428.png (stored 0%)
#   adding: content/One_block_shuffling/stego_962.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1825.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_580.png (stored 0%)
#   adding: content/One_block_shuffling/clean_308.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_286.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1202.png (stored 0%)
#   adding: content/One_block_shuffling/stego_633.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1696.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1137.png (stored 0%)
#   adding: content/One_block_shuffling/clean_947.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1605.png (stored 0%)
#   adding: content/One_block_shuffling/clean_269.png (stored 0%)
#   adding: content/One_block_shuffling/clean_167.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1041.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1368.png (stored 0%)
#   adding: content/One_block_shuffling/clean_945.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1424.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1281.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1699.png (stored 0%)
#   adding: content/One_block_shuffling/stego_394.png (stored 0%)
#   adding: content/One_block_shuffling/stego_299.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1814.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1793.png (stored 0%)
#   adding: content/One_block_shuffling/clean_951.png (stored 0%)
#   adding: content/One_block_shuffling/stego_262.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1931.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1518.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1988.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1672.png (stored 0%)
#   adding: content/One_block_shuffling/stego_111.png (stored 0%)
#   adding: content/One_block_shuffling/clean_789.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1082.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1955.png (stored 0%)
#   adding: content/One_block_shuffling/stego_579.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1683.png (stored 0%)
#   adding: content/One_block_shuffling/stego_215.png (stored 0%)
#   adding: content/One_block_shuffling/clean_111.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1659.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1618.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1378.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1256.png (stored 0%)
#   adding: content/One_block_shuffling/clean_135.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1881.png (stored 0%)
#   adding: content/One_block_shuffling/clean_236.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1570.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1150.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1215.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1288.png (stored 0%)
#   adding: content/One_block_shuffling/clean_607.png (stored 0%)
#   adding: content/One_block_shuffling/stego_855.png (stored 0%)
#   adding: content/One_block_shuffling/stego_972.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1927.png (stored 0%)
#   adding: content/One_block_shuffling/stego_999.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1040.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1377.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1067.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1562.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1948.png (stored 0%)
#   adding: content/One_block_shuffling/clean_129.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1291.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1612.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1947.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1382.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1236.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1403.png (stored 0%)
#   adding: content/One_block_shuffling/stego_121.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1458.png (stored 0%)
#   adding: content/One_block_shuffling/clean_389.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1001.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1084.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1246.png (stored 0%)
#   adding: content/One_block_shuffling/stego_97.png (stored 0%)
#   adding: content/One_block_shuffling/clean_2000.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_1186.png (stored 0%)
#   adding: content/One_block_shuffling/clean_392.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1454.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1107.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1969.png (stored 0%)
#   adding: content/One_block_shuffling/clean_274.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1810.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1237.png (stored 0%)
#   adding: content/One_block_shuffling/stego_180.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1407.png (stored 0%)
#   adding: content/One_block_shuffling/clean_41.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_84.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1874.png (deflated 8%)
#   adding: content/One_block_shuffling/stego_1572.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1597.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_350.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1959.png (stored 0%)
#   adding: content/One_block_shuffling/stego_281.png (stored 0%)
#   adding: content/One_block_shuffling/clean_436.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1786.png (stored 0%)
#   adding: content/One_block_shuffling/stego_979.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1091.png (stored 0%)
#   adding: content/One_block_shuffling/stego_305.png (stored 0%)
#   adding: content/One_block_shuffling/stego_514.png (stored 0%)
#   adding: content/One_block_shuffling/stego_189.png (stored 0%)
#   adding: content/One_block_shuffling/clean_706.png (stored 0%)
#   adding: content/One_block_shuffling/stego_745.png (stored 0%)
#   adding: content/One_block_shuffling/clean_592.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_831.png (stored 0%)
#   adding: content/One_block_shuffling/stego_176.png (stored 0%)
#   adding: content/One_block_shuffling/stego_889.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1172.png (stored 0%)
#   adding: content/One_block_shuffling/stego_614.png (stored 0%)
#   adding: content/One_block_shuffling/stego_67.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1160.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1472.png (stored 0%)
#   adding: content/One_block_shuffling/stego_195.png (stored 0%)
#   adding: content/One_block_shuffling/clean_550.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1135.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_38.png (stored 0%)
#   adding: content/One_block_shuffling/clean_651.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1183.png (stored 0%)
#   adding: content/One_block_shuffling/clean_967.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1845.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1532.png (stored 0%)
#   adding: content/One_block_shuffling/clean_845.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_669.png (stored 0%)
#   adding: content/One_block_shuffling/clean_499.png (stored 0%)
#   adding: content/One_block_shuffling/stego_145.png (stored 0%)
#   adding: content/One_block_shuffling/clean_757.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_1180.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1687.png (stored 0%)
#   adding: content/One_block_shuffling/clean_671.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1626.png (stored 0%)
#   adding: content/One_block_shuffling/stego_763.png (stored 0%)
#   adding: content/One_block_shuffling/clean_601.png (stored 0%)
#   adding: content/One_block_shuffling/clean_12.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1965.png (stored 0%)
#   adding: content/One_block_shuffling/clean_553.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1341.png (stored 0%)
#   adding: content/One_block_shuffling/clean_232.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_1772.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1836.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1815.png (stored 0%)
#   adding: content/One_block_shuffling/stego_221.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1946.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1308.png (deflated 2%)
#   adding: content/One_block_shuffling/stego_1860.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1784.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_847.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_935.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1691.png (stored 0%)
#   adding: content/One_block_shuffling/clean_912.png (stored 0%)
#   adding: content/One_block_shuffling/clean_121.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_200.png (stored 0%)
#   adding: content/One_block_shuffling/clean_515.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1389.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1515.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_219.png (stored 0%)
#   adding: content/One_block_shuffling/clean_266.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1999.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1227.png (stored 0%)
#   adding: content/One_block_shuffling/stego_44.png (stored 0%)
#   adding: content/One_block_shuffling/clean_82.png (deflated 2%)
#   adding: content/One_block_shuffling/clean_818.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_870.png (stored 0%)
#   adding: content/One_block_shuffling/stego_943.png (stored 0%)
#   adding: content/One_block_shuffling/clean_996.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1293.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_270.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1164.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1284.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_1898.png (stored 0%)
#   adding: content/One_block_shuffling/clean_860.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1182.png (stored 0%)
#   adding: content/One_block_shuffling/clean_733.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1059.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1841.png (stored 0%)
#   adding: content/One_block_shuffling/clean_219.png (stored 0%)
#   adding: content/One_block_shuffling/clean_418.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_1740.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_369.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1264.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_404.png (stored 0%)
#   adding: content/One_block_shuffling/stego_384.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1520.png (stored 0%)
#   adding: content/One_block_shuffling/stego_671.png (stored 0%)
#   adding: content/One_block_shuffling/clean_164.png (stored 0%)
#   adding: content/One_block_shuffling/stego_568.png (stored 0%)
#   adding: content/One_block_shuffling/stego_726.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1001.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1224.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1124.png (stored 0%)
#   adding: content/One_block_shuffling/stego_849.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1103.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_69.png (stored 0%)
#   adding: content/One_block_shuffling/clean_939.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_1063.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_1750.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_341.png (stored 0%)
#   adding: content/One_block_shuffling/stego_272.png (stored 0%)
#   adding: content/One_block_shuffling/clean_669.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1852.png (stored 0%)
#   adding: content/One_block_shuffling/stego_915.png (stored 0%)
#   adding: content/One_block_shuffling/clean_978.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1170.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1718.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1414.png (stored 0%)
#   adding: content/One_block_shuffling/clean_299.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1438.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1425.png (stored 0%)
#   adding: content/One_block_shuffling/clean_530.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1323.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1858.png (stored 0%)
#   adding: content/One_block_shuffling/stego_330.png (stored 0%)
#   adding: content/One_block_shuffling/stego_879.png (stored 0%)
#   adding: content/One_block_shuffling/stego_239.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1191.png (stored 0%)
#   adding: content/One_block_shuffling/clean_888.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1019.png (stored 0%)
#   adding: content/One_block_shuffling/stego_985.png (stored 0%)
#   adding: content/One_block_shuffling/clean_804.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1895.png (stored 0%)
#   adding: content/One_block_shuffling/clean_74.png (stored 0%)
#   adding: content/One_block_shuffling/clean_966.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1127.png (stored 0%)
#   adding: content/One_block_shuffling/clean_626.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_10.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1188.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1310.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1141.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1324.png (stored 0%)
#   adding: content/One_block_shuffling/clean_386.png (stored 0%)
#   adding: content/One_block_shuffling/stego_371.png (stored 0%)
#   adding: content/One_block_shuffling/stego_427.png (stored 0%)
#   adding: content/One_block_shuffling/clean_638.png (stored 0%)
#   adding: content/One_block_shuffling/clean_479.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1383.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1757.png (stored 0%)
#   adding: content/One_block_shuffling/clean_523.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_553.png (stored 0%)
#   adding: content/One_block_shuffling/clean_3.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1721.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1789.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_943.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1451.png (stored 0%)
#   adding: content/One_block_shuffling/clean_475.png (deflated 2%)
#   adding: content/One_block_shuffling/clean_1457.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_1132.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1851.png (stored 0%)
#   adding: content/One_block_shuffling/stego_163.png (stored 0%)
#   adding: content/One_block_shuffling/stego_107.png (stored 0%)
#   adding: content/One_block_shuffling/clean_886.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1913.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1164.png (stored 0%)
#   adding: content/One_block_shuffling/clean_787.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1495.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1811.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1893.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1971.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1616.png (stored 0%)
#   adding: content/One_block_shuffling/stego_458.png (stored 0%)
#   adding: content/One_block_shuffling/clean_506.png (stored 0%)
#   adding: content/One_block_shuffling/stego_347.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1147.png (stored 0%)
#   adding: content/One_block_shuffling/clean_391.png (stored 0%)
#   adding: content/One_block_shuffling/clean_800.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1042.png (stored 0%)
#   adding: content/One_block_shuffling/stego_468.png (stored 0%)
#   adding: content/One_block_shuffling/stego_208.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1596.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1862.png (stored 0%)
#   adding: content/One_block_shuffling/stego_412.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1899.png (stored 0%)
#   adding: content/One_block_shuffling/clean_31.png (stored 0%)
#   adding: content/One_block_shuffling/stego_70.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1705.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_946.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1873.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1201.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1697.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1128.png (stored 0%)
#   adding: content/One_block_shuffling/clean_247.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_110.png (stored 0%)
#   adding: content/One_block_shuffling/stego_33.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1566.png (stored 0%)
#   adding: content/One_block_shuffling/stego_465.png (stored 0%)
#   adding: content/One_block_shuffling/stego_921.png (stored 0%)
#   adding: content/One_block_shuffling/clean_141.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1355.png (stored 0%)
#   adding: content/One_block_shuffling/stego_124.png (stored 0%)
#   adding: content/One_block_shuffling/clean_437.png (stored 0%)
#   adding: content/One_block_shuffling/stego_856.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1595.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1720.png (stored 0%)
#   adding: content/One_block_shuffling/clean_989.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1594.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1498.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1256.png (stored 0%)
#   adding: content/One_block_shuffling/stego_809.png (stored 0%)
#   adding: content/One_block_shuffling/clean_245.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1708.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1623.png (stored 0%)
#   adding: content/One_block_shuffling/stego_593.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1888.png (stored 0%)
#   adding: content/One_block_shuffling/clean_240.png (stored 0%)
#   adding: content/One_block_shuffling/clean_178.png (deflated 6%)
#   adding: content/One_block_shuffling/stego_1297.png (stored 0%)
#   adding: content/One_block_shuffling/stego_147.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1624.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_249.png (stored 0%)
#   adding: content/One_block_shuffling/clean_234.png (stored 0%)
#   adding: content/One_block_shuffling/stego_815.png (stored 0%)
#   adding: content/One_block_shuffling/stego_802.png (stored 0%)
#   adding: content/One_block_shuffling/clean_762.png (stored 0%)
#   adding: content/One_block_shuffling/clean_923.png (stored 0%)
#   adding: content/One_block_shuffling/stego_37.png (stored 0%)
#   adding: content/One_block_shuffling/stego_337.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1169.png (stored 0%)
#   adding: content/One_block_shuffling/stego_30.png (stored 0%)
#   adding: content/One_block_shuffling/stego_992.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1404.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1354.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1525.png (stored 0%)
#   adding: content/One_block_shuffling/stego_9.png (stored 0%)
#   adding: content/One_block_shuffling/stego_541.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1979.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1669.png (stored 0%)
#   adding: content/One_block_shuffling/clean_766.png (stored 0%)
#   adding: content/One_block_shuffling/clean_271.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_253.png (stored 0%)
#   adding: content/One_block_shuffling/clean_854.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1838.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1230.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1278.png (stored 0%)
#   adding: content/One_block_shuffling/clean_961.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_844.png (stored 0%)
#   adding: content/One_block_shuffling/stego_463.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1014.png (stored 0%)
#   adding: content/One_block_shuffling/stego_631.png (stored 0%)
#   adding: content/One_block_shuffling/clean_992.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1292.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1762.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1232.png (stored 0%)
#   adding: content/One_block_shuffling/clean_635.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_529.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1981.png (stored 0%)
#   adding: content/One_block_shuffling/clean_563.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_304.png (stored 0%)
#   adding: content/One_block_shuffling/clean_406.png (stored 0%)
#   adding: content/One_block_shuffling/stego_420.png (stored 0%)
#   adding: content/One_block_shuffling/stego_160.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1108.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1909.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1640.png (stored 0%)
#   adding: content/One_block_shuffling/stego_662.png (stored 0%)
#   adding: content/One_block_shuffling/clean_387.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1665.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1743.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1453.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1260.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1417.png (stored 0%)
#   adding: content/One_block_shuffling/stego_743.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1742.png (stored 0%)
#   adding: content/One_block_shuffling/stego_415.png (stored 0%)
#   adding: content/One_block_shuffling/clean_400.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_388.png (stored 0%)
#   adding: content/One_block_shuffling/stego_598.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1849.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_1696.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1521.png (stored 0%)
#   adding: content/One_block_shuffling/stego_387.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1231.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1139.png (stored 0%)
#   adding: content/One_block_shuffling/stego_488.png (stored 0%)
#   adding: content/One_block_shuffling/stego_876.png (stored 0%)
#   adding: content/One_block_shuffling/clean_541.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1152.png (stored 0%)
#   adding: content/One_block_shuffling/clean_723.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1546.png (stored 0%)
#   adding: content/One_block_shuffling/stego_601.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1266.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1848.png (stored 0%)
#   adding: content/One_block_shuffling/clean_612.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_1499.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1364.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_750.png (stored 0%)
#   adding: content/One_block_shuffling/clean_858.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1719.png (stored 0%)
#   adding: content/One_block_shuffling/stego_751.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1072.png (stored 0%)
#   adding: content/One_block_shuffling/stego_418.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1358.png (stored 0%)
#   adding: content/One_block_shuffling/clean_352.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_1625.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1642.png (deflated 2%)
#   adding: content/One_block_shuffling/stego_119.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1608.png (stored 0%)
#   adding: content/One_block_shuffling/stego_561.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1706.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1934.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1214.png (stored 0%)
#   adding: content/One_block_shuffling/stego_585.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1045.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1176.png (stored 0%)
#   adding: content/One_block_shuffling/stego_892.png (stored 0%)
#   adding: content/One_block_shuffling/clean_110.png (stored 0%)
#   adding: content/One_block_shuffling/clean_755.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_1281.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1469.png (stored 0%)
#   adding: content/One_block_shuffling/stego_231.png (stored 0%)
#   adding: content/One_block_shuffling/stego_438.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1591.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1213.png (stored 0%)
#   adding: content/One_block_shuffling/stego_533.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1138.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_235.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_1189.png (stored 0%)
#   adding: content/One_block_shuffling/stego_871.png (stored 0%)
#   adding: content/One_block_shuffling/clean_364.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_584.png (deflated 2%)
#   adding: content/One_block_shuffling/stego_1978.png (stored 0%)
#   adding: content/One_block_shuffling/stego_413.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1712.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1455.png (deflated 2%)
#   adding: content/One_block_shuffling/stego_1259.png (stored 0%)
#   adding: content/One_block_shuffling/stego_131.png (stored 0%)
#   adding: content/One_block_shuffling/stego_432.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1963.png (stored 0%)
#   adding: content/One_block_shuffling/stego_796.png (stored 0%)
#   adding: content/One_block_shuffling/clean_316.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1390.png (stored 0%)
#   adding: content/One_block_shuffling/stego_519.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1930.png (stored 0%)
#   adding: content/One_block_shuffling/clean_540.png (stored 0%)
#   adding: content/One_block_shuffling/stego_213.png (stored 0%)
#   adding: content/One_block_shuffling/stego_83.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1678.png (stored 0%)
#   adding: content/One_block_shuffling/stego_618.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1813.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1305.png (stored 0%)
#   adding: content/One_block_shuffling/clean_372.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1219.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1754.png (stored 0%)
#   adding: content/One_block_shuffling/clean_89.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1629.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1247.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1541.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1787.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1447.png (stored 0%)
#   adding: content/One_block_shuffling/stego_142.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1342.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1582.png (stored 0%)
#   adding: content/One_block_shuffling/clean_309.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_1228.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1331.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1636.png (stored 0%)
#   adding: content/One_block_shuffling/stego_197.png (stored 0%)
#   adding: content/One_block_shuffling/stego_284.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1722.png (stored 0%)
#   adding: content/One_block_shuffling/clean_123.png (stored 0%)
#   adding: content/One_block_shuffling/clean_805.png (stored 0%)
#   adding: content/One_block_shuffling/clean_277.png (stored 0%)
#   adding: content/One_block_shuffling/clean_323.png (stored 0%)
#   adding: content/One_block_shuffling/clean_763.png (stored 0%)
#   adding: content/One_block_shuffling/stego_451.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1481.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1780.png (stored 0%)
#   adding: content/One_block_shuffling/stego_783.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1007.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1054.png (stored 0%)
#   adding: content/One_block_shuffling/clean_802.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1538.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1344.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1450.png (stored 0%)
#   adding: content/One_block_shuffling/stego_863.png (stored 0%)
#   adding: content/One_block_shuffling/clean_527.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_656.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1000.png (stored 0%)
#   adding: content/One_block_shuffling/stego_274.png (stored 0%)
#   adding: content/One_block_shuffling/stego_293.png (stored 0%)
#   adding: content/One_block_shuffling/clean_742.png (stored 0%)
#   adding: content/One_block_shuffling/stego_104.png (stored 0%)
#   adding: content/One_block_shuffling/stego_444.png (stored 0%)
#   adding: content/One_block_shuffling/stego_167.png (stored 0%)
#   adding: content/One_block_shuffling/clean_905.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_639.png (stored 0%)
#   adding: content/One_block_shuffling/stego_730.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1227.png (stored 0%)
#   adding: content/One_block_shuffling/clean_248.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_1201.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_359.png (stored 0%)
#   adding: content/One_block_shuffling/stego_285.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1023.png (stored 0%)
#   adding: content/One_block_shuffling/clean_831.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_725.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1295.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_1364.png (stored 0%)
#   adding: content/One_block_shuffling/clean_22.png (stored 0%)
#   adding: content/One_block_shuffling/clean_431.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1054.png (stored 0%)
#   adding: content/One_block_shuffling/clean_231.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1387.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1441.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1934.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_958.png (stored 0%)
#   adding: content/One_block_shuffling/clean_868.png (stored 0%)
#   adding: content/One_block_shuffling/stego_419.png (stored 0%)
#   adding: content/One_block_shuffling/clean_953.png (stored 0%)
#   adding: content/One_block_shuffling/stego_530.png (stored 0%)
#   adding: content/One_block_shuffling/stego_771.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1783.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1538.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1805.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1020.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1546.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_764.png (stored 0%)
#   adding: content/One_block_shuffling/stego_397.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1553.png (stored 0%)
#   adding: content/One_block_shuffling/stego_170.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1644.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1230.png (stored 0%)
#   adding: content/One_block_shuffling/stego_157.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1102.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1104.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1791.png (stored 0%)
#   adding: content/One_block_shuffling/clean_679.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1045.png (stored 0%)
#   adding: content/One_block_shuffling/stego_179.png (stored 0%)
#   adding: content/One_block_shuffling/clean_101.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1925.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1204.png (stored 0%)
#   adding: content/One_block_shuffling/clean_949.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1386.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_1778.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1345.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1037.png (stored 0%)
#   adding: content/One_block_shuffling/clean_547.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1892.png (stored 0%)
#   adding: content/One_block_shuffling/clean_458.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1321.png (stored 0%)
#   adding: content/One_block_shuffling/clean_710.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1167.png (stored 0%)
#   adding: content/One_block_shuffling/clean_785.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1822.png (stored 0%)
#   adding: content/One_block_shuffling/stego_489.png (stored 0%)
#   adding: content/One_block_shuffling/clean_942.png (stored 0%)
#   adding: content/One_block_shuffling/clean_873.png (stored 0%)
#   adding: content/One_block_shuffling/clean_846.png (stored 0%)
#   adding: content/One_block_shuffling/clean_151.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1914.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_1799.png (deflated 2%)
#   adding: content/One_block_shuffling/clean_1729.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1258.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1449.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_76.png (stored 0%)
#   adding: content/One_block_shuffling/clean_261.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1800.png (deflated 2%)
#   adding: content/One_block_shuffling/clean_1855.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1202.png (stored 0%)
#   adding: content/One_block_shuffling/stego_166.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1991.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1741.png (stored 0%)
#   adding: content/One_block_shuffling/stego_819.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1627.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1144.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1503.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1641.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_411.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1788.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1216.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1185.png (stored 0%)
# ...
#   adding: content/One_block_shuffling/stego_204.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1285.png (stored 0%)
#   adding: content/One_block_shuffling/clean_900.png (stored 0%)
#   adding: content/One_block_shuffling/clean_125.png (stored 0%)
#   adding: content/One_block_shuffling/clean_944.png (stored 0%)
#   adding: content/One_block_shuffling/clean_998.png (stored 0%)
#   adding: content/One_block_shuffling/stego_407.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1833.png (stored 0%)
#   adding: content/One_block_shuffling/clean_724.png (stored 0%)
#   adding: content/One_block_shuffling/clean_497.png (deflated 5%)
#   adding: content/One_block_shuffling/clean_366.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1863.png (stored 0%)
#   adding: content/One_block_shuffling/stego_735.png (stored 0%)
#   adding: content/One_block_shuffling/stego_893.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1905.png (stored 0%)
#   adding: content/One_block_shuffling/stego_60.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1112.png (stored 0%)
#   adding: content/One_block_shuffling/clean_380.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_600.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1566.png (stored 0%)
#   adding: content/One_block_shuffling/clean_738.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1483.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1516.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1536.png (stored 0%)
#   adding: content/One_block_shuffling/clean_534.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1148.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_50.png (stored 0%)
#   adding: content/One_block_shuffling/stego_342.png (stored 0%)
#   adding: content/One_block_shuffling/clean_665.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1589.png (stored 0%)
#   adding: content/One_block_shuffling/clean_159.png (stored 0%)
#   adding: content/One_block_shuffling/clean_314.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1686.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1010.png (stored 0%)
#   adding: content/One_block_shuffling/clean_126.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1602.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1471.png (deflated 9%)
#   adding: content/One_block_shuffling/clean_71.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1182.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1445.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1249.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1746.png (stored 0%)
#   adding: content/One_block_shuffling/clean_273.png (deflated 3%)
#   adding: content/One_block_shuffling/stego_257.png (stored 0%)
#   adding: content/One_block_shuffling/clean_375.png (stored 0%)
#   adding: content/One_block_shuffling/clean_963.png (stored 0%)
#   adding: content/One_block_shuffling/clean_115.png (stored 0%)
#   adding: content/One_block_shuffling/stego_93.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1739.png (stored 0%)
#   adding: content/One_block_shuffling/clean_165.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1894.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1651.png (stored 0%)
#   adding: content/One_block_shuffling/clean_363.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1904.png (stored 0%)
#   adding: content/One_block_shuffling/stego_842.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1207.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1132.png (stored 0%)
#   adding: content/One_block_shuffling/clean_428.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1707.png (stored 0%)
#   adding: content/One_block_shuffling/clean_196.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1408.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1115.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1389.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1777.png (stored 0%)
#   adding: content/One_block_shuffling/stego_226.png (stored 0%)
#   adding: content/One_block_shuffling/stego_749.png (stored 0%)
#   adding: content/One_block_shuffling/stego_54.png (stored 0%)
#   adding: content/One_block_shuffling/stego_501.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1124.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1064.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_256.png (stored 0%)
#   adding: content/One_block_shuffling/clean_66.png (deflated 4%)
#   adding: content/One_block_shuffling/stego_1804.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1411.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_1053.png (stored 0%)
#   adding: content/One_block_shuffling/stego_698.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1932.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1056.png (stored 0%)
#   adding: content/One_block_shuffling/stego_238.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1776.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1811.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1748.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1910.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1351.png (stored 0%)
#   adding: content/One_block_shuffling/clean_343.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1222.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1635.png (stored 0%)
#   adding: content/One_block_shuffling/clean_937.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_570.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1567.png (deflated 2%)
#   adding: content/One_block_shuffling/stego_345.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1332.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_271.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1403.png (stored 0%)
#   adding: content/One_block_shuffling/clean_337.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1484.png (stored 0%)
#   adding: content/One_block_shuffling/clean_656.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_94.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1698.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1455.png (stored 0%)
#   adding: content/One_block_shuffling/clean_427.png (stored 0%)
#   adding: content/One_block_shuffling/clean_595.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1427.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_1725.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_155.png (stored 0%)
#   adding: content/One_block_shuffling/clean_714.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_339.png (stored 0%)
#   adding: content/One_block_shuffling/stego_562.png (stored 0%)
#   adding: content/One_block_shuffling/stego_421.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1671.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1235.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_984.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1717.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1853.png (stored 0%)
#   adding: content/One_block_shuffling/stego_516.png (stored 0%)
#   adding: content/One_block_shuffling/clean_488.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1568.png (stored 0%)
#   adding: content/One_block_shuffling/stego_450.png (stored 0%)
#   adding: content/One_block_shuffling/clean_817.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_165.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1828.png (stored 0%)
#   adding: content/One_block_shuffling/clean_775.png (deflated 2%)
#   adding: content/One_block_shuffling/stego_1586.png (stored 0%)
#   adding: content/One_block_shuffling/stego_942.png (stored 0%)
#   adding: content/One_block_shuffling/clean_933.png (stored 0%)
#   adding: content/One_block_shuffling/clean_455.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_336.png (stored 0%)
#   adding: content/One_block_shuffling/stego_707.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1684.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1123.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1737.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1288.png (stored 0%)
#   adding: content/One_block_shuffling/clean_877.png (deflated 4%)
#   adding: content/One_block_shuffling/clean_1776.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1186.png (stored 0%)
#   adding: content/One_block_shuffling/clean_834.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1312.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1936.png (stored 0%)
#   adding: content/One_block_shuffling/stego_193.png (stored 0%)
#   adding: content/One_block_shuffling/stego_65.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1086.png (stored 0%)
#   adding: content/One_block_shuffling/stego_543.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1859.png (stored 0%)
#   adding: content/One_block_shuffling/stego_201.png (stored 0%)
#   adding: content/One_block_shuffling/stego_243.png (stored 0%)
#   adding: content/One_block_shuffling/stego_459.png (stored 0%)
#   adding: content/One_block_shuffling/clean_416.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1598.png (stored 0%)
#   adding: content/One_block_shuffling/clean_211.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_59.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1747.png (stored 0%)
#   adding: content/One_block_shuffling/clean_889.png (stored 0%)
#   adding: content/One_block_shuffling/clean_217.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1328.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1448.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1531.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1961.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1025.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1665.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1439.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_682.png (stored 0%)
#   adding: content/One_block_shuffling/clean_113.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1707.png (deflated 9%)
#   adding: content/One_block_shuffling/stego_913.png (stored 0%)
#   adding: content/One_block_shuffling/clean_169.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1985.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1319.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_401.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1981.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1773.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_835.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1071.png (stored 0%)
#   adding: content/One_block_shuffling/clean_385.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1090.png (stored 0%)
#   adding: content/One_block_shuffling/stego_137.png (stored 0%)
#   adding: content/One_block_shuffling/clean_197.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1352.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1181.png (stored 0%)
#   adding: content/One_block_shuffling/stego_184.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1004.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_21.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_241.png (stored 0%)
#   adding: content/One_block_shuffling/stego_680.png (stored 0%)
#   adding: content/One_block_shuffling/clean_694.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1816.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_1484.png (stored 0%)
#   adding: content/One_block_shuffling/stego_918.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1758.png (stored 0%)
#   adding: content/One_block_shuffling/clean_230.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_1057.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1362.png (stored 0%)
#   adding: content/One_block_shuffling/clean_890.png (deflated 1%)
#   adding: content/One_block_shuffling/clean_1327.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_244.png (stored 0%)
#   adding: content/One_block_shuffling/clean_195.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_437.png (stored 0%)
#   adding: content/One_block_shuffling/clean_44.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1357.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1756.png (stored 0%)
#   adding: content/One_block_shuffling/stego_461.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1793.png (stored 0%)
#   adding: content/One_block_shuffling/clean_114.png (deflated 7%)
#   adding: content/One_block_shuffling/stego_1727.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1032.png (stored 0%)
#   adding: content/One_block_shuffling/stego_574.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1088.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_1901.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1621.png (stored 0%)
#   adding: content/One_block_shuffling/clean_449.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_929.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1771.png (stored 0%)
#   adding: content/One_block_shuffling/clean_85.png (stored 0%)
#   adding: content/One_block_shuffling/stego_635.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1561.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_664.png (stored 0%)
#   adding: content/One_block_shuffling/stego_509.png (stored 0%)
#   adding: content/One_block_shuffling/stego_744.png (stored 0%)
#   adding: content/One_block_shuffling/stego_757.png (stored 0%)
#   adding: content/One_block_shuffling/clean_471.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_1262.png (deflated 3%)
#   adding: content/One_block_shuffling/stego_729.png (stored 0%)
#   adding: content/One_block_shuffling/clean_502.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_479.png (stored 0%)
#   adding: content/One_block_shuffling/stego_916.png (stored 0%)
#   adding: content/One_block_shuffling/stego_935.png (stored 0%)
#   adding: content/One_block_shuffling/clean_92.png (deflated 1%)
#   adding: content/One_block_shuffling/stego_8.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1346.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1056.png (stored 0%)
#   adding: content/One_block_shuffling/stego_897.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1396.png (stored 0%)
#   adding: content/One_block_shuffling/clean_562.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_557.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1686.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1221.png (stored 0%)
#   adding: content/One_block_shuffling/clean_48.png (stored 0%)
#   adding: content/One_block_shuffling/stego_447.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1663.png (deflated 0%)
#   adding: content/One_block_shuffling/clean_425.png (stored 0%)
#   adding: content/One_block_shuffling/clean_1868.png (stored 0%)
#   adding: content/One_block_shuffling/clean_917.png (stored 0%)
#   adding: content/One_block_shuffling/clean_959.png (deflated 0%)
#   adding: content/One_block_shuffling/stego_51.png (stored 0%)
#   adding: content/One_block_shuffling/stego_462.png (stored 0%)
#   adding: content/One_block_shuffling/stego_1149.png (stored 0%)
#   adding: content/One_block_shuffling/stego_348.png (stored 0%)

# %% [markdown]
# ## Four Block Shuffling

# %%
# Variable used to weight the losses of the secret and cover images (See paper for more details)
beta = 1.0

# Loss for reveal network
def rev_loss(y_true, y_pred):
    # Loss for reveal network is: beta * |S-S'|
    return beta * K.sum(K.square(y_true - y_pred))

# Loss for the full model, used for preparation and hidding networks
def full_loss(y_true, y_pred):
    # Loss for the full model is: |C-C'| + beta * |S-S'|
    s_true, c_true = y_true[:,:,:,0:3], y_true[:,:,:,3:6]
    s_pred, c_pred = y_pred[:,:,:,0:3], y_pred[:,:,:,3:6]
    s_loss = K.sum(K.square(s_true - s_pred))
    c_loss = K.sum(K.square(c_true - c_pred))
    return s_loss + c_loss


# Returns the encoder as a Keras model, composed by Preparation and Hiding Networks.
def make_encoder(input_size):

    input_S = Input(shape=(input_size))
    input_C= Input(shape=(input_size))
    input_K = Input(shape=(total_block,))

    batch_size = tf.shape(input_S)[0]

    blocks = tf.image.extract_patches(input_S,sizes=[1,block_size,block_size,1],strides=[1,block_size,block_size,1],rates=[1, 1, 1, 1],padding='VALID')
    blocks = tf.reshape(blocks,[batch_size, total_block, block_size, block_size, 3])

    integer_K = tf.dtypes.cast(input_K, tf.int32)
    i1 = tf.expand_dims(tf.range(batch_size), axis = 1)
    i1 = tf.tile(i1, [1, total_block])
    indices = tf.stack([i1,integer_K], axis=-1)

    scattered = tf.scatter_nd(indices, blocks, (batch_size, total_block, block_size, block_size,3 ))

    scattered_blocks = tf.unstack(scattered, axis =1)
    scattered_tensor_row_wise = [tf.concat(scattered_blocks[i:i+block_in_one_axis], axis = -2) for i in tf.range(0,total_block,block_in_one_axis)]
    x = concatenate(scattered_tensor_row_wise, axis = 1)



    # Preparation Network
    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_prep0_3x3')(x) #changed
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_prep0_4x4')(x) #changed
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_prep0_5x5')(x) #changed
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_prep1_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_prep1_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_prep1_5x5')(x)
    x = concatenate([x3, x4, x5])

    x = concatenate([input_C, x])

    # Hiding network
    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid0_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid0_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid0_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid1_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid1_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid1_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid2_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid2_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid2_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid3_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid3_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid3_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid4_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid4_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid5_5x5')(x)
    x = concatenate([x3, x4, x5])

    output_Cprime = Conv2D(3, (3, 3), strides = (1, 1), padding='same', activation='relu', name='output_C')(x)

    return Model(inputs=[input_S, input_C, input_K], #changed
                 outputs=output_Cprime,
                 name = 'Encoder')

# Returns the decoder as a Keras model, composed by the Reveal Network
def make_decoder(input_size, fixed=False):
    # Reveal network
    reveal_input = Input(shape=(input_size))
    input_K = Input(shape=(total_block,))

    batch_size = tf.shape(reveal_input)[0]
    # Adding Gaussian noise with 0.01 standard deviation.
    input_with_noise = GaussianNoise(0.01, name='output_C_noise')(reveal_input) #changed

    x = input_with_noise
    #x = concatenate([input_with_noise, input_K])
    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev0_3x3')(x) #changed
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev0_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev0_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev1_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev1_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev1_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev2_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev2_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev2_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev3_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev3_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev3_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev4_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev4_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev5_5x5')(x)
    x = concatenate([x3, x4, x5])

    x = Conv2D(3, (3, 3), strides = (1, 1), padding='same', activation='relu', name='output_S')(x)

    scattered_tensor = x
    blocks = tf.image.extract_patches(scattered_tensor,sizes=[1,block_size,block_size,1],strides=[1,block_size,block_size,1],rates=[1, 1, 1, 1],padding='VALID')
    blocks = tf.reshape(blocks,[batch_size,total_block,block_size,block_size,3])

    integer_K = tf.dtypes.cast(input_K, tf.int32)

    i1 = tf.expand_dims(tf.range(batch_size), axis = 1)
    i1 = tf.tile(i1, [1, total_block])
    indices = tf.stack([i1,integer_K], axis=-1)

    unscattered = tf.gather_nd(blocks,indices)

    unscattered_blocks = tf.unstack(unscattered, axis =1)
    unscattered_tensor_row_wise = [tf.concat(unscattered_blocks[i:i+block_in_one_axis], axis = -2) for i in range(0,total_block,block_in_one_axis)]
    output_Sprime = concatenate(unscattered_tensor_row_wise, axis = 1)


    if not fixed:
        return Model(inputs=[reveal_input,input_K],
                     outputs=output_Sprime,
                     name = 'Decoder')
    # else:
    #     return Container(inputs=reveal_input,
    #                      outputs=output_Sprime,
    #                      name = 'DecoderFixed')                    # Changed
    else:
      return Network(inputs=[reveal_input,input_K],   #changed
                      outputs=output_Sprime,
                      name = 'DecoderFixed')

# Full model.
def make_model(input_size):
    # Calculations for dividing into blocks

    input_S = Input(shape=(input_size))
    input_C= Input(shape=(input_size))
    input_K = Input(shape=(total_block,))


    encoder = make_encoder(input_size)

    decoder = make_decoder(input_size)
    decoder.compile(optimizer='adam', loss=rev_loss)
    decoder.trainable = False

    output_Cprime = encoder([input_S, input_C, input_K]) #changed
    output_Sprime = decoder([output_Cprime, input_K]) #changed

    autoencoder = Model(inputs=[input_S, input_C, input_K],
                        outputs=concatenate([output_Sprime, output_Cprime]))
    autoencoder.compile(optimizer='adam', loss=full_loss)
    return encoder, decoder, autoencoder

# %%
# Block size to fragment the image
block_size = 4
block_in_one_axis =  64 // block_size
total_block = block_in_one_axis * block_in_one_axis

# %%
encoder_model, reveal_model, autoencoder_model = make_model(input_S.shape[1:])
autoencoder_model.load_weights('/content/drive/My Drive/Final_Model/four_block_shuffling/four_block_shuffling_autoencoder_model_100k_50e.hdf5')
encoder_model.load_weights('/content/drive/My Drive/Final_Model/four_block_shuffling/four_block_shuffling_encoder_model_100k_50e.hdf5')
reveal_model.load_weights('/content/drive/My Drive/Final_Model/four_block_shuffling/four_block_shuffling_reveal_model_100k_50e.hdf5')

# %%
# !mkdir "/content/Four_block_shuffling"

# %%
from google.colab import files
from cv2 import cv2
from tqdm import tqdm
from PIL import Image
import matplotlib

secret=X_test[0:2000]
cover=X_test[2000:4000]



input_K = np.zeros(shape=(len(secret), total_block))
for i in range(len(secret)):
    input_K[i] = random.sample(range(0, total_block), total_block)

C_prime = encoder_model.predict([secret, cover, input_K])

i=1
for c in tqdm(cover):
  matplotlib.image.imsave('/content/Four_block_shuffling/clean_'+str(i)+'.png',c)
  i= i+1

i=1
for s in tqdm(C_prime):
  s = s.clip(min = 0, max =1)
  matplotlib.image.imsave('/content/Four_block_shuffling/stego_'+str(i)+'.png',s)

  i= i+1
# Out:
# 100%|██████████| 2000/2000 [00:04<00:00, 412.69it/s]
# 100%|██████████| 2000/2000 [00:04<00:00, 405.55it/s]

# %%
# !zip -r /content/Four_block_shuffling.zip /content/Four_block_shuffling
from google.colab import files
files.download("/content/Four_block_shuffling.zip")
# Out:
#   adding: content/Four_block_shuffling/ (stored 0%)
#   adding: content/Four_block_shuffling/stego_690.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1950.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_899.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1851.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_21.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1400.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1638.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_640.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_930.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1883.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_16.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1369.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_39.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_566.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_13.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1330.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1233.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_375.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1260.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_429.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1126.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1912.png (deflated 2%)
#   adding: content/Four_block_shuffling/stego_950.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1196.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1329.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1826.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1622.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_1192.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_1600.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1788.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1806.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_820.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1702.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1890.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_303.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_631.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_17.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_965.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1310.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1829.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1531.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_891.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_383.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_315.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1029.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_591.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1850.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_279.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1890.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_450.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1986.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1675.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1155.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_813.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1122.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_485.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_815.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1028.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1246.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_1741.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1148.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1475.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1647.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_42.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_51.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1460.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1142.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1556.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1753.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_972.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1922.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_291.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_768.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_975.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_551.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_278.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_220.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1489.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1028.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_136.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1122.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1488.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_744.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_662.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_1664.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_758.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1210.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_952.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_149.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_983.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1678.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1993.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_394.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_1409.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_985.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_538.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_790.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1402.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1413.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_869.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1664.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_584.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_676.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_432.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_374.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_525.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_608.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1326.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_5.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_637.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_252.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_275.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_773.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_655.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1567.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_494.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_860.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1662.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_185.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1784.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1708.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_309.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_473.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1990.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1126.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_190.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_312.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_320.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_798.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_246.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_499.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_982.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1088.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1505.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_615.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1441.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_509.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1863.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_684.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_586.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1016.png (deflated 8%)
#   adding: content/Four_block_shuffling/clean_350.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_734.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_2.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_861.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_896.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1816.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1157.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1371.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1812.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1269.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1973.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_435.png (deflated 2%)
#   adding: content/Four_block_shuffling/clean_1242.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1070.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_723.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_820.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_1536.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1501.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_468.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_205.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1514.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_340.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_1051.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_986.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_692.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1061.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_117.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1303.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_747.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_242.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1293.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_70.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_428.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_962.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1825.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_580.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_308.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_286.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1202.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_633.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1696.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1137.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_947.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1605.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_269.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_167.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1041.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1368.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_945.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1424.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1281.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1699.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_394.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_299.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1814.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1793.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_951.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_262.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1931.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1518.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1988.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1672.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_111.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_789.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1082.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1955.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_579.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1683.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_215.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_111.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1659.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1618.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1378.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1256.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_135.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1881.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_236.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1570.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1150.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1215.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1288.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_607.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_855.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_972.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1927.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_999.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1040.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1377.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1067.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1562.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1948.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_129.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1291.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1612.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1947.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1382.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1236.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1403.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_121.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1458.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_389.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1001.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1084.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1246.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_97.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_2000.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_1186.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_392.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1454.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1107.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1969.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_274.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1810.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1237.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_180.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1407.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_41.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_84.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1874.png (deflated 8%)
#   adding: content/Four_block_shuffling/stego_1572.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1597.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_350.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1959.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_281.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_436.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1786.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_979.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1091.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_305.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_514.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_189.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_706.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_745.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_592.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_831.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_176.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_889.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1172.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_614.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_67.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1160.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1472.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_195.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_550.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1135.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_38.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_651.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1183.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_967.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1845.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1532.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_845.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_669.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_499.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_145.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_757.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_1180.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1687.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_671.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1626.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_763.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_601.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_12.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1965.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_553.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1341.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_232.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_1772.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1836.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1815.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_221.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1946.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1308.png (deflated 2%)
#   adding: content/Four_block_shuffling/stego_1860.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1784.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_847.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_935.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1691.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_912.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_121.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_200.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_515.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1389.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1515.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_219.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_266.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1999.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1227.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_44.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_82.png (deflated 2%)
#   adding: content/Four_block_shuffling/clean_818.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_870.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_943.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_996.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1293.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_270.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1164.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1284.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_1898.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_860.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1182.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_733.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1059.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1841.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_219.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_418.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_1740.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_369.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1264.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_404.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_384.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1520.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_671.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_164.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_568.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_726.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1001.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1224.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1124.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_849.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1103.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_69.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_939.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_1063.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_1750.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_341.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_272.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_669.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1852.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_915.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_978.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1170.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1718.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1414.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_299.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1438.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1425.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_530.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1323.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1858.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_330.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_879.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_239.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1191.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_888.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1019.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_985.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_804.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1895.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_74.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_966.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1127.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_626.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_10.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1188.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1310.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1141.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1324.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_386.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_371.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_427.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_638.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_479.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1383.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1757.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_523.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_553.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_3.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1721.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1789.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_943.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1451.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_475.png (deflated 2%)
#   adding: content/Four_block_shuffling/clean_1457.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_1132.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1851.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_163.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_107.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_886.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1913.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1164.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_787.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1495.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1811.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1893.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1971.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1616.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_458.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_506.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_347.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1147.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_391.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_800.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1042.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_468.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_208.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1596.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1862.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_412.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1899.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_31.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_70.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1705.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_946.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1873.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1201.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1697.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1128.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_247.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_110.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_33.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1566.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_465.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_921.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_141.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1355.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_124.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_437.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_856.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1595.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1720.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_989.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1594.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1498.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1256.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_809.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_245.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1708.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1623.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_593.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1888.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_240.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_178.png (deflated 6%)
#   adding: content/Four_block_shuffling/stego_1297.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_147.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1624.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_249.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_234.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_815.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_802.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_762.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_923.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_37.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_337.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1169.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_30.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_992.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1404.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1354.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1525.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_9.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_541.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1979.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1669.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_766.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_271.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_253.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_854.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1838.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1230.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1278.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_961.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_844.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_463.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1014.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_631.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_992.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1292.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1762.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1232.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_635.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_529.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1981.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_563.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_304.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_406.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_420.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_160.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1108.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1909.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1640.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_662.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_387.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1665.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1743.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1453.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1260.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1417.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_743.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1742.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_415.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_400.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_388.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_598.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1849.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_1696.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1521.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_387.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1231.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1139.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_488.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_876.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_541.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1152.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_723.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1546.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_601.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1266.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1848.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_612.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_1499.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1364.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_750.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_858.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1719.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_751.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1072.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_418.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1358.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_352.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_1625.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1642.png (deflated 2%)
#   adding: content/Four_block_shuffling/stego_119.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1608.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_561.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1706.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1934.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1214.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_585.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1045.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1176.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_892.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_110.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_755.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_1281.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1469.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_231.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_438.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1591.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1213.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_533.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1138.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_235.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_1189.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_871.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_364.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_584.png (deflated 2%)
#   adding: content/Four_block_shuffling/stego_1978.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_413.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1712.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1455.png (deflated 2%)
#   adding: content/Four_block_shuffling/stego_1259.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_131.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_432.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1963.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_796.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_316.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1390.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_519.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1930.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_540.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_213.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_83.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1678.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_618.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1813.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1305.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_372.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1219.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1754.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_89.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1629.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1247.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1541.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1787.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1447.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_142.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1342.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1582.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_309.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_1228.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1331.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1636.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_197.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_284.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1722.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_123.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_805.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_277.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_323.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_763.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_451.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1481.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1780.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_783.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1007.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1054.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_802.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1538.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1344.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1450.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_863.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_527.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_656.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1000.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_274.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_293.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_742.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_104.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_444.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_167.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_905.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_639.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_730.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1227.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_248.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_1201.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_359.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_285.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1023.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_831.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_725.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1295.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_1364.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_22.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_431.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1054.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_231.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1387.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1441.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1934.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_958.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_868.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_419.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_953.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_530.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_771.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1783.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1538.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1805.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1020.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1546.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_764.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_397.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1553.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_170.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1644.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1230.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_157.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1102.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1104.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1791.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_679.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1045.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_179.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_101.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1925.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1204.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_949.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1386.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_1778.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1345.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1037.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_547.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1892.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_458.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1321.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_710.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1167.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_785.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1822.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_489.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_942.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_873.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_846.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_151.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1914.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_1799.png (deflated 2%)
#   adding: content/Four_block_shuffling/clean_1729.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1258.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1449.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_76.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_261.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1800.png (deflated 2%)
#   adding: content/Four_block_shuffling/clean_1855.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1202.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_166.png (stored 0%)
# ...
#   adding: content/Four_block_shuffling/clean_944.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_998.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_407.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1833.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_724.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_497.png (deflated 5%)
#   adding: content/Four_block_shuffling/clean_366.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1863.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_735.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_893.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1905.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_60.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1112.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_380.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_600.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1566.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_738.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1483.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1516.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1536.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_534.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1148.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_50.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_342.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_665.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1589.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_159.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_314.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1686.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1010.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_126.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1602.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1471.png (deflated 9%)
#   adding: content/Four_block_shuffling/clean_71.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1182.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1445.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1249.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1746.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_273.png (deflated 3%)
#   adding: content/Four_block_shuffling/stego_257.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_375.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_963.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_115.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_93.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1739.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_165.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1894.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1651.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_363.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1904.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_842.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1207.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1132.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_428.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1707.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_196.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1408.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1115.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1389.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1777.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_226.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_749.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_54.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_501.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1124.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1064.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_256.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_66.png (deflated 4%)
#   adding: content/Four_block_shuffling/stego_1804.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1411.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_1053.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_698.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1932.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1056.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_238.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1776.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1811.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1748.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1910.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1351.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_343.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1222.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1635.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_937.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_570.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1567.png (deflated 2%)
#   adding: content/Four_block_shuffling/stego_345.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1332.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_271.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1403.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_337.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1484.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_656.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_94.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1698.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1455.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_427.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_595.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1427.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_1725.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_155.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_714.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_339.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_562.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_421.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1671.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1235.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_984.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1717.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1853.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_516.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_488.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1568.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_450.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_817.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_165.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1828.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_775.png (deflated 2%)
#   adding: content/Four_block_shuffling/stego_1586.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_942.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_933.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_455.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_336.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_707.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1684.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1123.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1737.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1288.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_877.png (deflated 4%)
#   adding: content/Four_block_shuffling/clean_1776.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1186.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_834.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1312.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1936.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_193.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_65.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1086.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_543.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1859.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_201.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_243.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_459.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_416.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1598.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_211.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_59.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1747.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_889.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_217.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1328.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1448.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1531.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1961.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1025.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1665.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1439.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_682.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_113.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1707.png (deflated 9%)
#   adding: content/Four_block_shuffling/stego_913.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_169.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1985.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1319.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_401.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1981.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1773.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_835.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1071.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_385.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1090.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_137.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_197.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1352.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1181.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_184.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1004.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_21.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_241.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_680.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_694.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1816.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_1484.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_918.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1758.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_230.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_1057.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1362.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_890.png (deflated 1%)
#   adding: content/Four_block_shuffling/clean_1327.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_244.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_195.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_437.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_44.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1357.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1756.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_461.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1793.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_114.png (deflated 7%)
#   adding: content/Four_block_shuffling/stego_1727.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1032.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_574.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1088.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_1901.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1621.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_449.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_929.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1771.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_85.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_635.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1561.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_664.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_509.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_744.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_757.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_471.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_1262.png (deflated 3%)
#   adding: content/Four_block_shuffling/stego_729.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_502.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_479.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_916.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_935.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_92.png (deflated 1%)
#   adding: content/Four_block_shuffling/stego_8.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1346.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1056.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_897.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1396.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_562.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_557.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1686.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1221.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_48.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_447.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1663.png (deflated 0%)
#   adding: content/Four_block_shuffling/clean_425.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_1868.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_917.png (stored 0%)
#   adding: content/Four_block_shuffling/clean_959.png (deflated 0%)
#   adding: content/Four_block_shuffling/stego_51.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_462.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_1149.png (stored 0%)
#   adding: content/Four_block_shuffling/stego_348.png (stored 0%)

# %% [markdown]
# ##Eight Block Shuffling

# %%
# Variable used to weight the losses of the secret and cover images (See paper for more details)
beta = 1.0

# Loss for reveal network
def rev_loss(y_true, y_pred):
    # Loss for reveal network is: beta * |S-S'|
    return beta * K.sum(K.square(y_true - y_pred))

# Loss for the full model, used for preparation and hidding networks
def full_loss(y_true, y_pred):
    # Loss for the full model is: |C-C'| + beta * |S-S'|
    s_true, c_true = y_true[:,:,:,0:3], y_true[:,:,:,3:6]
    s_pred, c_pred = y_pred[:,:,:,0:3], y_pred[:,:,:,3:6]
    s_loss = K.sum(K.square(s_true - s_pred))
    c_loss = K.sum(K.square(c_true - c_pred))
    return s_loss + c_loss


# Returns the encoder as a Keras model, composed by Preparation and Hiding Networks.
def make_encoder(input_size):

    input_S = Input(shape=(input_size))
    input_C= Input(shape=(input_size))
    input_K= Input(shape=(total_block,))

    batch_size = tf.shape(input_S)[0]
    # print(tf.shape(input_S))
    # block_in_one_axis =  row // block_size
    # total_block = block_in_one_axis * block_in_one_axis


    blocks = tf.image.extract_patches(input_S,sizes=[1,block_size,block_size,1],strides=[1,block_size,block_size,1],rates=[1, 1, 1, 1],padding='VALID')
    blocks = tf.reshape(blocks,[batch_size, total_block, block_size, block_size, 3])

    integer_K = tf.dtypes.cast(input_K, tf.int32)
    i1 = tf.expand_dims(tf.range(batch_size), axis = 1)
    i1 = tf.tile(i1, [1, total_block])
    indices = tf.stack([i1,integer_K], axis=-1)

    scattered = tf.scatter_nd(indices, blocks, (batch_size, total_block, block_size, block_size,3 ))

    scattered_blocks = tf.unstack(scattered, axis =1)
    scattered_tensor_row_wise = [tf.concat(scattered_blocks[i:i+block_in_one_axis], axis = -2) for i in tf.range(0,total_block,block_in_one_axis)]
    x = tf.keras.layers.concatenate(scattered_tensor_row_wise, axis = 1)


    # Preparation Network
    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_prep0_3x3')(x) #changed
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_prep0_4x4')(x) #changed
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_prep0_5x5')(x) #changed
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_prep1_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_prep1_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_prep1_5x5')(x)
    x = concatenate([x3, x4, x5])

    x = concatenate([input_C, x])

    # Hiding network
    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid0_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid0_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid0_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid1_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid1_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid1_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid2_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid2_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid2_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid3_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid3_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid3_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid4_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid4_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid5_5x5')(x)
    x = concatenate([x3, x4, x5])

    output_Cprime = Conv2D(3, (3, 3), strides = (1, 1), padding='same', activation='relu', name='output_C')(x)

    return Model(inputs=[input_S, input_C, input_K], #changed
                  outputs=output_Cprime,
                  name = 'Encoder')

# Returns the decoder as a Keras model, composed by the Reveal Network
def make_decoder(input_size, fixed=False):
    reveal_input = Input(shape=(input_size))

    batch_size = tf.shape(reveal_input)[0]
    # print(tf.shape(reveal_input))
    # block_in_one_axis =  row // block_size
    # total_block = block_in_one_axis * block_in_one_axis

    input_K= Input(shape=(total_block,))


    # Adding Gaussian noise with 0.01 standard deviation.
    input_with_noise = GaussianNoise(0.01, name='output_C_noise')(reveal_input) #changed
    x = input_with_noise

    #x = concatenate([input_with_noise, input_K])
    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev0_3x3')(x) #changed
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev0_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev0_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev1_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev1_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev1_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev2_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev2_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev2_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev3_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev3_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev3_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev4_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev4_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev5_5x5')(x)
    x = concatenate([x3, x4, x5])

    x = Conv2D(3, (3, 3), strides = (1, 1), padding='same', activation='relu', name='output_S')(x)


    scattered_tensor = x
    blocks = tf.image.extract_patches(scattered_tensor,sizes=[1,block_size,block_size,1],strides=[1,block_size,block_size,1],rates=[1, 1, 1, 1],padding='VALID')
    blocks = tf.reshape(blocks,[batch_size,total_block,block_size,block_size,3])

    integer_K = tf.dtypes.cast(input_K, tf.int32)

    i1 = tf.expand_dims(tf.range(batch_size), axis = 1)
    i1 = tf.tile(i1, [1, total_block])
    indices = tf.stack([i1,integer_K], axis=-1)

    unscattered = tf.gather_nd(blocks,indices)

    unscattered_blocks = tf.unstack(unscattered, axis =1)
    unscattered_tensor_row_wise = [tf.concat(unscattered_blocks[i:i+block_in_one_axis], axis = -2) for i in range(0,total_block,block_in_one_axis)]
    output_Sprime = tf.keras.layers.concatenate(unscattered_tensor_row_wise, axis = 1)

    if not fixed:
        return Model(inputs=[reveal_input,input_K],
                     outputs=output_Sprime,
                     name = 'Decoder')
    # else:
    #     return Container(inputs=reveal_input,
    #                      outputs=output_Sprime,
    #                      name = 'DecoderFixed')                    # Changed
    else:
      return Network(inputs=[reveal_input,input_K],   #changed
                      outputs=output_Sprime,
                      name = 'DecoderFixed')

# Full model.
def make_model(input_size):

    input_S = Input(shape=(input_size))
    input_C= Input(shape=(input_size))
    input_K = Input(shape=(total_block,))

    encoder = make_encoder(input_size)

    decoder = make_decoder(input_size)
    decoder.compile(optimizer='adam', loss=rev_loss)
    decoder.trainable = False

    output_Cprime = encoder([input_S, input_C, input_K]) #changed
    output_Sprime = decoder([output_Cprime, input_K]) #changed

    autoencoder = Model(inputs=[input_S, input_C, input_K],
                        outputs=concatenate([output_Sprime, output_Cprime]))
    autoencoder.compile(optimizer='adam', loss=full_loss)
    return encoder, decoder, autoencoder

# %%
# Block size to fragment the image
block_size = 8
block_in_one_axis =  64 // block_size
total_block = block_in_one_axis * block_in_one_axis

# %%
encoder_model, reveal_model, autoencoder_model = make_model(input_S.shape[1:])
autoencoder_model.load_weights('/content/drive/My Drive/Final_Model/eight_block_shuffling/eight_block_shuffling_autoencoder_model_100k_50e.hdf5')
encoder_model.load_weights('/content/drive/My Drive/Final_Model/eight_block_shuffling/eight_block_shuffling_encoder_model_100k_50e.hdf5')
reveal_model.load_weights('/content/drive/My Drive/Final_Model/eight_block_shuffling/eight_block_shuffling_reveal_model_100k_50e.hdf5')

# %%
# !mkdir "/content/Eight_block_shuffling"

# %%
from google.colab import files
from cv2 import cv2
from tqdm import tqdm
from PIL import Image
import matplotlib

secret=X_test[0:2000]
cover=X_test[2000:4000]



input_K = np.zeros(shape=(len(secret), total_block))
for i in range(len(secret)):
    input_K[i] = random.sample(range(0, total_block), total_block)

C_prime = encoder_model.predict([secret, cover, input_K])

i=1
for c in tqdm(cover):
  matplotlib.image.imsave('/content/Eight_block_shuffling/clean_'+str(i)+'.png',c)
  i= i+1

i=1
for s in tqdm(C_prime):
  s = s.clip(min = 0, max =1)
  matplotlib.image.imsave('/content/Eight_block_shuffling/stego_'+str(i)+'.png',s)

  i= i+1
# Out:
# 100%|██████████| 2000/2000 [00:05<00:00, 370.74it/s]
# 100%|██████████| 2000/2000 [00:04<00:00, 409.96it/s]

# %%
# !zip -r /content/Eight_block_shuffling.zip /content/Eight_block_shuffling
from google.colab import files
files.download("/content/Eight_block_shuffling.zip")
# Out:
#   adding: content/Eight_block_shuffling/ (stored 0%)
#   adding: content/Eight_block_shuffling/stego_690.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1950.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_899.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1851.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_21.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1400.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1638.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_640.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_930.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1883.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_16.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1369.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_39.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_566.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_13.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1330.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1233.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_375.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1260.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_429.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1126.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1912.png (deflated 2%)
#   adding: content/Eight_block_shuffling/stego_950.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1196.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1329.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1826.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1622.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_1192.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_1600.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1788.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1806.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_820.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1702.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1890.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_303.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_631.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_17.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_965.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1310.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1829.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1531.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_891.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_383.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_315.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1029.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_591.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1850.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_279.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1890.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_450.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1986.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1675.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1155.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_813.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1122.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_485.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_815.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1028.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1246.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_1741.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1148.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1475.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1647.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_42.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_51.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1460.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1142.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1556.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1753.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_972.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1922.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_291.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_768.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_975.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_551.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_278.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_220.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1489.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1028.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_136.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1122.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1488.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_744.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_662.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_1664.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_758.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1210.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_952.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_149.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_983.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1678.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1993.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_394.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_1409.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_985.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_538.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_790.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1402.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1413.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_869.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1664.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_584.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_676.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_432.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_374.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_525.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_608.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1326.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_5.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_637.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_252.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_275.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_773.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_655.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1567.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_494.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_860.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1662.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_185.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1784.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1708.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_309.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_473.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1990.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1126.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_190.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_312.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_320.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_798.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_246.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_499.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_982.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1088.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1505.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_615.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1441.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_509.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1863.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_684.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_586.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1016.png (deflated 8%)
#   adding: content/Eight_block_shuffling/clean_350.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_734.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_2.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_861.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_896.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1816.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1157.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1371.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1812.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1269.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1973.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_435.png (deflated 2%)
#   adding: content/Eight_block_shuffling/clean_1242.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1070.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_723.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_820.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_1536.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1501.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_468.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_205.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1514.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_340.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_1051.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_986.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_692.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1061.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_117.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1303.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_747.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_242.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1293.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_70.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_428.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_962.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1825.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_580.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_308.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_286.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1202.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_633.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1696.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1137.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_947.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1605.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_269.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_167.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1041.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1368.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_945.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1424.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1281.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1699.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_394.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_299.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1814.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1793.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_951.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_262.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1931.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1518.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1988.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1672.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_111.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_789.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1082.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1955.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_579.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1683.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_215.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_111.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1659.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1618.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1378.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1256.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_135.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1881.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_236.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1570.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1150.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1215.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1288.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_607.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_855.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_972.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1927.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_999.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1040.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1377.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1067.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1562.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1948.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_129.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1291.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1612.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1947.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1382.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1236.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1403.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_121.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1458.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_389.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1001.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1084.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1246.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_97.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_2000.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_1186.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_392.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1454.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1107.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1969.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_274.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1810.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1237.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_180.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1407.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_41.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_84.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1874.png (deflated 8%)
#   adding: content/Eight_block_shuffling/stego_1572.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1597.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_350.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1959.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_281.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_436.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1786.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_979.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1091.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_305.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_514.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_189.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_706.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_745.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_592.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_831.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_176.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_889.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1172.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_614.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_67.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1160.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1472.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_195.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_550.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1135.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_38.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_651.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1183.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_967.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1845.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1532.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_845.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_669.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_499.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_145.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_757.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_1180.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1687.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_671.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1626.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_763.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_601.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_12.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1965.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_553.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1341.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_232.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_1772.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1836.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1815.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_221.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1946.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1308.png (deflated 2%)
#   adding: content/Eight_block_shuffling/stego_1860.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1784.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_847.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_935.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1691.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_912.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_121.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_200.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_515.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1389.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1515.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_219.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_266.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1999.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1227.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_44.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_82.png (deflated 2%)
#   adding: content/Eight_block_shuffling/clean_818.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_870.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_943.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_996.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1293.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_270.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1164.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1284.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_1898.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_860.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1182.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_733.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1059.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1841.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_219.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_418.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_1740.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_369.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1264.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_404.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_384.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1520.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_671.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_164.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_568.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_726.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1001.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1224.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1124.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_849.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1103.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_69.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_939.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_1063.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_1750.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_341.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_272.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_669.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1852.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_915.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_978.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1170.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1718.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1414.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_299.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1438.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1425.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_530.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1323.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1858.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_330.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_879.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_239.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1191.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_888.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1019.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_985.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_804.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1895.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_74.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_966.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1127.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_626.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_10.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1188.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1310.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1141.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1324.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_386.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_371.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_427.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_638.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_479.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1383.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1757.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_523.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_553.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_3.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1721.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1789.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_943.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1451.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_475.png (deflated 2%)
#   adding: content/Eight_block_shuffling/clean_1457.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_1132.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1851.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_163.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_107.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_886.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1913.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1164.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_787.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1495.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1811.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1893.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1971.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1616.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_458.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_506.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_347.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1147.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_391.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_800.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1042.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_468.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_208.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1596.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1862.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_412.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1899.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_31.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_70.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1705.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_946.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1873.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1201.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1697.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1128.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_247.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_110.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_33.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1566.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_465.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_921.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_141.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1355.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_124.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_437.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_856.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1595.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1720.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_989.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1594.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1498.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1256.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_809.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_245.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1708.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1623.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_593.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1888.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_240.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_178.png (deflated 6%)
#   adding: content/Eight_block_shuffling/stego_1297.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_147.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1624.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_249.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_234.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_815.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_802.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_762.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_923.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_37.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_337.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1169.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_30.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_992.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1404.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1354.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1525.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_9.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_541.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1979.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1669.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_766.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_271.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_253.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_854.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1838.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1230.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1278.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_961.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_844.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_463.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1014.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_631.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_992.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1292.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1762.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1232.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_635.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_529.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1981.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_563.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_304.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_406.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_420.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_160.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1108.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1909.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1640.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_662.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_387.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1665.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1743.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1453.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1260.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1417.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_743.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1742.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_415.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_400.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_388.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_598.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1849.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_1696.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1521.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_387.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1231.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1139.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_488.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_876.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_541.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1152.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_723.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1546.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_601.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1266.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1848.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_612.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_1499.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1364.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_750.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_858.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1719.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_751.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1072.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_418.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1358.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_352.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_1625.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1642.png (deflated 2%)
#   adding: content/Eight_block_shuffling/stego_119.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1608.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_561.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1706.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1934.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1214.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_585.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1045.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1176.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_892.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_110.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_755.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_1281.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1469.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_231.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_438.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1591.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1213.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_533.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1138.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_235.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_1189.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_871.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_364.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_584.png (deflated 2%)
#   adding: content/Eight_block_shuffling/stego_1978.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_413.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1712.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1455.png (deflated 2%)
#   adding: content/Eight_block_shuffling/stego_1259.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_131.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_432.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1963.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_796.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_316.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1390.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_519.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1930.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_540.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_213.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_83.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1678.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_618.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1813.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1305.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_372.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1219.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1754.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_89.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1629.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1247.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1541.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1787.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1447.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_142.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1342.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1582.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_309.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_1228.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1331.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1636.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_197.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_284.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1722.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_123.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_805.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_277.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_323.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_763.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_451.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1481.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1780.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_783.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1007.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1054.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_802.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1538.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1344.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1450.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_863.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_527.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_656.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1000.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_274.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_293.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_742.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_104.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_444.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_167.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_905.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_639.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_730.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1227.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_248.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_1201.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_359.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_285.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1023.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_831.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_725.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1295.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_1364.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_22.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_431.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1054.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_231.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1387.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1441.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1934.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_958.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_868.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_419.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_953.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_530.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_771.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1783.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1538.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1805.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1020.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1546.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_764.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_397.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1553.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_170.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1644.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1230.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_157.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1102.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1104.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1791.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_679.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1045.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_179.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_101.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1925.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1204.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_949.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1386.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_1778.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1345.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1037.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_547.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1892.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_458.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1321.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_710.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1167.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_785.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1822.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_489.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_942.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_873.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_846.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_151.png (deflated 0%)
# ...
#   adding: content/Eight_block_shuffling/clean_1833.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_724.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_497.png (deflated 5%)
#   adding: content/Eight_block_shuffling/clean_366.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1863.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_735.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_893.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1905.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_60.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1112.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_380.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_600.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1566.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_738.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1483.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1516.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1536.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_534.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1148.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_50.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_342.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_665.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1589.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_159.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_314.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1686.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1010.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_126.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1602.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1471.png (deflated 9%)
#   adding: content/Eight_block_shuffling/clean_71.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1182.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1445.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1249.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1746.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_273.png (deflated 3%)
#   adding: content/Eight_block_shuffling/stego_257.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_375.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_963.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_115.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_93.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1739.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_165.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1894.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1651.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_363.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1904.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_842.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1207.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1132.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_428.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1707.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_196.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1408.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1115.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1389.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1777.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_226.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_749.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_54.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_501.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1124.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1064.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_256.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_66.png (deflated 4%)
#   adding: content/Eight_block_shuffling/stego_1804.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1411.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_1053.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_698.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1932.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1056.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_238.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1776.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1811.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1748.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1910.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1351.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_343.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1222.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1635.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_937.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_570.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1567.png (deflated 2%)
#   adding: content/Eight_block_shuffling/stego_345.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1332.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_271.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1403.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_337.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1484.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_656.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_94.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1698.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1455.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_427.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_595.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1427.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_1725.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_155.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_714.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_339.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_562.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_421.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1671.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1235.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_984.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1717.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1853.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_516.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_488.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1568.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_450.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_817.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_165.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1828.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_775.png (deflated 2%)
#   adding: content/Eight_block_shuffling/stego_1586.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_942.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_933.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_455.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_336.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_707.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1684.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1123.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1737.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1288.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_877.png (deflated 4%)
#   adding: content/Eight_block_shuffling/clean_1776.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1186.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_834.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1312.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1936.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_193.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_65.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1086.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_543.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1859.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_201.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_243.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_459.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_416.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1598.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_211.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_59.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1747.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_889.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_217.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1328.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1448.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1531.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1961.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1025.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1665.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1439.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_682.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_113.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1707.png (deflated 9%)
#   adding: content/Eight_block_shuffling/stego_913.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_169.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1985.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1319.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_401.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1981.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1773.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_835.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1071.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_385.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1090.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_137.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_197.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1352.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1181.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_184.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1004.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_21.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_241.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_680.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_694.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1816.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_1484.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_918.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1758.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_230.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_1057.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1362.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_890.png (deflated 1%)
#   adding: content/Eight_block_shuffling/clean_1327.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_244.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_195.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_437.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_44.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1357.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1756.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_461.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1793.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_114.png (deflated 7%)
#   adding: content/Eight_block_shuffling/stego_1727.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1032.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_574.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1088.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_1901.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1621.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_449.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_929.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1771.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_85.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_635.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1561.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_664.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_509.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_744.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_757.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_471.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_1262.png (deflated 3%)
#   adding: content/Eight_block_shuffling/stego_729.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_502.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_479.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_916.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_935.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_92.png (deflated 1%)
#   adding: content/Eight_block_shuffling/stego_8.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1346.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1056.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_897.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1396.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_562.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_557.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1686.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1221.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_48.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_447.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1663.png (deflated 0%)
#   adding: content/Eight_block_shuffling/clean_425.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_1868.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_917.png (stored 0%)
#   adding: content/Eight_block_shuffling/clean_959.png (deflated 0%)
#   adding: content/Eight_block_shuffling/stego_51.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_462.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_1149.png (stored 0%)
#   adding: content/Eight_block_shuffling/stego_348.png (stored 0%)

# %% [markdown]
# ##Key Concatenation + Eight Block Shuffling

# %%
# Variable used to weight the losses of the secret and cover images (See paper for more details)
beta = 1.0

# Loss for reveal network
def rev_loss(y_true, y_pred):
    # Loss for reveal network is: beta * |S-S'|
    return beta * K.sum(K.square(y_true - y_pred))

# Loss for the full model, used for preparation and hidding networks
def full_loss(y_true, y_pred):
    # Loss for the full model is: |C-C'| + beta * |S-S'|
    s_true, c_true = y_true[:,:,:,0:3], y_true[:,:,:,3:6]
    s_pred, c_pred = y_pred[:,:,:,0:3], y_pred[:,:,:,3:6]
    s_loss = K.sum(K.square(s_true - s_pred))
    c_loss = K.sum(K.square(c_true - c_pred))
    return s_loss + c_loss


# Returns the encoder as a Keras model, composed by Preparation and Hiding Networks.
def make_encoder(input_size):

    input_S = Input(shape=(input_size))
    input_C= Input(shape=(input_size))
    input_K = Input(shape=(total_block,))
    input_K_concat = Input(shape=(input_size))

    batch_size = tf.shape(input_S)[0]

    blocks = tf.image.extract_patches(input_S,sizes=[1,block_size,block_size,1],strides=[1,block_size,block_size,1],rates=[1, 1, 1, 1],padding='VALID')
    blocks = tf.reshape(blocks,[batch_size, total_block, block_size, block_size, 3])

    integer_K = tf.dtypes.cast(input_K, tf.int32)
    i1 = tf.expand_dims(tf.range(batch_size), axis = 1)
    i1 = tf.tile(i1, [1, total_block])
    indices = tf.stack([i1,integer_K], axis=-1)

    scattered = tf.scatter_nd(indices, blocks, (batch_size, total_block, block_size, block_size,3 ))

    scattered_blocks = tf.unstack(scattered, axis =1)
    scattered_tensor_row_wise = [tf.concat(scattered_blocks[i:i+block_in_one_axis], axis = -2) for i in tf.range(0,total_block,block_in_one_axis)]
    x = concatenate(scattered_tensor_row_wise, axis = 1)

    # Key Concatenation
    x = concatenate([x, input_K_concat])


    # Preparation Network
    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_prep0_3x3')(x) #changed
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_prep0_4x4')(x) #changed
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_prep0_5x5')(x) #changed
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_prep1_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_prep1_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_prep1_5x5')(x)
    x = concatenate([x3, x4, x5])

    x = concatenate([input_C, x])

    # Hiding network
    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid0_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid0_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid0_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid1_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid1_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid1_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid2_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid2_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid2_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid3_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid3_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid3_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_hid4_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_hid4_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_hid5_5x5')(x)
    x = concatenate([x3, x4, x5])

    output_Cprime = Conv2D(3, (3, 3), strides = (1, 1), padding='same', activation='relu', name='output_C')(x)

    return Model(inputs=[input_S, input_C, input_K, input_K_concat], #changed
                 outputs=output_Cprime,
                 name = 'Encoder')

# Returns the decoder as a Keras model, composed by the Reveal Network
def make_decoder(input_size, fixed=False):
    # Reveal network
    reveal_input = Input(shape=(input_size))
    input_K = Input(shape=(total_block,))
    input_K_concat = Input(shape=(input_size))

    batch_size = tf.shape(reveal_input)[0]
    # Adding Gaussian noise with 0.01 standard deviation.
    input_with_noise = GaussianNoise(0.01, name='output_C_noise')(reveal_input) #changed

    x = concatenate([input_with_noise, input_K_concat])
    #x = concatenate([input_with_noise, input_K])
    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev0_3x3')(x) #changed
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev0_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev0_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev1_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev1_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev1_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev2_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev2_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev2_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev3_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev3_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev3_5x5')(x)
    x = concatenate([x3, x4, x5])

    x3 = Conv2D(50, (3, 3), strides = (1, 1), padding='same', activation='relu', name='conv_rev4_3x3')(x)
    x4 = Conv2D(10, (4, 4), strides = (1, 1), padding='same', activation='relu', name='conv_rev4_4x4')(x)
    x5 = Conv2D(5, (5, 5), strides = (1, 1), padding='same', activation='relu', name='conv_rev5_5x5')(x)
    x = concatenate([x3, x4, x5])

    x = Conv2D(3, (3, 3), strides = (1, 1), padding='same', activation='relu', name='output_S')(x)

    scattered_tensor = x
    blocks = tf.image.extract_patches(scattered_tensor,sizes=[1,block_size,block_size,1],strides=[1,block_size,block_size,1],rates=[1, 1, 1, 1],padding='VALID')
    blocks = tf.reshape(blocks,[batch_size,total_block,block_size,block_size,3])

    integer_K = tf.dtypes.cast(input_K, tf.int32)

    i1 = tf.expand_dims(tf.range(batch_size), axis = 1)
    i1 = tf.tile(i1, [1, total_block])
    indices = tf.stack([i1,integer_K], axis=-1)

    unscattered = tf.gather_nd(blocks,indices)

    unscattered_blocks = tf.unstack(unscattered, axis =1)
    unscattered_tensor_row_wise = [tf.concat(unscattered_blocks[i:i+block_in_one_axis], axis = -2) for i in range(0,total_block,block_in_one_axis)]
    output_Sprime = concatenate(unscattered_tensor_row_wise, axis = 1)


    if not fixed:
        return Model(inputs=[reveal_input,input_K, input_K_concat],
                     outputs=output_Sprime,
                     name = 'Decoder')
    # else:
    #     return Container(inputs=reveal_input,
    #                      outputs=output_Sprime,
    #                      name = 'DecoderFixed')                    # Changed
    else:
      return Network(inputs=[reveal_input,input_K, input_K_concat],   #changed
                      outputs=output_Sprime,
                      name = 'DecoderFixed')

# Full model.
def make_model(input_size):
    # Calculations for dividing into blocks

    input_S = Input(shape=(input_size))
    input_C= Input(shape=(input_size))
    input_K = Input(shape=(total_block,))
    input_K_concat = Input(shape=(input_size))

    encoder = make_encoder(input_size)

    decoder = make_decoder(input_size)
    decoder.compile(optimizer='adam', loss=rev_loss)
    decoder.trainable = False

    output_Cprime = encoder([input_S, input_C, input_K, input_K_concat]) #changed
    output_Sprime = decoder([output_Cprime, input_K, input_K_concat]) #changed

    autoencoder = Model(inputs=[input_S, input_C, input_K, input_K_concat],
                        outputs=concatenate([output_Sprime, output_Cprime]))
    autoencoder.compile(optimizer='adam', loss=full_loss)
    return encoder, decoder, autoencoder

# %%
# Block size to fragment the image
block_size = 8
block_in_one_axis =  64 // block_size
total_block = block_in_one_axis * block_in_one_axis

# %%
encoder_model, reveal_model, autoencoder_model = make_model(input_S.shape[1:])
autoencoder_model.load_weights('/content/drive/My Drive/Final_Model/key_concatenation_eight_block_shuffling/key_concatenation_eight_block_shuffling_autoencoder_model_100k_50e.hdf5')
encoder_model.load_weights('/content/drive/My Drive/Final_Model/key_concatenation_eight_block_shuffling/key_concatenation_eight_block_shuffling_encoder_model_100k_50e.hdf5')
reveal_model.load_weights('/content/drive/My Drive/Final_Model/key_concatenation_eight_block_shuffling/key_concatenation_eight_block_shuffling_reveal_model_100k_50e.hdf5')

# %%
# !mkdir "/content/Key_concat_eight_block_shuffling"

# %%
from google.colab import files
from cv2 import cv2
from tqdm import tqdm
from PIL import Image
import matplotlib

secret=X_test[0:2000]
cover=X_test[2000:4000]



input_K = np.zeros(shape=(len(secret), total_block))
for i in range(len(secret)):
    input_K[i] = random.sample(range(0, total_block), total_block)

input_K_concat = np.random.randint(256, size=(len(secret), 64, 64, 3))
input_K_concat = input_K_concat/255.

C_prime = encoder_model.predict([secret, cover, input_K, input_K_concat])

i=1
for c in tqdm(cover):
  matplotlib.image.imsave('/content/Key_concat_eight_block_shuffling/clean_'+str(i)+'.png',c)
  i= i+1

i=1
for s in tqdm(C_prime):
  s = s.clip(min = 0, max =1)
  matplotlib.image.imsave('/content/Key_concat_eight_block_shuffling/stego_'+str(i)+'.png',s)

  i= i+1
# Out:
# 100%|██████████| 2000/2000 [00:04<00:00, 435.57it/s]
# 100%|██████████| 2000/2000 [00:04<00:00, 418.43it/s]

# %%
# !zip -r /content/Key_concat_eight_block_shuffling.zip /content/Key_concat_eight_block_shuffling
from google.colab import files
files.download("/content/Key_concat_eight_block_shuffling.zip")
# Out:
#   adding: content/Key_concat_eight_block_shuffling/ (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_690.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1950.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_899.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1851.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_21.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1400.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1638.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_640.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_930.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1883.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_16.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1369.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_39.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_566.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_13.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1330.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1233.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_375.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1260.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_429.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1126.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1912.png (deflated 2%)
#   adding: content/Key_concat_eight_block_shuffling/stego_950.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1196.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1329.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1826.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1622.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1192.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1600.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1788.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1806.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_820.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1702.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1890.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_303.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_631.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/stego_17.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_965.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1310.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1829.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1531.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_891.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_383.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_315.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1029.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_591.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1850.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_279.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1890.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_450.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1986.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1675.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1155.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_813.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1122.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_485.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_815.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1028.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1246.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1741.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1148.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1475.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1647.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_42.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_51.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1460.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1142.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1556.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1753.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_972.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1922.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_291.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_768.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_975.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_551.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_278.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_220.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1489.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1028.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_136.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1122.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1488.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_744.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_662.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1664.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_758.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1210.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_952.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_149.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_983.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1678.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1993.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_394.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1409.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_985.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_538.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_790.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1402.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1413.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_869.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1664.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_584.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_676.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_432.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_374.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_525.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_608.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1326.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_5.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_637.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_252.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_275.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_773.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_655.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1567.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_494.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_860.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1662.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_185.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1784.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1708.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_309.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_473.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1990.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1126.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_190.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_312.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_320.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_798.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_246.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_499.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_982.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1088.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1505.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_615.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1441.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_509.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1863.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_684.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_586.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1016.png (deflated 8%)
#   adding: content/Key_concat_eight_block_shuffling/clean_350.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_734.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_2.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_861.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_896.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1816.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1157.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1371.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1812.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1269.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1973.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_435.png (deflated 2%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1242.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1070.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_723.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_820.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1536.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1501.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_468.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_205.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1514.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_340.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1051.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_986.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/stego_692.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1061.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_117.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1303.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_747.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_242.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1293.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_70.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_428.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_962.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1825.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_580.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_308.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/stego_286.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1202.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_633.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1696.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1137.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_947.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1605.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_269.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_167.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1041.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1368.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_945.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1424.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1281.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1699.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_394.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_299.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1814.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1793.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_951.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_262.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1931.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1518.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1988.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1672.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_111.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_789.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1082.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1955.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_579.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1683.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_215.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_111.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1659.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1618.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1378.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1256.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_135.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1881.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_236.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1570.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1150.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1215.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1288.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_607.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_855.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_972.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1927.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_999.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1040.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1377.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1067.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1562.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1948.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_129.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1291.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1612.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1947.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1382.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1236.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1403.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_121.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1458.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_389.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1001.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1084.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1246.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_97.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_2000.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1186.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_392.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1454.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1107.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1969.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_274.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1810.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1237.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_180.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1407.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_41.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_84.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1874.png (deflated 8%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1572.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1597.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_350.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1959.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_281.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_436.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1786.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_979.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1091.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_305.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_514.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_189.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_706.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_745.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_592.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_831.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_176.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_889.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1172.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_614.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_67.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1160.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1472.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_195.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_550.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1135.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_38.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_651.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1183.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_967.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1845.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1532.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_845.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_669.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_499.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_145.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_757.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1180.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1687.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_671.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1626.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_763.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_601.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_12.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1965.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_553.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1341.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_232.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1772.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1836.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1815.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_221.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1946.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1308.png (deflated 2%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1860.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1784.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_847.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_935.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1691.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_912.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_121.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_200.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_515.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1389.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1515.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_219.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_266.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1999.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1227.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_44.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_82.png (deflated 2%)
#   adding: content/Key_concat_eight_block_shuffling/clean_818.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_870.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_943.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_996.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1293.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_270.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1164.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1284.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1898.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_860.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1182.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_733.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1059.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1841.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_219.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_418.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1740.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_369.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1264.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_404.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_384.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1520.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_671.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_164.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_568.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_726.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1001.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1224.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1124.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_849.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1103.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_69.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_939.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1063.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1750.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_341.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_272.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_669.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1852.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_915.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_978.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1170.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1718.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1414.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_299.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1438.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1425.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_530.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1323.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1858.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_330.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_879.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_239.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1191.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_888.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1019.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_985.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_804.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1895.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_74.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_966.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1127.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_626.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_10.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1188.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1310.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1141.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1324.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_386.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_371.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_427.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_638.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_479.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1383.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1757.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_523.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_553.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_3.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1721.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1789.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_943.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1451.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_475.png (deflated 2%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1457.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1132.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1851.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_163.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_107.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_886.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1913.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1164.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_787.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1495.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1811.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1893.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1971.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1616.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_458.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_506.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_347.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1147.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_391.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_800.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1042.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_468.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_208.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1596.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1862.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_412.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1899.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_31.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_70.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1705.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_946.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1873.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1201.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1697.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1128.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_247.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/stego_110.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_33.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1566.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_465.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_921.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_141.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1355.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_124.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_437.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_856.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1595.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1720.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_989.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1594.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1498.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1256.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_809.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_245.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1708.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1623.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_593.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1888.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_240.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_178.png (deflated 6%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1297.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_147.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1624.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/stego_249.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_234.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_815.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_802.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_762.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_923.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_37.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_337.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1169.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_30.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_992.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1404.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1354.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1525.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_9.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_541.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1979.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1669.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_766.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_271.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_253.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_854.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1838.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1230.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1278.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_961.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_844.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_463.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1014.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_631.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_992.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1292.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1762.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1232.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_635.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/stego_529.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1981.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_563.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_304.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_406.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_420.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_160.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1108.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1909.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1640.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_662.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_387.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1665.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1743.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1453.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1260.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1417.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_743.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1742.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_415.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_400.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_388.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_598.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1849.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1696.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1521.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_387.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1231.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1139.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_488.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_876.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_541.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1152.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_723.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1546.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_601.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1266.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1848.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_612.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1499.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1364.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/stego_750.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_858.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1719.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_751.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1072.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_418.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1358.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_352.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1625.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1642.png (deflated 2%)
#   adding: content/Key_concat_eight_block_shuffling/stego_119.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1608.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_561.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1706.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1934.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1214.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_585.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1045.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1176.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_892.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_110.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_755.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1281.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1469.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_231.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_438.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1591.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1213.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_533.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1138.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_235.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1189.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_871.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_364.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_584.png (deflated 2%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1978.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_413.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1712.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1455.png (deflated 2%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1259.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_131.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_432.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1963.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_796.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_316.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1390.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_519.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1930.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_540.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_213.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_83.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1678.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_618.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1813.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1305.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_372.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1219.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1754.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_89.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1629.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1247.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1541.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1787.png (stored 0%)
# ...
#   adding: content/Key_concat_eight_block_shuffling/stego_1746.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_273.png (deflated 3%)
#   adding: content/Key_concat_eight_block_shuffling/stego_257.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_375.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_963.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_115.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_93.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1739.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_165.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1894.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1651.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_363.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1904.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_842.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1207.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1132.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_428.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1707.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_196.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1408.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1115.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1389.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1777.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_226.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_749.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_54.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_501.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1124.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1064.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/stego_256.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_66.png (deflated 4%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1804.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1411.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1053.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_698.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1932.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1056.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_238.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1776.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1811.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1748.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1910.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1351.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_343.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1222.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1635.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_937.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_570.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1567.png (deflated 2%)
#   adding: content/Key_concat_eight_block_shuffling/stego_345.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1332.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_271.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1403.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_337.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1484.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_656.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/stego_94.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1698.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1455.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_427.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_595.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1427.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1725.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_155.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_714.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_339.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_562.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_421.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1671.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1235.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_984.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1717.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1853.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_516.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_488.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1568.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_450.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_817.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/stego_165.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1828.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_775.png (deflated 2%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1586.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_942.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_933.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_455.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_336.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_707.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1684.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1123.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1737.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1288.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_877.png (deflated 4%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1776.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1186.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_834.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1312.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1936.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_193.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_65.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1086.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_543.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1859.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_201.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_243.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_459.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_416.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1598.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_211.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/stego_59.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1747.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_889.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_217.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1328.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1448.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1531.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1961.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1025.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1665.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1439.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_682.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_113.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1707.png (deflated 9%)
#   adding: content/Key_concat_eight_block_shuffling/stego_913.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_169.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1985.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1319.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/stego_401.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1981.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1773.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_835.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1071.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_385.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1090.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_137.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_197.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1352.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1181.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_184.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1004.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_21.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_241.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_680.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_694.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1816.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1484.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_918.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1758.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_230.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1057.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1362.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_890.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1327.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/stego_244.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_195.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_437.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_44.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1357.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1756.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_461.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1793.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_114.png (deflated 7%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1727.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1032.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_574.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1088.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1901.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1621.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_449.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_929.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1771.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_85.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_635.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1561.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_664.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_509.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_744.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_757.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_471.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1262.png (deflated 3%)
#   adding: content/Key_concat_eight_block_shuffling/stego_729.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_502.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_479.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_916.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_935.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_92.png (deflated 1%)
#   adding: content/Key_concat_eight_block_shuffling/stego_8.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1346.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1056.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_897.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1396.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_562.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_557.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1686.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1221.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_48.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_447.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1663.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_425.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_1868.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_917.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/clean_959.png (deflated 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_51.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_462.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_1149.png (stored 0%)
#   adding: content/Key_concat_eight_block_shuffling/stego_348.png (stored 0%)
