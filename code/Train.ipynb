# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import glob
import random
list_files = []
list_file_pattern = ["tiny-imagenet-200/train/*/*/*.JPEG"]
for file_pattern in list_file_pattern:
     sub_list_files = glob.glob(file_pattern)
     list_files = [*list_files, *sub_list_files]
#changed
random.seed(10)
random.shuffle(list_files)
#list_files = list_files[:5000]

N_TEST_SAMPLES = int(0.1 * len(list_files))
N_TRAIN_SAMPLES= len(list_files) - N_TEST_SAMPLES
list_files_train, list_files_val = list_files[:N_TRAIN_SAMPLES], list_files[N_TRAIN_SAMPLES:]

print("Total number of image:", len(list_files))
print("Total number of training:", N_TRAIN_SAMPLES)
print("Total number of testing:", N_TEST_SAMPLES)
# Out:
# Total number of image: 100000
# Total number of training: 90000
# Total number of testing: 10000

# %% [markdown]
# Check Out the Dataset
#
#
# ```
# # This is formatted as code
# ```

# %% [markdown]
# dataset.py

# %%
import numpy as np
import cv2

import keras
 
class ImageDataGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_files, dim, std, mean, batch_size=64, shuffle=True):
        'Initialization'
        
        self.list_files = list_files
        self.dim = dim
        self.std = std
        self.mean = mean
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_files) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        list_files_batch = [self.list_files[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(list_files_batch)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_files))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def normalize_batch(self, imgs):
        imgs = np.array(imgs, dtype=np.float32)
        imgs /= 255
        return (imgs -  self.mean) / self.std
                                                            
    def denormalize_batch(self, imgs, should_clip=True):
        imgs= imgs * self.std + self.mean 
        if should_clip:
            imgs = np.clip(imgs,0,1)
        imgs *= 255
        return imgs

    def __data_generation(self, list_files_batch):
        'Generates data containing batch_size samples' 
        X = []
        for i, fname in enumerate(list_files_batch):
            img = cv2.imread(fname)
            img = cv2.resize(img, (self.dim[1], self.dim[0]))
            # print(img.shape)
            X.append(img)
        X = self.normalize_batch(X)
        mid = int(len(X) / 2)
        secret = X[:mid]
        cover = X[mid:]
        return [secret, cover], [cover, secret]

# %% [markdown]
# model.py

# %%
import keras
import numpy as np
import os
import pickle

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

import tensorflow as tf
from tensorflow.compat.v1.keras.backend import set_session #changed
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, concatenate, Input
from keras.layers.noise import GaussianNoise
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adadelta, RMSprop



def prepare_network(input_shape, input_tensor):
    # first block
    first_3x3_conv = Sequential([
        Conv2D(filters = 50, kernel_size = (3, 3),padding = 'Same', activation = 'relu', input_shape = input_shape),
        Conv2D(filters = 50, kernel_size = (3, 3),padding = 'Same', activation = 'relu'),
        Conv2D(filters = 50, kernel_size = (3, 3),padding = 'Same', activation = 'relu'),
        Conv2D(filters = 50, kernel_size = (3, 3),padding = 'Same', activation = 'relu')
    ])(input_tensor)

    first_4x4_conv = Sequential([
        Conv2D(filters = 50, kernel_size = (4, 4),padding = 'Same', activation = 'relu', input_shape = input_shape),
        Conv2D(filters = 50, kernel_size = (4, 4),padding = 'Same', activation = 'relu'),
        Conv2D(filters = 50, kernel_size = (4, 4),padding = 'Same', activation = 'relu'),
        Conv2D(filters = 50, kernel_size = (4, 4),padding = 'Same', activation = 'relu')
    ])(input_tensor)

    first_5x5_conv = Sequential([
        Conv2D(filters = 50, kernel_size = (5, 5),padding = 'Same', activation = 'relu', input_shape = input_shape),
        Conv2D(filters = 50, kernel_size = (5, 5),padding = 'Same', activation = 'relu'),
        Conv2D(filters = 50, kernel_size = (5, 5),padding = 'Same', activation = 'relu'),
        Conv2D(filters = 50, kernel_size = (5, 5),padding = 'Same', activation = 'relu')
    ])(input_tensor)
    
    first_tensor = concatenate([first_3x3_conv, first_4x4_conv, first_5x5_conv], axis=3)

    # second blockGaussianNoise
    second_3x3_conv = Conv2D(filters = 50, kernel_size = (3, 3), 
                            padding = 'Same', activation = 'relu')(first_tensor)

    second_4x4_conv = Conv2D(filters = 50, kernel_size = (4, 4), 
                            padding = 'Same', activation = 'relu')(first_tensor)

    second_5x5_conv = Conv2D(filters = 50, kernel_size = (5, 5), 
                            padding = 'Same', activation = 'relu')(first_tensor)                                                

    second_tensor = concatenate([second_3x3_conv, second_4x4_conv, second_5x5_conv], axis=3, name='prepare_net_out')

    return second_tensor


def hidding_network(input_shape, input_tensor):
    # first block
    first_3x3_conv = Sequential([
        Conv2D(filters = 50, kernel_size = (3, 3),padding = 'Same', activation = 'relu', input_shape = input_shape),
        Conv2D(filters = 50, kernel_size = (3, 3),padding = 'Same', activation = 'relu'),
        Conv2D(filters = 50, kernel_size = (3, 3),padding = 'Same', activation = 'relu'),
        Conv2D(filters = 50, kernel_size = (3, 3),padding = 'Same', activation = 'relu')
    ])(input_tensor)

    first_4x4_conv = Sequential([
        Conv2D(filters = 50, kernel_size = (4, 4),padding = 'Same', activation = 'relu', input_shape = input_shape),
        Conv2D(filters = 50, kernel_size = (4, 4),padding = 'Same', activation = 'relu'),
        Conv2D(filters = 50, kernel_size = (4, 4),padding = 'Same', activation = 'relu'),
        Conv2D(filters = 50, kernel_size = (4, 4),padding = 'Same', activation = 'relu')
    ])(input_tensor)

    first_5x5_conv = Sequential([
        Conv2D(filters = 50, kernel_size = (5, 5),padding = 'Same', activation = 'relu', input_shape = input_shape),
        Conv2D(filters = 50, kernel_size = (5, 5),padding = 'Same', activation = 'relu'),
        Conv2D(filters = 50, kernel_size = (5, 5),padding = 'Same', activation = 'relu'),
        Conv2D(filters = 50, kernel_size = (5, 5),padding = 'Same', activation = 'relu')
    ])(input_tensor)
    
    first_tensor = concatenate([first_3x3_conv, first_4x4_conv, first_5x5_conv], axis=3)

    # second block
    second_3x3_conv = Conv2D(filters = 50, kernel_size = (3, 3), 
                            padding = 'Same', activation = 'relu')(first_tensor)

    second_4x4_conv = Conv2D(filters = 50, kernel_size = (4, 4), 
                            padding = 'Same', activation = 'relu')(first_tensor)

    second_5x5_conv = Conv2D(filters = 50, kernel_size = (5, 5), 
                            padding = 'Same', activation = 'relu')(first_tensor)                                                

    second_tensor = concatenate([second_3x3_conv, second_4x4_conv, second_5x5_conv], axis=3)

    # convert to 3 channels image
    out = Conv2D(filters = 3, kernel_size = (1, 1), padding = 'Same', 
                activation = 'relu', name='hidding_net_out')(second_tensor) 
                
    # add noise
    out_noise = GaussianNoise(stddev=0.1, name='hidding_net_out_noise')(out)

    return out, out_noise

def reveal_network(input_shape, input_tensor):
    # first block
    first_3x3_conv = Sequential([
        Conv2D(filters = 50, kernel_size = (3, 3),padding = 'Same', activation = 'relu', input_shape = input_shape),
        Conv2D(filters = 50, kernel_size = (3, 3),padding = 'Same', activation = 'relu'),
        Conv2D(filters = 50, kernel_size = (3, 3),padding = 'Same', activation = 'relu'),
        Conv2D(filters = 50, kernel_size = (3, 3),padding = 'Same', activation = 'relu')
    ])(input_tensor)

    first_4x4_conv = Sequential([
        Conv2D(filters = 50, kernel_size = (4, 4),padding = 'Same', activation = 'relu', input_shape = input_shape),
        Conv2D(filters = 50, kernel_size = (4, 4),padding = 'Same', activation = 'relu'),
        Conv2D(filters = 50, kernel_size = (4, 4),padding = 'Same', activation = 'relu'),
        Conv2D(filters = 50, kernel_size = (4, 4),padding = 'Same', activation = 'relu')
    ])(input_tensor)

    first_5x5_conv = Sequential([
        Conv2D(filters = 50, kernel_size = (5, 5),padding = 'Same', activation = 'relu', input_shape = input_shape),
        Conv2D(filters = 50, kernel_size = (5, 5),padding = 'Same', activation = 'relu'),
        Conv2D(filters = 50, kernel_size = (5, 5),padding = 'Same', activation = 'relu'),
        Conv2D(filters = 50, kernel_size = (5, 5),padding = 'Same', activation = 'relu')
    ])(input_tensor)
    
    first_tensor = concatenate([first_3x3_conv, first_4x4_conv, first_5x5_conv], axis=3)

    # second block
    second_3x3_conv = Conv2D(filters = 50, kernel_size = (3, 3), 
                            padding = 'Same', activation = 'relu')(first_tensor)

    second_4x4_conv = Conv2D(filters = 50, kernel_size = (4, 4), 
                            padding = 'Same', activation = 'relu')(first_tensor)

    second_5x5_conv = Conv2D(filters = 50, kernel_size = (5, 5), 
                            padding = 'Same', activation = 'relu')(first_tensor)                                                

    second_tensor = concatenate([second_3x3_conv, second_4x4_conv, second_5x5_conv], axis=3)

    # convert to 3 channels image
    out = Conv2D(filters = 3, kernel_size = (1, 1), padding = 'Same', 
                activation = 'relu', name = 'reveal_net_out')(second_tensor) 
    
    return out

def net(img_shape):
    # prepare network
    secret_img = Input(shape=img_shape)
    prepare_net_input_shape = img_shape
    prepare_net_out = prepare_network(prepare_net_input_shape, secret_img)

    # hidding network
    cover_img = Input(shape=img_shape)
    hidding_net_input = concatenate([cover_img, prepare_net_out], axis=3)
    hidding_net_input_shape = (*img_shape[:2], 153)
    hidding_net_out, hidding_net_out_noise = hidding_network(hidding_net_input_shape, hidding_net_input)

    reveal_net_input_shape = img_shape
    reveal_net_out = reveal_network(reveal_net_input_shape, hidding_net_out)

    model = Model(inputs=[secret_img, cover_img], outputs=[hidding_net_out, reveal_net_out])
    return model

# %% [markdown]
# Train.py

# %%
import numpy as np
import os
import pickle
import glob
import random
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

import tensorflow as tf
import keras
from keras import backend as K
from tensorflow.compat.v1.keras.backend import set_session #changed
from keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from keras.optimizers import Adadelta, RMSprop
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.utils import multi_gpu_model

# from model import *
# from dataset import ImageDataGenerator 

config = tf.compat.v1.ConfigProto() #changed
config.gpu_options.allow_growth = True
set_session(tf.compat.v1.Session(config=config))

list_files = []
list_file_pattern = ["tiny-imagenet-200/train/*/*/*.JPEG"]
for file_pattern in list_file_pattern:
    sub_list_files = glob.glob(file_pattern)
    list_files = [*list_files, *sub_list_files]

# def get_file():
#     data = pd.read_csv('shape.csv')
#     fname, x, y = data.iloc[:, 0], data.iloc[:, 1], data.iloc[:, 2]
#     list_files = []
#     for i in range(len(fname)):
#         rate = y[i] / x[i]
#         if 1.0 < rate and rate < 1.4:
#             list_files.append(fname[i])
#     return list_files
# list_files = get_file()
random.seed(10)
random.shuffle(list_files)
# list_files =list_files[:5000]

N_TEST_SAMPLES = int(0.1 * len(list_files))
N_TRAIN_SAMPLES= len(list_files) - N_TEST_SAMPLES
list_files_train, list_files_val = list_files[:N_TRAIN_SAMPLES], list_files[N_TRAIN_SAMPLES:]

print("Total number of image:", len(list_files))
print("Total number of training:", N_TRAIN_SAMPLES)
print("Total number of testing:", N_TEST_SAMPLES)

N_EPOCHS = 100
BATCH_SIZE = 64
BETA = 0.8
params = {
    'dim': (64, 64, 3),
    'std': np.array([0.229, 0.224, 0.225]),
    'mean': np.array([0.485, 0.456, 0.406]),
    'batch_size': BATCH_SIZE
}

# Generators
training_generator = ImageDataGenerator(list_files_train, **params, shuffle=True)
validation_generator = ImageDataGenerator(list_files_val, **params, shuffle=True)

# config to run with multi-GPU

'''
with tf.device("/cpu:0"):
    model = net(params['dim'])
model = multi_gpu_model(model, gpus=2)
'''
model = net(params['dim']) #changed


model.load_weights("/content/drive/My Drive/Model/weights-28-2.00.hdf5")
model.summary()

def SSIMLoss(y_true, y_pred):
  return 1 - tf.reduce_mean(tf.image.ssim(y_true, y_pred, 1.0))
#https://stackoverflow.com/questions/57357146/use-ssim-loss-function-with-keras

import math
def PSNR(y_true, y_pred):
    max_pixel = 1.0
    return 10.0 * (1.0 / math.log(10)) * K.log((max_pixel ** 2) / (K.mean(K.square(y_pred -y_true))))

#https://stackoverflow.com/questions/55844618/how-to-calculate-psnr-metric-in-keras
  
model.compile(
    loss={'hidding_net_out': 'mse', 'reveal_net_out': 'mse'},
    optimizer=RMSprop(lr=0.001, rho=0.9, epsilon=1e-08, decay=0.0),
    loss_weights={'hidding_net_out': 1, 'reveal_net_out': BETA},
    metrics=None
)


model_file = "/content/drive/My Drive/Model/weights-{epoch:02d}-{val_loss:.2f}.hdf5"
checkpoint = ModelCheckpoint(model_file, monitor='val_loss', verbose=1)
# tbCallBack = TensorBoard(log_dir='./tensorboard/CNN', write_graph=True, write_images=True)
#learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience=2, verbose=1, factor=0.5, min_lr=0.000001)
callbacks_list = [checkpoint]

model.fit_generator(
        training_generator,
        steps_per_epoch=min(N_TRAIN_SAMPLES // BATCH_SIZE, 500),
        initial_epoch=28,
        epochs=N_EPOCHS,
        validation_data=validation_generator,
        validation_steps=min(N_TEST_SAMPLES // BATCH_SIZE, 50),
        callbacks=callbacks_list,
        verbose=1)
# Out:
# Total number of image: 100000
# Total number of training: 90000
# Total number of testing: 10000
# Model: "functional_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# sequential_36 (Sequential)      (None, 64, 64, 50)   69050       input_9[0][0]
# __________________________________________________________________________________________________
# sequential_37 (Sequential)      (None, 64, 64, 50)   122600      input_9[0][0]
# __________________________________________________________________________________________________
# sequential_38 (Sequential)      (None, 64, 64, 50)   191450      input_9[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 64, 64, 150)  0           sequential_36[0][0]
#                                                                  sequential_37[0][0]
#                                                                  sequential_38[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, 64, 64, 50)   67550       concatenate_24[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, 64, 64, 50)   120050      concatenate_24[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 64, 64, 50)   187550      concatenate_24[0][0]
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# prepare_net_out (Concatenate)   (None, 64, 64, 150)  0           conv2d_192[0][0]
#                                                                  conv2d_193[0][0]
#                                                                  conv2d_194[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 64, 64, 153)  0           input_10[0][0]
#                                                                  prepare_net_out[0][0]
# __________________________________________________________________________________________________
# sequential_39 (Sequential)      (None, 64, 64, 50)   136550      concatenate_25[0][0]
# __________________________________________________________________________________________________
# sequential_40 (Sequential)      (None, 64, 64, 50)   242600      concatenate_25[0][0]
# __________________________________________________________________________________________________
# sequential_41 (Sequential)      (None, 64, 64, 50)   378950      concatenate_25[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 64, 64, 150)  0           sequential_39[0][0]
#                                                                  sequential_40[0][0]
#                                                                  sequential_41[0][0]
# __________________________________________________________________________________________________
# conv2d_207 (Conv2D)             (None, 64, 64, 50)   67550       concatenate_26[0][0]
# __________________________________________________________________________________________________
# conv2d_208 (Conv2D)             (None, 64, 64, 50)   120050      concatenate_26[0][0]
# __________________________________________________________________________________________________
# conv2d_209 (Conv2D)             (None, 64, 64, 50)   187550      concatenate_26[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 64, 64, 150)  0           conv2d_207[0][0]
#                                                                  conv2d_208[0][0]
#                                                                  conv2d_209[0][0]
# __________________________________________________________________________________________________
# hidding_net_out (Conv2D)        (None, 64, 64, 3)    453         concatenate_27[0][0]
# __________________________________________________________________________________________________
# sequential_42 (Sequential)      (None, 64, 64, 50)   69050       hidding_net_out[0][0]
# __________________________________________________________________________________________________
# sequential_43 (Sequential)      (None, 64, 64, 50)   122600      hidding_net_out[0][0]
# __________________________________________________________________________________________________
# sequential_44 (Sequential)      (None, 64, 64, 50)   191450      hidding_net_out[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 64, 64, 150)  0           sequential_42[0][0]
#                                                                  sequential_43[0][0]
#                                                                  sequential_44[0][0]
# __________________________________________________________________________________________________
# conv2d_222 (Conv2D)             (None, 64, 64, 50)   67550       concatenate_28[0][0]
# __________________________________________________________________________________________________
# conv2d_223 (Conv2D)             (None, 64, 64, 50)   120050      concatenate_28[0][0]
# __________________________________________________________________________________________________
# conv2d_224 (Conv2D)             (None, 64, 64, 50)   187550      concatenate_28[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 64, 64, 150)  0           conv2d_222[0][0]
#                                                                  conv2d_223[0][0]
#                                                                  conv2d_224[0][0]
# __________________________________________________________________________________________________
# reveal_net_out (Conv2D)         (None, 64, 64, 3)    453         concatenate_29[0][0]
# ==================================================================================================
# Total params: 2,650,656
# Trainable params: 2,650,656
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 29/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0156 - hidding_net_out_loss: 0.7619 - reveal_net_out_loss: 1.5671
# Epoch 00029: saving model to /content/drive/My Drive/Model/weights-29-2.02.hdf5
# 500/500 [==============================] - 263s 526ms/step - loss: 2.0156 - hidding_net_out_loss: 0.7619 - reveal_net_out_loss: 1.5671 - val_loss: 2.0201 - val_hidding_net_out_loss: 0.7541 - val_reveal_net_out_loss: 1.5824
# Epoch 30/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0231 - hidding_net_out_loss: 0.7584 - reveal_net_out_loss: 1.5809
# Epoch 00030: saving model to /content/drive/My Drive/Model/weights-30-2.04.hdf5
# 500/500 [==============================] - 263s 525ms/step - loss: 2.0231 - hidding_net_out_loss: 0.7584 - reveal_net_out_loss: 1.5809 - val_loss: 2.0374 - val_hidding_net_out_loss: 0.7636 - val_reveal_net_out_loss: 1.5922
# Epoch 31/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0267 - hidding_net_out_loss: 0.7680 - reveal_net_out_loss: 1.5733
# Epoch 00031: saving model to /content/drive/My Drive/Model/weights-31-2.03.hdf5
# 500/500 [==============================] - 262s 524ms/step - loss: 2.0267 - hidding_net_out_loss: 0.7680 - reveal_net_out_loss: 1.5733 - val_loss: 2.0275 - val_hidding_net_out_loss: 0.7473 - val_reveal_net_out_loss: 1.6003
# Epoch 32/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0216 - hidding_net_out_loss: 0.7663 - reveal_net_out_loss: 1.5692
# Epoch 00032: saving model to /content/drive/My Drive/Model/weights-32-2.02.hdf5
# 500/500 [==============================] - 262s 524ms/step - loss: 2.0216 - hidding_net_out_loss: 0.7663 - reveal_net_out_loss: 1.5692 - val_loss: 2.0174 - val_hidding_net_out_loss: 0.7582 - val_reveal_net_out_loss: 1.5741
# Epoch 33/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0076 - hidding_net_out_loss: 0.7553 - reveal_net_out_loss: 1.5653
# Epoch 00033: saving model to /content/drive/My Drive/Model/weights-33-2.03.hdf5
# 500/500 [==============================] - 262s 524ms/step - loss: 2.0076 - hidding_net_out_loss: 0.7553 - reveal_net_out_loss: 1.5653 - val_loss: 2.0258 - val_hidding_net_out_loss: 0.7739 - val_reveal_net_out_loss: 1.5650
# Epoch 34/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0298 - hidding_net_out_loss: 0.7653 - reveal_net_out_loss: 1.5806
# Epoch 00034: saving model to /content/drive/My Drive/Model/weights-34-1.99.hdf5
# 500/500 [==============================] - 262s 524ms/step - loss: 2.0298 - hidding_net_out_loss: 0.7653 - reveal_net_out_loss: 1.5806 - val_loss: 1.9864 - val_hidding_net_out_loss: 0.7376 - val_reveal_net_out_loss: 1.5609
# Epoch 35/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0170 - hidding_net_out_loss: 0.7604 - reveal_net_out_loss: 1.5708
# Epoch 00035: saving model to /content/drive/My Drive/Model/weights-35-2.05.hdf5
# 500/500 [==============================] - 262s 524ms/step - loss: 2.0170 - hidding_net_out_loss: 0.7604 - reveal_net_out_loss: 1.5708 - val_loss: 2.0522 - val_hidding_net_out_loss: 0.7720 - val_reveal_net_out_loss: 1.6002
# Epoch 36/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0231 - hidding_net_out_loss: 0.7613 - reveal_net_out_loss: 1.5772
# Epoch 00036: saving model to /content/drive/My Drive/Model/weights-36-2.01.hdf5
# 500/500 [==============================] - 262s 524ms/step - loss: 2.0231 - hidding_net_out_loss: 0.7613 - reveal_net_out_loss: 1.5772 - val_loss: 2.0137 - val_hidding_net_out_loss: 0.7749 - val_reveal_net_out_loss: 1.5485
# Epoch 37/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0076 - hidding_net_out_loss: 0.7553 - reveal_net_out_loss: 1.5654
# Epoch 00037: saving model to /content/drive/My Drive/Model/weights-37-2.01.hdf5
# 500/500 [==============================] - 262s 524ms/step - loss: 2.0076 - hidding_net_out_loss: 0.7553 - reveal_net_out_loss: 1.5654 - val_loss: 2.0117 - val_hidding_net_out_loss: 0.7454 - val_reveal_net_out_loss: 1.5829
# Epoch 38/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0285 - hidding_net_out_loss: 0.7652 - reveal_net_out_loss: 1.5791
# Epoch 00038: saving model to /content/drive/My Drive/Model/weights-38-2.03.hdf5
# 500/500 [==============================] - 262s 524ms/step - loss: 2.0285 - hidding_net_out_loss: 0.7652 - reveal_net_out_loss: 1.5791 - val_loss: 2.0285 - val_hidding_net_out_loss: 0.7632 - val_reveal_net_out_loss: 1.5816
# Epoch 39/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0105 - hidding_net_out_loss: 0.7558 - reveal_net_out_loss: 1.5684
# Epoch 00039: saving model to /content/drive/My Drive/Model/weights-39-2.01.hdf5
# 500/500 [==============================] - 261s 523ms/step - loss: 2.0105 - hidding_net_out_loss: 0.7558 - reveal_net_out_loss: 1.5684 - val_loss: 2.0134 - val_hidding_net_out_loss: 0.7478 - val_reveal_net_out_loss: 1.5819
# Epoch 40/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0179 - hidding_net_out_loss: 0.7600 - reveal_net_out_loss: 1.5724
# Epoch 00040: saving model to /content/drive/My Drive/Model/weights-40-2.04.hdf5
# 500/500 [==============================] - 262s 523ms/step - loss: 2.0179 - hidding_net_out_loss: 0.7600 - reveal_net_out_loss: 1.5724 - val_loss: 2.0376 - val_hidding_net_out_loss: 0.7883 - val_reveal_net_out_loss: 1.5616
# Epoch 41/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0214 - hidding_net_out_loss: 0.7611 - reveal_net_out_loss: 1.5753
# Epoch 00041: saving model to /content/drive/My Drive/Model/weights-41-2.01.hdf5
# 500/500 [==============================] - 261s 522ms/step - loss: 2.0214 - hidding_net_out_loss: 0.7611 - reveal_net_out_loss: 1.5753 - val_loss: 2.0067 - val_hidding_net_out_loss: 0.7517 - val_reveal_net_out_loss: 1.5689
# Epoch 42/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0140 - hidding_net_out_loss: 0.7578 - reveal_net_out_loss: 1.5704
# Epoch 00042: saving model to /content/drive/My Drive/Model/weights-42-2.03.hdf5
# 500/500 [==============================] - 261s 523ms/step - loss: 2.0140 - hidding_net_out_loss: 0.7578 - reveal_net_out_loss: 1.5704 - val_loss: 2.0330 - val_hidding_net_out_loss: 0.7603 - val_reveal_net_out_loss: 1.5909
# Epoch 43/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0261 - hidding_net_out_loss: 0.7690 - reveal_net_out_loss: 1.5713
# Epoch 00043: saving model to /content/drive/My Drive/Model/weights-43-2.01.hdf5
# 500/500 [==============================] - 262s 523ms/step - loss: 2.0261 - hidding_net_out_loss: 0.7690 - reveal_net_out_loss: 1.5713 - val_loss: 2.0063 - val_hidding_net_out_loss: 0.7499 - val_reveal_net_out_loss: 1.5705
# Epoch 44/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0222 - hidding_net_out_loss: 0.7638 - reveal_net_out_loss: 1.5730
# Epoch 00044: saving model to /content/drive/My Drive/Model/weights-44-2.04.hdf5
# 500/500 [==============================] - 261s 522ms/step - loss: 2.0222 - hidding_net_out_loss: 0.7638 - reveal_net_out_loss: 1.5730 - val_loss: 2.0415 - val_hidding_net_out_loss: 0.7729 - val_reveal_net_out_loss: 1.5858
# Epoch 45/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0128 - hidding_net_out_loss: 0.7565 - reveal_net_out_loss: 1.5703
# Epoch 00045: saving model to /content/drive/My Drive/Model/weights-45-2.01.hdf5
# 500/500 [==============================] - 261s 523ms/step - loss: 2.0128 - hidding_net_out_loss: 0.7565 - reveal_net_out_loss: 1.5703 - val_loss: 2.0097 - val_hidding_net_out_loss: 0.7565 - val_reveal_net_out_loss: 1.5665
# Epoch 46/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0200 - hidding_net_out_loss: 0.7664 - reveal_net_out_loss: 1.5669
# Epoch 00046: saving model to /content/drive/My Drive/Model/weights-46-2.00.hdf5
# 500/500 [==============================] - 261s 523ms/step - loss: 2.0200 - hidding_net_out_loss: 0.7664 - reveal_net_out_loss: 1.5669 - val_loss: 2.0013 - val_hidding_net_out_loss: 0.7536 - val_reveal_net_out_loss: 1.5597
# Epoch 47/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0247 - hidding_net_out_loss: 0.7627 - reveal_net_out_loss: 1.5774
# Epoch 00047: saving model to /content/drive/My Drive/Model/weights-47-2.03.hdf5
# 500/500 [==============================] - 261s 523ms/step - loss: 2.0247 - hidding_net_out_loss: 0.7627 - reveal_net_out_loss: 1.5774 - val_loss: 2.0258 - val_hidding_net_out_loss: 0.7681 - val_reveal_net_out_loss: 1.5722
# Epoch 48/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0202 - hidding_net_out_loss: 0.7614 - reveal_net_out_loss: 1.5735
# Epoch 00048: saving model to /content/drive/My Drive/Model/weights-48-2.05.hdf5
# 500/500 [==============================] - 261s 522ms/step - loss: 2.0202 - hidding_net_out_loss: 0.7614 - reveal_net_out_loss: 1.5735 - val_loss: 2.0486 - val_hidding_net_out_loss: 0.7690 - val_reveal_net_out_loss: 1.5995
# Epoch 49/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0206 - hidding_net_out_loss: 0.7628 - reveal_net_out_loss: 1.5722
# Epoch 00049: saving model to /content/drive/My Drive/Model/weights-49-2.03.hdf5
# 500/500 [==============================] - 261s 522ms/step - loss: 2.0206 - hidding_net_out_loss: 0.7628 - reveal_net_out_loss: 1.5722 - val_loss: 2.0304 - val_hidding_net_out_loss: 0.7589 - val_reveal_net_out_loss: 1.5894
# Epoch 50/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0111 - hidding_net_out_loss: 0.7596 - reveal_net_out_loss: 1.5643
# Epoch 00050: saving model to /content/drive/My Drive/Model/weights-50-2.00.hdf5
# 500/500 [==============================] - 261s 523ms/step - loss: 2.0111 - hidding_net_out_loss: 0.7596 - reveal_net_out_loss: 1.5643 - val_loss: 2.0024 - val_hidding_net_out_loss: 0.7400 - val_reveal_net_out_loss: 1.5780
# Epoch 51/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0207 - hidding_net_out_loss: 0.7643 - reveal_net_out_loss: 1.5706
# Epoch 00051: saving model to /content/drive/My Drive/Model/weights-51-2.06.hdf5
# 500/500 [==============================] - 261s 523ms/step - loss: 2.0207 - hidding_net_out_loss: 0.7643 - reveal_net_out_loss: 1.5706 - val_loss: 2.0558 - val_hidding_net_out_loss: 0.7669 - val_reveal_net_out_loss: 1.6112
# Epoch 52/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0094 - hidding_net_out_loss: 0.7615 - reveal_net_out_loss: 1.5598
# Epoch 00052: saving model to /content/drive/My Drive/Model/weights-52-2.02.hdf5
# 500/500 [==============================] - 262s 523ms/step - loss: 2.0094 - hidding_net_out_loss: 0.7615 - reveal_net_out_loss: 1.5598 - val_loss: 2.0183 - val_hidding_net_out_loss: 0.7640 - val_reveal_net_out_loss: 1.5680
# Epoch 53/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0325 - hidding_net_out_loss: 0.7631 - reveal_net_out_loss: 1.5867
# Epoch 00053: saving model to /content/drive/My Drive/Model/weights-53-2.03.hdf5
# 500/500 [==============================] - 261s 523ms/step - loss: 2.0325 - hidding_net_out_loss: 0.7631 - reveal_net_out_loss: 1.5867 - val_loss: 2.0319 - val_hidding_net_out_loss: 0.7611 - val_reveal_net_out_loss: 1.5885
# Epoch 54/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0304 - hidding_net_out_loss: 0.7641 - reveal_net_out_loss: 1.5829
# Epoch 00054: saving model to /content/drive/My Drive/Model/weights-54-2.00.hdf5
# 500/500 [==============================] - 261s 523ms/step - loss: 2.0304 - hidding_net_out_loss: 0.7641 - reveal_net_out_loss: 1.5829 - val_loss: 2.0022 - val_hidding_net_out_loss: 0.7451 - val_reveal_net_out_loss: 1.5713
# Epoch 55/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0149 - hidding_net_out_loss: 0.7555 - reveal_net_out_loss: 1.5742
# Epoch 00055: saving model to /content/drive/My Drive/Model/weights-55-2.03.hdf5
# 500/500 [==============================] - 262s 523ms/step - loss: 2.0149 - hidding_net_out_loss: 0.7555 - reveal_net_out_loss: 1.5742 - val_loss: 2.0335 - val_hidding_net_out_loss: 0.7659 - val_reveal_net_out_loss: 1.5846
# Epoch 56/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0236 - hidding_net_out_loss: 0.7605 - reveal_net_out_loss: 1.5789
# Epoch 00056: saving model to /content/drive/My Drive/Model/weights-56-2.02.hdf5
# 500/500 [==============================] - 261s 522ms/step - loss: 2.0236 - hidding_net_out_loss: 0.7605 - reveal_net_out_loss: 1.5789 - val_loss: 2.0248 - val_hidding_net_out_loss: 0.7605 - val_reveal_net_out_loss: 1.5804
# Epoch 57/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0230 - hidding_net_out_loss: 0.7676 - reveal_net_out_loss: 1.5694
# Epoch 00057: saving model to /content/drive/My Drive/Model/weights-57-2.02.hdf5
# 500/500 [==============================] - 261s 523ms/step - loss: 2.0230 - hidding_net_out_loss: 0.7676 - reveal_net_out_loss: 1.5694 - val_loss: 2.0167 - val_hidding_net_out_loss: 0.7502 - val_reveal_net_out_loss: 1.5831
# Epoch 58/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0162 - hidding_net_out_loss: 0.7611 - reveal_net_out_loss: 1.5690
# Epoch 00058: saving model to /content/drive/My Drive/Model/weights-58-2.01.hdf5
# 500/500 [==============================] - 261s 522ms/step - loss: 2.0162 - hidding_net_out_loss: 0.7611 - reveal_net_out_loss: 1.5690 - val_loss: 2.0090 - val_hidding_net_out_loss: 0.7423 - val_reveal_net_out_loss: 1.5835
# Epoch 59/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0146 - hidding_net_out_loss: 0.7597 - reveal_net_out_loss: 1.5687
# Epoch 00059: saving model to /content/drive/My Drive/Model/weights-59-2.03.hdf5
# 500/500 [==============================] - 261s 523ms/step - loss: 2.0146 - hidding_net_out_loss: 0.7597 - reveal_net_out_loss: 1.5687 - val_loss: 2.0315 - val_hidding_net_out_loss: 0.7718 - val_reveal_net_out_loss: 1.5747
# Epoch 60/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0182 - hidding_net_out_loss: 0.7596 - reveal_net_out_loss: 1.5732
# Epoch 00060: saving model to /content/drive/My Drive/Model/weights-60-2.02.hdf5
# 500/500 [==============================] - 262s 523ms/step - loss: 2.0182 - hidding_net_out_loss: 0.7596 - reveal_net_out_loss: 1.5732 - val_loss: 2.0238 - val_hidding_net_out_loss: 0.7614 - val_reveal_net_out_loss: 1.5780
# Epoch 61/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0295 - hidding_net_out_loss: 0.7593 - reveal_net_out_loss: 1.5877
# Epoch 00061: saving model to /content/drive/My Drive/Model/weights-61-2.02.hdf5
# 500/500 [==============================] - 261s 523ms/step - loss: 2.0295 - hidding_net_out_loss: 0.7593 - reveal_net_out_loss: 1.5877 - val_loss: 2.0240 - val_hidding_net_out_loss: 0.7639 - val_reveal_net_out_loss: 1.5751
# Epoch 62/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0157 - hidding_net_out_loss: 0.7568 - reveal_net_out_loss: 1.5736
# Epoch 00062: saving model to /content/drive/My Drive/Model/weights-62-2.01.hdf5
# 500/500 [==============================] - 261s 522ms/step - loss: 2.0157 - hidding_net_out_loss: 0.7568 - reveal_net_out_loss: 1.5736 - val_loss: 2.0069 - val_hidding_net_out_loss: 0.7562 - val_reveal_net_out_loss: 1.5633
# Epoch 63/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0162 - hidding_net_out_loss: 0.7620 - reveal_net_out_loss: 1.5677
# Epoch 00063: saving model to /content/drive/My Drive/Model/weights-63-2.01.hdf5
# 500/500 [==============================] - 261s 523ms/step - loss: 2.0162 - hidding_net_out_loss: 0.7620 - reveal_net_out_loss: 1.5677 - val_loss: 2.0057 - val_hidding_net_out_loss: 0.7590 - val_reveal_net_out_loss: 1.5584
# Epoch 64/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0212 - hidding_net_out_loss: 0.7579 - reveal_net_out_loss: 1.5791
# Epoch 00064: saving model to /content/drive/My Drive/Model/weights-64-2.03.hdf5
# 500/500 [==============================] - 261s 523ms/step - loss: 2.0212 - hidding_net_out_loss: 0.7579 - reveal_net_out_loss: 1.5791 - val_loss: 2.0276 - val_hidding_net_out_loss: 0.7616 - val_reveal_net_out_loss: 1.5825
# Epoch 65/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0117 - hidding_net_out_loss: 0.7608 - reveal_net_out_loss: 1.5636
# Epoch 00065: saving model to /content/drive/My Drive/Model/weights-65-2.02.hdf5
# 500/500 [==============================] - 262s 523ms/step - loss: 2.0117 - hidding_net_out_loss: 0.7608 - reveal_net_out_loss: 1.5636 - val_loss: 2.0182 - val_hidding_net_out_loss: 0.7595 - val_reveal_net_out_loss: 1.5733
# Epoch 66/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0123 - hidding_net_out_loss: 0.7599 - reveal_net_out_loss: 1.5654
# Epoch 00066: saving model to /content/drive/My Drive/Model/weights-66-2.02.hdf5
# 500/500 [==============================] - 262s 523ms/step - loss: 2.0123 - hidding_net_out_loss: 0.7599 - reveal_net_out_loss: 1.5654 - val_loss: 2.0173 - val_hidding_net_out_loss: 0.7609 - val_reveal_net_out_loss: 1.5705
# Epoch 67/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0160 - hidding_net_out_loss: 0.7563 - reveal_net_out_loss: 1.5746
# Epoch 00067: saving model to /content/drive/My Drive/Model/weights-67-2.01.hdf5
# 500/500 [==============================] - 261s 523ms/step - loss: 2.0160 - hidding_net_out_loss: 0.7563 - reveal_net_out_loss: 1.5746 - val_loss: 2.0107 - val_hidding_net_out_loss: 0.7597 - val_reveal_net_out_loss: 1.5638
# Epoch 68/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0133 - hidding_net_out_loss: 0.7564 - reveal_net_out_loss: 1.5711
# Epoch 00068: saving model to /content/drive/My Drive/Model/weights-68-2.01.hdf5
# 500/500 [==============================] - 261s 523ms/step - loss: 2.0133 - hidding_net_out_loss: 0.7564 - reveal_net_out_loss: 1.5711 - val_loss: 2.0127 - val_hidding_net_out_loss: 0.7531 - val_reveal_net_out_loss: 1.5746
# Epoch 69/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0122 - hidding_net_out_loss: 0.7606 - reveal_net_out_loss: 1.5645
# Epoch 00069: saving model to /content/drive/My Drive/Model/weights-69-2.03.hdf5
# 500/500 [==============================] - 262s 524ms/step - loss: 2.0122 - hidding_net_out_loss: 0.7606 - reveal_net_out_loss: 1.5645 - val_loss: 2.0304 - val_hidding_net_out_loss: 0.7654 - val_reveal_net_out_loss: 1.5813
# Epoch 70/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0207 - hidding_net_out_loss: 0.7596 - reveal_net_out_loss: 1.5763
# Epoch 00070: saving model to /content/drive/My Drive/Model/weights-70-2.03.hdf5
# 500/500 [==============================] - 262s 524ms/step - loss: 2.0207 - hidding_net_out_loss: 0.7596 - reveal_net_out_loss: 1.5763 - val_loss: 2.0326 - val_hidding_net_out_loss: 0.7552 - val_reveal_net_out_loss: 1.5967
# Epoch 71/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0165 - hidding_net_out_loss: 0.7603 - reveal_net_out_loss: 1.5703
# Epoch 00071: saving model to /content/drive/My Drive/Model/weights-71-2.03.hdf5
# 500/500 [==============================] - 262s 524ms/step - loss: 2.0165 - hidding_net_out_loss: 0.7603 - reveal_net_out_loss: 1.5703 - val_loss: 2.0261 - val_hidding_net_out_loss: 0.7598 - val_reveal_net_out_loss: 1.5829
# Epoch 72/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0143 - hidding_net_out_loss: 0.7599 - reveal_net_out_loss: 1.5679
# Epoch 00072: saving model to /content/drive/My Drive/Model/weights-72-2.03.hdf5
# 500/500 [==============================] - 262s 524ms/step - loss: 2.0143 - hidding_net_out_loss: 0.7599 - reveal_net_out_loss: 1.5679 - val_loss: 2.0269 - val_hidding_net_out_loss: 0.7680 - val_reveal_net_out_loss: 1.5737
# Epoch 73/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0137 - hidding_net_out_loss: 0.7551 - reveal_net_out_loss: 1.5733
# Epoch 00073: saving model to /content/drive/My Drive/Model/weights-73-1.98.hdf5
# 500/500 [==============================] - 262s 523ms/step - loss: 2.0137 - hidding_net_out_loss: 0.7551 - reveal_net_out_loss: 1.5733 - val_loss: 1.9824 - val_hidding_net_out_loss: 0.7471 - val_reveal_net_out_loss: 1.5442
# Epoch 74/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0133 - hidding_net_out_loss: 0.7553 - reveal_net_out_loss: 1.5725
# Epoch 00074: saving model to /content/drive/My Drive/Model/weights-74-2.01.hdf5
# 500/500 [==============================] - 262s 524ms/step - loss: 2.0133 - hidding_net_out_loss: 0.7553 - reveal_net_out_loss: 1.5725 - val_loss: 2.0147 - val_hidding_net_out_loss: 0.7439 - val_reveal_net_out_loss: 1.5885
# Epoch 75/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0289 - hidding_net_out_loss: 0.7655 - reveal_net_out_loss: 1.5791
# Epoch 00075: saving model to /content/drive/My Drive/Model/weights-75-2.02.hdf5
# 500/500 [==============================] - 262s 524ms/step - loss: 2.0289 - hidding_net_out_loss: 0.7655 - reveal_net_out_loss: 1.5791 - val_loss: 2.0237 - val_hidding_net_out_loss: 0.7830 - val_reveal_net_out_loss: 1.5509
# Epoch 76/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0145 - hidding_net_out_loss: 0.7538 - reveal_net_out_loss: 1.5759
# Epoch 00076: saving model to /content/drive/My Drive/Model/weights-76-2.04.hdf5
# 500/500 [==============================] - 262s 523ms/step - loss: 2.0145 - hidding_net_out_loss: 0.7538 - reveal_net_out_loss: 1.5759 - val_loss: 2.0380 - val_hidding_net_out_loss: 0.7625 - val_reveal_net_out_loss: 1.5944
# Epoch 77/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0211 - hidding_net_out_loss: 0.7619 - reveal_net_out_loss: 1.5740
# Epoch 00077: saving model to /content/drive/My Drive/Model/weights-77-2.02.hdf5
# 500/500 [==============================] - 262s 523ms/step - loss: 2.0211 - hidding_net_out_loss: 0.7619 - reveal_net_out_loss: 1.5740 - val_loss: 2.0176 - val_hidding_net_out_loss: 0.7566 - val_reveal_net_out_loss: 1.5762
# Epoch 78/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0214 - hidding_net_out_loss: 0.7597 - reveal_net_out_loss: 1.5771
# Epoch 00078: saving model to /content/drive/My Drive/Model/weights-78-2.03.hdf5
# 500/500 [==============================] - 262s 523ms/step - loss: 2.0214 - hidding_net_out_loss: 0.7597 - reveal_net_out_loss: 1.5771 - val_loss: 2.0305 - val_hidding_net_out_loss: 0.7484 - val_reveal_net_out_loss: 1.6026
# Epoch 79/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0179 - hidding_net_out_loss: 0.7609 - reveal_net_out_loss: 1.5712
# Epoch 00079: saving model to /content/drive/My Drive/Model/weights-79-2.01.hdf5
# 500/500 [==============================] - 261s 523ms/step - loss: 2.0179 - hidding_net_out_loss: 0.7609 - reveal_net_out_loss: 1.5712 - val_loss: 2.0055 - val_hidding_net_out_loss: 0.7413 - val_reveal_net_out_loss: 1.5803
# Epoch 80/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0252 - hidding_net_out_loss: 0.7647 - reveal_net_out_loss: 1.5756
# Epoch 00080: saving model to /content/drive/My Drive/Model/weights-80-2.00.hdf5
# 500/500 [==============================] - 262s 523ms/step - loss: 2.0252 - hidding_net_out_loss: 0.7647 - reveal_net_out_loss: 1.5756 - val_loss: 2.0014 - val_hidding_net_out_loss: 0.7475 - val_reveal_net_out_loss: 1.5674
# Epoch 81/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0273 - hidding_net_out_loss: 0.7649 - reveal_net_out_loss: 1.5781
# Epoch 00081: saving model to /content/drive/My Drive/Model/weights-81-2.01.hdf5
# 500/500 [==============================] - 262s 523ms/step - loss: 2.0273 - hidding_net_out_loss: 0.7649 - reveal_net_out_loss: 1.5781 - val_loss: 2.0127 - val_hidding_net_out_loss: 0.7631 - val_reveal_net_out_loss: 1.5619
# Epoch 82/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0138 - hidding_net_out_loss: 0.7576 - reveal_net_out_loss: 1.5702
# Epoch 00082: saving model to /content/drive/My Drive/Model/weights-82-2.01.hdf5
# 500/500 [==============================] - 262s 524ms/step - loss: 2.0138 - hidding_net_out_loss: 0.7576 - reveal_net_out_loss: 1.5702 - val_loss: 2.0113 - val_hidding_net_out_loss: 0.7628 - val_reveal_net_out_loss: 1.5606
# Epoch 83/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0223 - hidding_net_out_loss: 0.7582 - reveal_net_out_loss: 1.5800
# Epoch 00083: saving model to /content/drive/My Drive/Model/weights-83-2.00.hdf5
# 500/500 [==============================] - 262s 524ms/step - loss: 2.0223 - hidding_net_out_loss: 0.7582 - reveal_net_out_loss: 1.5800 - val_loss: 1.9987 - val_hidding_net_out_loss: 0.7568 - val_reveal_net_out_loss: 1.5524
# Epoch 84/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0166 - hidding_net_out_loss: 0.7591 - reveal_net_out_loss: 1.5719
# Epoch 00084: saving model to /content/drive/My Drive/Model/weights-84-2.01.hdf5
# 500/500 [==============================] - 261s 522ms/step - loss: 2.0166 - hidding_net_out_loss: 0.7591 - reveal_net_out_loss: 1.5719 - val_loss: 2.0140 - val_hidding_net_out_loss: 0.7600 - val_reveal_net_out_loss: 1.5675
# Epoch 85/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0181 - hidding_net_out_loss: 0.7622 - reveal_net_out_loss: 1.5700
# Epoch 00085: saving model to /content/drive/My Drive/Model/weights-85-2.03.hdf5
# 500/500 [==============================] - 261s 523ms/step - loss: 2.0181 - hidding_net_out_loss: 0.7622 - reveal_net_out_loss: 1.5700 - val_loss: 2.0257 - val_hidding_net_out_loss: 0.7600 - val_reveal_net_out_loss: 1.5820
# Epoch 86/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0197 - hidding_net_out_loss: 0.7562 - reveal_net_out_loss: 1.5794
# Epoch 00086: saving model to /content/drive/My Drive/Model/weights-86-1.99.hdf5
# 500/500 [==============================] - 262s 523ms/step - loss: 2.0197 - hidding_net_out_loss: 0.7562 - reveal_net_out_loss: 1.5794 - val_loss: 1.9913 - val_hidding_net_out_loss: 0.7398 - val_reveal_net_out_loss: 1.5644
# Epoch 87/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0179 - hidding_net_out_loss: 0.7577 - reveal_net_out_loss: 1.5753
# Epoch 00087: saving model to /content/drive/My Drive/Model/weights-87-2.00.hdf5
# 500/500 [==============================] - 262s 523ms/step - loss: 2.0179 - hidding_net_out_loss: 0.7577 - reveal_net_out_loss: 1.5753 - val_loss: 2.0018 - val_hidding_net_out_loss: 0.7448 - val_reveal_net_out_loss: 1.5713
# Epoch 88/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0144 - hidding_net_out_loss: 0.7629 - reveal_net_out_loss: 1.5643
# Epoch 00088: saving model to /content/drive/My Drive/Model/weights-88-2.01.hdf5
# 500/500 [==============================] - 262s 523ms/step - loss: 2.0144 - hidding_net_out_loss: 0.7629 - reveal_net_out_loss: 1.5643 - val_loss: 2.0094 - val_hidding_net_out_loss: 0.7411 - val_reveal_net_out_loss: 1.5854
# Epoch 89/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0182 - hidding_net_out_loss: 0.7637 - reveal_net_out_loss: 1.5681
# Epoch 00089: saving model to /content/drive/My Drive/Model/weights-89-2.01.hdf5
# 500/500 [==============================] - 262s 523ms/step - loss: 2.0182 - hidding_net_out_loss: 0.7637 - reveal_net_out_loss: 1.5681 - val_loss: 2.0080 - val_hidding_net_out_loss: 0.7414 - val_reveal_net_out_loss: 1.5833
# Epoch 90/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0079 - hidding_net_out_loss: 0.7533 - reveal_net_out_loss: 1.5682
# Epoch 00090: saving model to /content/drive/My Drive/Model/weights-90-1.98.hdf5
# 500/500 [==============================] - 262s 523ms/step - loss: 2.0079 - hidding_net_out_loss: 0.7533 - reveal_net_out_loss: 1.5682 - val_loss: 1.9822 - val_hidding_net_out_loss: 0.7284 - val_reveal_net_out_loss: 1.5672
# Epoch 91/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0087 - hidding_net_out_loss: 0.7585 - reveal_net_out_loss: 1.5627
# Epoch 00091: saving model to /content/drive/My Drive/Model/weights-91-2.03.hdf5
# 500/500 [==============================] - 262s 523ms/step - loss: 2.0087 - hidding_net_out_loss: 0.7585 - reveal_net_out_loss: 1.5627 - val_loss: 2.0277 - val_hidding_net_out_loss: 0.7514 - val_reveal_net_out_loss: 1.5954
# Epoch 92/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0169 - hidding_net_out_loss: 0.7599 - reveal_net_out_loss: 1.5712
# Epoch 00092: saving model to /content/drive/My Drive/Model/weights-92-2.01.hdf5
# 500/500 [==============================] - 262s 523ms/step - loss: 2.0169 - hidding_net_out_loss: 0.7599 - reveal_net_out_loss: 1.5712 - val_loss: 2.0082 - val_hidding_net_out_loss: 0.7538 - val_reveal_net_out_loss: 1.5680
# Epoch 93/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0080 - hidding_net_out_loss: 0.7534 - reveal_net_out_loss: 1.5681
# Epoch 00093: saving model to /content/drive/My Drive/Model/weights-93-2.04.hdf5
# 500/500 [==============================] - 261s 523ms/step - loss: 2.0080 - hidding_net_out_loss: 0.7534 - reveal_net_out_loss: 1.5681 - val_loss: 2.0449 - val_hidding_net_out_loss: 0.7601 - val_reveal_net_out_loss: 1.6060
# Epoch 94/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0256 - hidding_net_out_loss: 0.7615 - reveal_net_out_loss: 1.5801
# Epoch 00094: saving model to /content/drive/My Drive/Model/weights-94-2.02.hdf5
# 500/500 [==============================] - 261s 523ms/step - loss: 2.0256 - hidding_net_out_loss: 0.7615 - reveal_net_out_loss: 1.5801 - val_loss: 2.0200 - val_hidding_net_out_loss: 0.7654 - val_reveal_net_out_loss: 1.5682
# Epoch 95/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0182 - hidding_net_out_loss: 0.7612 - reveal_net_out_loss: 1.5713
# Epoch 00095: saving model to /content/drive/My Drive/Model/weights-95-2.02.hdf5
# 500/500 [==============================] - 262s 523ms/step - loss: 2.0182 - hidding_net_out_loss: 0.7612 - reveal_net_out_loss: 1.5713 - val_loss: 2.0231 - val_hidding_net_out_loss: 0.7548 - val_reveal_net_out_loss: 1.5853
# Epoch 96/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0136 - hidding_net_out_loss: 0.7586 - reveal_net_out_loss: 1.5687
# Epoch 00096: saving model to /content/drive/My Drive/Model/weights-96-2.00.hdf5
# 500/500 [==============================] - 262s 523ms/step - loss: 2.0136 - hidding_net_out_loss: 0.7586 - reveal_net_out_loss: 1.5687 - val_loss: 2.0042 - val_hidding_net_out_loss: 0.7514 - val_reveal_net_out_loss: 1.5660
# Epoch 97/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0119 - hidding_net_out_loss: 0.7544 - reveal_net_out_loss: 1.5718
# Epoch 00097: saving model to /content/drive/My Drive/Model/weights-97-2.00.hdf5
# 500/500 [==============================] - 261s 523ms/step - loss: 2.0119 - hidding_net_out_loss: 0.7544 - reveal_net_out_loss: 1.5718 - val_loss: 1.9985 - val_hidding_net_out_loss: 0.7547 - val_reveal_net_out_loss: 1.5547
# Epoch 98/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0116 - hidding_net_out_loss: 0.7554 - reveal_net_out_loss: 1.5701
# Epoch 00098: saving model to /content/drive/My Drive/Model/weights-98-2.01.hdf5
# 500/500 [==============================] - 261s 523ms/step - loss: 2.0116 - hidding_net_out_loss: 0.7554 - reveal_net_out_loss: 1.5701 - val_loss: 2.0135 - val_hidding_net_out_loss: 0.7648 - val_reveal_net_out_loss: 1.5608
# Epoch 99/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0117 - hidding_net_out_loss: 0.7580 - reveal_net_out_loss: 1.5671
# Epoch 00099: saving model to /content/drive/My Drive/Model/weights-99-1.98.hdf5
# 500/500 [==============================] - 262s 523ms/step - loss: 2.0117 - hidding_net_out_loss: 0.7580 - reveal_net_out_loss: 1.5671 - val_loss: 1.9837 - val_hidding_net_out_loss: 0.7438 - val_reveal_net_out_loss: 1.5498
# Epoch 100/100
# 500/500 [==============================] - ETA: 0s - loss: 2.0173 - hidding_net_out_loss: 0.7519 - reveal_net_out_loss: 1.5818
# Epoch 00100: saving model to /content/drive/My Drive/Model/weights-100-2.02.hdf5
# 500/500 [==============================] - 261s 522ms/step - loss: 2.0173 - hidding_net_out_loss: 0.7519 - reveal_net_out_loss: 1.5818 - val_loss: 2.0202 - val_hidding_net_out_loss: 0.7567 - val_reveal_net_out_loss: 1.5793
